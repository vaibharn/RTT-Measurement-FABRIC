# %% [markdown]
# # MFLIB Slice Imports & Common Variables

# %%
slice_name = "PTP_slice_All"
print(f"Using slice_name **** {slice_name} ****")
# Out:
# Using slice_name **** PTP_slice_All ****

# %% [markdown]
# # General

# %%
import os
import json
import traceback

# %% [markdown]
# # Fablib

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

try:
    fablib = fablib_manager()                
    #fablib.show_config()
except Exception as e:
    print(f"Exception: {e}")

# %% [markdown]
# ## MFLib
# If you have trouble importing MFLib it may be because:
# * It has not been installed. Use
# ```
# pip install --user fabrictestbed-mflib
# ```
# * After you do the MFLib install, you will have to restart the notebook kernel before the importing of MFLib will work.
# * When your Jupyter Hub server container is reloaded, the above install will may be removed. If you log out or have to restart the server you will get an import error when trying to import MFLib.

# %%
#import mflib
#print(f"MFLib version  {mflib.__version__} " )

from mflib.mflib import MFLib

# %% [markdown]
# # First things first (Install necessary packages)

# %% [markdown]
# ### For extracting data from `*.pcap` files

# %%
# !conda install -y -q -c conda-forge scapy
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - scapy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.1.0               |       hd590300_1          19 KB  conda-forge
#     brotli-bin-1.1.0           |       hd590300_1          19 KB  conda-forge
#     ca-certificates-2023.11.17 |       hbcca054_0         151 KB  conda-forge
#     certifi-2023.11.17         |     pyhd8ed1ab_0         155 KB  conda-forge
#     contourpy-1.2.0            |  py310hd41b1e2_0         233 KB  conda-forge
#     cycler-0.12.1              |     pyhd8ed1ab_0          13 KB  conda-forge
#     fonttools-4.44.3           |  py310h2372a71_0         2.1 MB  conda-forge
#     freetype-2.12.1            |       h267a509_2         620 KB  conda-forge
#     kiwisolver-1.4.5           |  py310hd41b1e2_1          71 KB  conda-forge
#     lcms2-2.15                 |       haa2dc70_1         236 KB  conda-forge
#     lerc-4.0.0                 |       h27087fc_0         275 KB  conda-forge
#     libblas-3.9.0              |19_linux64_openblas          14 KB  conda-forge
#     libbrotlicommon-1.1.0      |       hd590300_1          68 KB  conda-forge
#     libbrotlidec-1.1.0         |       hd590300_1          32 KB  conda-forge
#     libbrotlienc-1.1.0         |       hd590300_1         276 KB  conda-forge
#     libcblas-3.9.0             |19_linux64_openblas          14 KB  conda-forge
#     libdeflate-1.18            |       h0b41bf4_0          64 KB  conda-forge
#     libgfortran-ng-13.2.0      |       h69a702a_0          23 KB  conda-forge
#     libgfortran5-13.2.0        |       ha4646dd_0         1.4 MB  conda-forge
#     libjpeg-turbo-2.1.5.1      |       hd590300_1         485 KB  conda-forge
#     liblapack-3.9.0            |19_linux64_openblas          14 KB  conda-forge
#     libopenblas-0.3.24         |pthreads_h413a1c8_0         5.2 MB  conda-forge
#     libpng-1.6.39              |       h753d276_0         276 KB  conda-forge
#     libtiff-4.5.1              |       h8b53f26_1         407 KB  conda-forge
#     libwebp-base-1.3.2         |       hd590300_0         392 KB  conda-forge
#     libxcb-1.15                |       h0b41bf4_0         375 KB  conda-forge
#     libzlib-1.2.13             |       hd590300_5          60 KB  conda-forge
#     matplotlib-base-3.8.0      |  py310h62c0568_1         6.5 MB  conda-forge
#     munkres-1.1.4              |     pyh9f0ad1d_0          12 KB  conda-forge
#     numpy-1.26.0               |  py310hb13e2d6_0         6.6 MB  conda-forge
#     openjpeg-2.5.0             |       hfec8fc6_2         344 KB  conda-forge
#     openssl-1.1.1w             |       hd590300_0         1.9 MB  conda-forge
#     pillow-9.5.0               |  py310h582fbeb_1        44.0 MB  conda-forge
#     pthread-stubs-0.4          |    h36c2ea0_1001           5 KB  conda-forge
#     scapy-2.5.0                |     pyhd8ed1ab_0        1010 KB  conda-forge
#     unicodedata2-15.1.0        |  py310h2372a71_0         365 KB  conda-forge
#     xorg-libxau-1.0.11         |       hd590300_0          14 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h7f98852_0          19 KB  conda-forge
#     zlib-1.2.13                |       hd590300_5          91 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        73.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli             conda-forge/linux-64::brotli-1.1.0-hd590300_1
#   brotli-bin         conda-forge/linux-64::brotli-bin-1.1.0-hd590300_1
#   contourpy          conda-forge/linux-64::contourpy-1.2.0-py310hd41b1e2_0
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_0
#   fonttools          conda-forge/linux-64::fonttools-4.44.3-py310h2372a71_0
#   freetype           conda-forge/linux-64::freetype-2.12.1-h267a509_2
#   kiwisolver         conda-forge/linux-64::kiwisolver-1.4.5-py310hd41b1e2_1
#   lcms2              conda-forge/linux-64::lcms2-2.15-haa2dc70_1
#   lerc               conda-forge/linux-64::lerc-4.0.0-h27087fc_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-19_linux64_openblas
#   libbrotlicommon    conda-forge/linux-64::libbrotlicommon-1.1.0-hd590300_1
#   libbrotlidec       conda-forge/linux-64::libbrotlidec-1.1.0-hd590300_1
#   libbrotlienc       conda-forge/linux-64::libbrotlienc-1.1.0-hd590300_1
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-19_linux64_openblas
#   libdeflate         conda-forge/linux-64::libdeflate-1.18-h0b41bf4_0
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-13.2.0-h69a702a_0
#   libgfortran5       conda-forge/linux-64::libgfortran5-13.2.0-ha4646dd_0
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-2.1.5.1-hd590300_1
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-19_linux64_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.24-pthreads_h413a1c8_0
#   libpng             conda-forge/linux-64::libpng-1.6.39-h753d276_0
#   libtiff            conda-forge/linux-64::libtiff-4.5.1-h8b53f26_1
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.3.2-hd590300_0
#   libxcb             conda-forge/linux-64::libxcb-1.15-h0b41bf4_0
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.8.0-py310h62c0568_1
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   numpy              conda-forge/linux-64::numpy-1.26.0-py310hb13e2d6_0
#   openjpeg           conda-forge/linux-64::openjpeg-2.5.0-hfec8fc6_2
#   pillow             conda-forge/linux-64::pillow-9.5.0-py310h582fbeb_1
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   scapy              conda-forge/noarch::scapy-2.5.0-pyhd8ed1ab_0
#   unicodedata2       conda-forge/linux-64::unicodedata2-15.1.0-py310h2372a71_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.11-hd590300_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2022.6.15-ha878542_0 --> 2023.11.17-hbcca054_0
#   certifi                            2022.6.15-pyhd8ed1ab_1 --> 2023.11.17-pyhd8ed1ab_0
#   libzlib                                 1.2.12-h166bdaf_2 --> 1.2.13-hd590300_5
#   openssl                                 1.1.1q-h166bdaf_0 --> 1.1.1w-hd590300_0
#   zlib                                    1.2.12-h166bdaf_2 --> 1.2.13-hd590300_5
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done

# %% [markdown]
# ### For graphing

# %%
# !conda install -y  -c conda-forge -c plotly jupyter-dash
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.14.0
#   latest version: 23.10.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - jupyter-dash
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ansi2html-1.8.0            |  py310hff52083_2          41 KB  conda-forge
#     brotli-python-1.1.0        |  py310hc6cd4ac_1         341 KB  conda-forge
#     click-8.1.7                |unix_pyh707e725_0          82 KB  conda-forge
#     dash-2.0.0                 |     pyhd8ed1ab_2         5.7 MB  conda-forge
#     flask-2.1.3                |     pyhd8ed1ab_0          71 KB  conda-forge
#     flask-compress-1.14        |     pyhd8ed1ab_0          17 KB  conda-forge
#     itsdangerous-2.1.2         |     pyhd8ed1ab_0          16 KB  conda-forge
#     jupyter-dash-0.4.2         |     pyhd8ed1ab_1          20 KB  conda-forge
#     plotly-5.18.0              |     pyhd8ed1ab_0         4.9 MB  conda-forge
#     retrying-1.3.3             |             py_2          11 KB  conda-forge
#     tenacity-8.2.3             |     pyhd8ed1ab_0          22 KB  conda-forge
#     werkzeug-3.0.1             |     pyhd8ed1ab_0         236 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        11.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   ansi2html          conda-forge/linux-64::ansi2html-1.8.0-py310hff52083_2
#   brotli-python      conda-forge/linux-64::brotli-python-1.1.0-py310hc6cd4ac_1
#   click              conda-forge/noarch::click-8.1.7-unix_pyh707e725_0
#   dash               conda-forge/noarch::dash-2.0.0-pyhd8ed1ab_2
#   flask              conda-forge/noarch::flask-2.1.3-pyhd8ed1ab_0
#   flask-compress     conda-forge/noarch::flask-compress-1.14-pyhd8ed1ab_0
#   itsdangerous       conda-forge/noarch::itsdangerous-2.1.2-pyhd8ed1ab_0
#   jupyter-dash       conda-forge/noarch::jupyter-dash-0.4.2-pyhd8ed1ab_1
#   plotly             conda-forge/noarch::plotly-5.18.0-pyhd8ed1ab_0
#   retrying           conda-forge/noarch::retrying-1.3.3-py_2
#   tenacity           conda-forge/noarch::tenacity-8.2.3-pyhd8ed1ab_0
#   werkzeug           conda-forge/noarch::werkzeug-3.0.1-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
# tenacity-8.2.3       | 22 KB     | ##################################### | 100%
# werkzeug-3.0.1       | 236 KB    | ##################################### | 100%
# dash-2.0.0           | 5.7 MB    | ##################################### | 100%
# plotly-5.18.0        | 4.9 MB    | ##################################### | 100%
# flask-compress-1.14  | 17 KB     | ##################################### | 100%
# flask-2.1.3          | 71 KB     | ##################################### | 100%
# itsdangerous-2.1.2   | 16 KB     | ##################################### | 100%
# ansi2html-1.8.0      | 41 KB     | ##################################### | 100%
# jupyter-dash-0.4.2   | 20 KB     | ##################################### | 100%
# click-8.1.7          | 82 KB     | ##################################### | 100%
# brotli-python-1.1.0  | 341 KB    | ##################################### | 100%
# retrying-1.3.3       | 11 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Retrieving notices: ...working... done

# %% [markdown]
# ### Boring but necessary imports

# %%
from pathlib import Path
from mflib import owl_data

import pandas as pd

# Critical for showing data inline 
import plotly.io as pio
pio.renderers.default = 'iframe'

# %% [markdown]
# # Input data information
#
# - slice name
# - location of local `*.pcap` files (give root directory path from which a recursive search will run)
# - csv file (for extracted data)

# %%
from datetime import datetime

now = datetime.now()
current_time = now.strftime("%Y%m%d%H%M")

#slice_name="MFLibKNIT6"
#root_data_dir = f'/home/fabric/work/owl_output/{slice_name}'
root_data_dir = f'/home/fabric/work/my_notebooks/OWL_new'
csv_path = f'/home/fabric/work/owl_output/{slice_name}_{current_time}.csv'

# %% [markdown]
# ## If csv file does not yet exist and `*.pcap` files need to be parsed, run the following

# %% [markdown]
# ### List all the .pcap files under the root data dir (recursive search)

# %%
pcap_files = owl_data.list_pcap_files(root_data_dir)
print(pcap_files)
# Out:
# [PosixPath('/home/fabric/work/my_notebooks/OWL_new/FIU/10.135.133.2.pcap'), PosixPath('/home/fabric/work/my_notebooks/OWL_new/STAR/10.129.129.2.pcap'), PosixPath('/home/fabric/work/my_notebooks/OWL_new/CLEM/10.136.2.2.pcap'), PosixPath('/home/fabric/work/my_notebooks/OWL_new/UTAH/10.132.5.2.pcap'), PosixPath('/home/fabric/work/my_notebooks/OWL_new/NCSA/10.132.131.2.pcap'), PosixPath('/home/fabric/work/my_notebooks/OWL_new/CERN/10.143.2.2.pcap'), PosixPath('/home/fabric/work/my_notebooks/OWL_new/MAX/10.130.7.2.pcap'), PosixPath('/home/fabric/work/my_notebooks/OWL_new/MASS/10.131.132.2.pcap'), PosixPath('/home/fabric/work/my_notebooks/OWL_new/MICH/10.131.3.2.pcap'), PosixPath('/home/fabric/work/my_notebooks/OWL_new/UCSD/10.134.130.2.pcap')]

# %% [markdown]
# ### Extract entries from PCAP and add to the csv file
#
# Args:
#
# - `pcap_files`: list of pcap file paths
# - `outfile (default="out.csv")`: path to output csv file
# - `append_csv (default=False)`: if set to True, append to the existing csv file of the same name; if False, it will warn and exit in case there is already a csv file of the same name.
# - `verbose (default=False)`: if True, it will print out the content of pcap files during the extraction process

# %%
owl_data.convert_pcap_to_csv(pcap_files, outfile=csv_path)
# Out:
# non-zero pcap files to be processed:  ['/home/fabric/work/my_notebooks/OWL_new/FIU/10.135.133.2.pcap', '/home/fabric/work/my_notebooks/OWL_new/STAR/10.129.129.2.pcap', '/home/fabric/work/my_notebooks/OWL_new/CLEM/10.136.2.2.pcap', '/home/fabric/work/my_notebooks/OWL_new/UTAH/10.132.5.2.pcap', '/home/fabric/work/my_notebooks/OWL_new/NCSA/10.132.131.2.pcap', '/home/fabric/work/my_notebooks/OWL_new/CERN/10.143.2.2.pcap', '/home/fabric/work/my_notebooks/OWL_new/MAX/10.130.7.2.pcap', '/home/fabric/work/my_notebooks/OWL_new/MASS/10.131.132.2.pcap', '/home/fabric/work/my_notebooks/OWL_new/MICH/10.131.3.2.pcap', '/home/fabric/work/my_notebooks/OWL_new/UCSD/10.134.130.2.pcap']
# file name: /home/fabric/work/my_notebooks/OWL_new/FIU/10.135.133.2.pcap
# file name: /home/fabric/work/my_notebooks/OWL_new/STAR/10.129.129.2.pcap
# file name: /home/fabric/work/my_notebooks/OWL_new/CLEM/10.136.2.2.pcap
# file name: /home/fabric/work/my_notebooks/OWL_new/UTAH/10.132.5.2.pcap
# file name: /home/fabric/work/my_notebooks/OWL_new/NCSA/10.132.131.2.pcap
# file name: /home/fabric/work/my_notebooks/OWL_new/CERN/10.143.2.2.pcap
# file name: /home/fabric/work/my_notebooks/OWL_new/MAX/10.130.7.2.pcap
# file name: /home/fabric/work/my_notebooks/OWL_new/MASS/10.131.132.2.pcap
# file name: /home/fabric/work/my_notebooks/OWL_new/MICH/10.131.3.2.pcap
# file name: /home/fabric/work/my_notebooks/OWL_new/UCSD/10.134.130.2.pcap

# %% [markdown]
# # Create an analyzer instance
#
# It creates a pandas DataFrame from the csv file. Incomplete rows are dropped.
#
# The only argument is the path to csv file. CSV file should have 5 columns:
# - source IP
# - sent timestamp (epoch time)
# - destination IP
# - destinatin timestamp (epoch time)
# - sequence number
# - latency

# %%
owl_data_analyzer = owl_data.OwlDataAnalyzer(csv_path)

# %% [markdown]
# ## Get slice data

# %%
try:
    slice = fablib.get_slice(name=slice_name)  
except Exception as e:
    print(f"Exception: {e}")
    
nodes = slice.get_nodes()
# for node in nodes:
#     print(node.get_name())

# %% [markdown]
# ### Print nodes information

# %%
sites_df = owl_data_analyzer.find_node_locations(nodes)
sites_df
# Out:
# /opt/conda/lib/python3.10/site-packages/mflib/owl_data.py:296: FutureWarning:
#
# The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   node_name site_name         lon        lat        exp_ip
# 0      STAR      STAR  -87.616632  41.895371  10.129.129.2
# 0       MAX       MAX  -76.943479  38.988634    10.130.7.2
# 0      MICH      MICH  -83.710132  42.293109    10.131.3.2
# 0      MASS      MASS  -72.607877  42.202493  10.131.132.2
# 0      UTAH      UTAH -111.893963  40.752802    10.132.5.2
# 0      NCSA      NCSA  -88.241537  40.095840  10.132.131.2
# 0      UCSD      UCSD -117.239324  32.888680  10.134.130.2
# 0       FIU       FIU  -80.370289  25.754295  10.135.133.2
# 0      CLEM      CLEM  -82.821289  34.586544    10.136.2.2
# 0      CERN      CERN    6.046987  46.233870    10.143.2.2

# %% [markdown]
# ### But it should be prettier ... print a map
# Try hovering over each point.

# %%
owl_data_analyzer.print_map(sites_df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/computation/expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/computation/expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# TypeError: can only concatenate str (not "IPv4Address") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 owl_data_analyzer.print_map(sites_df)
#
# File /opt/conda/lib/python3.10/site-packages/mflib/owl_data.py:315, in OwlDataAnalyzer.print_map(df)
#     301 @staticmethod
#     302 def print_map(df):
#     303     """
#     304     Print a map with nodes/sites data for fun.
#     305
#     306     :param df: Pandas.DataFrame with columns 'node_name', 'site_name', 'lon', 'lat', 'exp_ip'
#     307     :type df: Pandas.DataFrame
#     308     """
#     312     fig = go.Figure(data=go.Scattergeo(
#     313             lon = df['lon'],
#     314             lat = df['lat'],
# --> 315             text = df['site_name'] + '; ' + df['exp_ip'],
#     316             marker=dict(size=8, color="blue")
#     317             ))
#     319     fig.update_layout(
#     320             title = 'Slice nodes',
#     321             geo_scope='world',
#     322         )
#     323     fig.show()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/ops/common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:186, in OpsMixin.__add__(self, other)
#      98 @unpack_zerodim_and_defer("__add__")
#      99 def __add__(self, other):
#     100     """
#     101     Get Addition of DataFrame and other, column-wise.
#     102
#    (...)
#     184     moose     3.0     NaN
#     185     """
# --> 186     return self._arith_method(other, operator.add)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/series.py:5815, in Series._arith_method(self, other, op)
#    5813 def _arith_method(self, other, op):
#    5814     self, other = self._align_for_op(other)
# -> 5815     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/base.py:1381, in IndexOpsMixin._arith_method(self, other, op)
#    1378     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1380 with np.errstate(all="ignore"):
# -> 1381     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1383 return self._construct_result(result, name=res_name)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:285, in arithmetic_op(left, right, op)
#     281     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     283     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     284     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 285     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     287 return res_values
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:229, in _na_arithmetic_op(left, right, op, is_cmp)
#     221 except TypeError:
#     222     if not is_cmp and (
#     223         left.dtype == object or getattr(right, "dtype", None) == object
#     224     ):
#    (...)
#     227         # Don't do this for comparisons, as that will handle complex numbers
#     228         #  incorrectly, see GH#32047
# --> 229         result = _masked_arith_op(left, right, op)
#     230     else:
#     231         raise
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/ops/array_ops.py:165, in _masked_arith_op(x, y, op)
#     163     # See GH#5284, GH#5035, GH#19448 for historical reference
#     164     if mask.any():
# --> 165         result[mask] = op(xrav[mask], yrav[mask])
#     167 else:
#     168     if not is_scalar(y):
#
# TypeError: can only concatenate str (not "IPv4Address") to str

# %% [markdown]
# # Analyze the latency data

# %% [markdown]
# ## (optional) Check the content of pandas.Dataframe

# %%
df = owl_data_analyzer.get_dataframe()
df
# Out:
#            src_ip        sent_t        dst_ip         dst_t  seq_n   latency  \
# 0      10.130.7.2  1.700293e+09  10.129.129.2  1.700293e+09    274   8627134
# 1      10.130.7.2  1.700293e+09  10.129.129.2  1.700293e+09    275   8633913
# 2      10.130.7.2  1.700293e+09  10.129.129.2  1.700293e+09    276   8883994
# 3      10.130.7.2  1.700293e+09  10.129.129.2  1.700293e+09    277   8623088
# 4      10.130.7.2  1.700293e+09  10.129.129.2  1.700293e+09    278   8627482
# ...           ...           ...           ...           ...    ...       ...
# 48152  10.143.2.2  1.700299e+09    10.131.3.2  1.700299e+09   1158  54435213
# 48153  10.143.2.2  1.700299e+09    10.131.3.2  1.700299e+09   1159  54436067
# 48154  10.143.2.2  1.700299e+09    10.131.3.2  1.700299e+09   1160  54435646
# 48155  10.143.2.2  1.700299e+09    10.131.3.2  1.700299e+09   1161  54438486
# 48156  10.143.2.2  1.700299e+09    10.131.3.2  1.700299e+09   1162  54433017
#
#                     sent_t_datetime                dst_t_datetime
# 0     2023-11-18 07:38:14.534985984 2023-11-18 07:38:14.543613184
# 1     2023-11-18 07:38:15.535111936 2023-11-18 07:38:15.543745536
# 2     2023-11-18 07:38:16.535536896 2023-11-18 07:38:16.544420864
# 3     2023-11-18 07:38:17.535521280 2023-11-18 07:38:17.544144384
# 4     2023-11-18 07:38:18.535701504 2023-11-18 07:38:18.544329216
# ...                             ...                           ...
# 48152 2023-11-18 09:16:27.974394112 2023-11-18 09:16:28.028829184
# 48153 2023-11-18 09:16:28.974558208 2023-11-18 09:16:29.028994304
# 48154 2023-11-18 09:16:29.974796288 2023-11-18 09:16:30.029232128
# 48155 2023-11-18 09:16:30.974958336 2023-11-18 09:16:31.029396736
# 48156 2023-11-18 09:16:31.975106816 2023-11-18 09:16:32.029539840
#
# [48157 rows x 8 columns]

# %% [markdown]
# ## Filter by source/destination

# %%
node_names = ["STAR", "MAX", "MICH",
"MASS",
"UTAH",
"NCSA",
"UCSD",
"FIU",
"CLEM" ,"CERN" ]

# %%
#node_names = ["Node1", "Node2", "Node3"]

nodes = []
for nn in node_names:
    nodes.append(slice.get_node(name=nn))
"""    
node1 = slice.get_node(name="Node1")
node2 = slice.get_node(name="Node2")
node3 = slice.get_node(name="Node3")
node1_ip = owl_data_analyzer.list_experiment_ip_addrs(node1)[0]
node2_ip = owl_data_analyzer.list_experiment_ip_addrs(node2)[0]
node3_ip = owl_data_analyzer.list_experiment_ip_addrs(node3)[0]

print(node1_ip, node2_ip, node3_ip)
"""
# Out:
# '    \nnode1 = slice.get_node(name="Node1")\nnode2 = slice.get_node(name="Node2")\nnode3 = slice.get_node(name="Node3")\nnode1_ip = owl_data_analyzer.list_experiment_ip_addrs(node1)[0]\nnode2_ip = owl_data_analyzer.list_experiment_ip_addrs(node2)[0]\nnode3_ip = owl_data_analyzer.list_experiment_ip_addrs(node3)[0]\n\nprint(node1_ip, node2_ip, node3_ip)\n'

# %% [markdown]
# ## Get statistics

# %%
#owl_data_analyzer.summarize_data(src_node=node1, dst_node=node2)
for i in range(10):
    for j in range(10):
        owl_data_analyzer.summarize_data(src_node = nodes[i], dst_node = nodes[j])
# Out:
# *****10.129.129.2 (STAR) --> 10.129.129.2 (STAR)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.129.129.2 (10.129.129.2) 56(84) bytes of data.
# 64 bytes from 10.129.129.2: icmp_seq=1 ttl=64 time=0.029 ms
# 64 bytes from 10.129.129.2: icmp_seq=2 ttl=64 time=0.017 ms
#
# --- 10.129.129.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1050ms
# rtt min/avg/max/mdev = 0.017/0.023/0.029/0.006 ms
#
# *****10.129.129.2 (STAR) --> 10.130.7.2 (MAX)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.130.7.2 (10.130.7.2) 56(84) bytes of data.
# 64 bytes from 10.130.7.2: icmp_seq=1 ttl=61 time=17.4 ms
# 64 bytes from 10.130.7.2: icmp_seq=2 ttl=61 time=17.3 ms
#
# --- 10.130.7.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1001ms
# rtt min/avg/max/mdev = 17.281/17.316/17.351/0.035 ms
#
# *****10.129.129.2 (STAR) --> 10.131.3.2 (MICH)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.131.3.2 (10.131.3.2) 56(84) bytes of data.
# 64 bytes from 10.131.3.2: icmp_seq=1 ttl=62 time=5.37 ms
# 64 bytes from 10.131.3.2: icmp_seq=2 ttl=62 time=5.33 ms
#
# --- 10.131.3.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1001ms
# rtt min/avg/max/mdev = 5.326/5.348/5.370/0.022 ms
#
# *****10.129.129.2 (STAR) --> 10.131.132.2 (MASS)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.131.132.2 (10.131.132.2) 56(84) bytes of data.
# From 10.131.128.133 icmp_seq=1 Destination Host Unreachable
#
# --- 10.131.132.2 ping statistics ---
# 2 packets transmitted, 0 received, +1 errors, 100% packet loss, time 1042ms
# pipe 2
#
# *****10.129.129.2 (STAR) --> 10.132.5.2 (UTAH)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.132.5.2 (10.132.5.2) 56(84) bytes of data.
# 64 bytes from 10.132.5.2: icmp_seq=1 ttl=61 time=31.1 ms
# 64 bytes from 10.132.5.2: icmp_seq=2 ttl=61 time=31.0 ms
#
# --- 10.132.5.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1001ms
# rtt min/avg/max/mdev = 31.023/31.053/31.084/0.178 ms
#
# *****10.129.129.2 (STAR) --> 10.132.131.2 (NCSA)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.132.131.2 (10.132.131.2) 56(84) bytes of data.
# 64 bytes from 10.132.131.2: icmp_seq=1 ttl=62 time=2.54 ms
# 64 bytes from 10.132.131.2: icmp_seq=2 ttl=62 time=2.49 ms
#
# --- 10.132.131.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1002ms
# rtt min/avg/max/mdev = 2.486/2.513/2.541/0.057 ms
#
# *****10.129.129.2 (STAR) --> 10.134.130.2 (UCSD)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.134.130.2 (10.134.130.2) 56(84) bytes of data.
#
# --- 10.134.130.2 ping statistics ---
# 2 packets transmitted, 0 received, 100% packet loss, time 1025ms
#
#
# *****10.129.129.2 (STAR) --> 10.135.133.2 (FIU)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.135.133.2 (10.135.133.2) 56(84) bytes of data.
# From 10.133.0.178 icmp_seq=1 Destination Host Unreachable
#
# --- 10.135.133.2 ping statistics ---
# 2 packets transmitted, 0 received, +1 errors, 100% packet loss, time 1053ms
# pipe 2
#
# *****10.129.129.2 (STAR) --> 10.136.2.2 (CLEM)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.136.2.2 (10.136.2.2) 56(84) bytes of data.
# From 10.133.0.173 icmp_seq=1 Time to live exceeded
# From 10.133.0.173 icmp_seq=2 Time to live exceeded
#
# --- 10.136.2.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1001ms
#
#
# *****10.129.129.2 (STAR) --> 10.143.2.2 (CERN)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.143.2.2 (10.143.2.2) 56(84) bytes of data.
# 64 bytes from 10.143.2.2: icmp_seq=1 ttl=61 time=104 ms
# 64 bytes from 10.143.2.2: icmp_seq=2 ttl=61 time=104 ms
#
# --- 10.143.2.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1002ms
# rtt min/avg/max/mdev = 103.781/103.783/103.786/0.322 ms
#
# *****10.130.7.2 (MAX) --> 10.129.129.2 (STAR)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.129.129.2 (10.129.129.2) 56(84) bytes of data.
# 64 bytes from 10.129.129.2: icmp_seq=1 ttl=61 time=17.2 ms
# 64 bytes from 10.129.129.2: icmp_seq=2 ttl=61 time=17.2 ms
#
# --- 10.129.129.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1001ms
# rtt min/avg/max/mdev = 17.165/17.194/17.224/0.134 ms
#
# *****10.130.7.2 (MAX) --> 10.130.7.2 (MAX)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.130.7.2 (10.130.7.2) 56(84) bytes of data.
# 64 bytes from 10.130.7.2: icmp_seq=1 ttl=64 time=0.038 ms
# 64 bytes from 10.130.7.2: icmp_seq=2 ttl=64 time=0.010 ms
#
# --- 10.130.7.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1049ms
# rtt min/avg/max/mdev = 0.010/0.024/0.038/0.014 ms
#
# *****10.130.7.2 (MAX) --> 10.131.3.2 (MICH)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.131.3.2 (10.131.3.2) 56(84) bytes of data.
# 64 bytes from 10.131.3.2: icmp_seq=1 ttl=60 time=22.4 ms
# 64 bytes from 10.131.3.2: icmp_seq=2 ttl=60 time=22.3 ms
#
# --- 10.131.3.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1001ms
# rtt min/avg/max/mdev = 22.341/22.373/22.406/0.153 ms
#
# *****10.130.7.2 (MAX) --> 10.131.132.2 (MASS)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.131.132.2 (10.131.132.2) 56(84) bytes of data.
# From 10.131.128.133 icmp_seq=1 Destination Host Unreachable
#
# --- 10.131.132.2 ping statistics ---
# 2 packets transmitted, 0 received, +1 errors, 100% packet loss, time 1048ms
# pipe 2
#
# *****10.130.7.2 (MAX) --> 10.132.5.2 (UTAH)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.132.5.2 (10.132.5.2) 56(84) bytes of data.
# 64 bytes from 10.132.5.2: icmp_seq=1 ttl=59 time=48.2 ms
# 64 bytes from 10.132.5.2: icmp_seq=2 ttl=59 time=48.1 ms
#
# --- 10.132.5.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1001ms
# rtt min/avg/max/mdev = 48.081/48.120/48.160/0.222 ms
#
# *****10.130.7.2 (MAX) --> 10.132.131.2 (NCSA)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.132.131.2 (10.132.131.2) 56(84) bytes of data.
# 64 bytes from 10.132.131.2: icmp_seq=1 ttl=60 time=19.6 ms
# 64 bytes from 10.132.131.2: icmp_seq=2 ttl=60 time=19.6 ms
#
# --- 10.132.131.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1002ms
# rtt min/avg/max/mdev = 19.572/19.600/19.629/0.142 ms
#
# *****10.130.7.2 (MAX) --> 10.134.130.2 (UCSD)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.134.130.2 (10.134.130.2) 56(84) bytes of data.
#
# --- 10.134.130.2 ping statistics ---
# 2 packets transmitted, 0 received, 100% packet loss, time 1041ms
#
#
# *****10.130.7.2 (MAX) --> 10.135.133.2 (FIU)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.135.133.2 (10.135.133.2) 56(84) bytes of data.
# From 10.133.0.178 icmp_seq=1 Destination Host Unreachable
#
# --- 10.135.133.2 ping statistics ---
# 2 packets transmitted, 0 received, +1 errors, 100% packet loss, time 1014ms
# pipe 2
#
# *****10.130.7.2 (MAX) --> 10.136.2.2 (CLEM)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.136.2.2 (10.136.2.2) 56(84) bytes of data.
# From 10.133.0.173 icmp_seq=1 Time to live exceeded
# From 10.133.0.173 icmp_seq=2 Time to live exceeded
#
# --- 10.136.2.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1001ms
#
#
# *****10.130.7.2 (MAX) --> 10.143.2.2 (CERN)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.143.2.2 (10.143.2.2) 56(84) bytes of data.
# 64 bytes from 10.143.2.2: icmp_seq=1 ttl=61 time=102 ms
# 64 bytes from 10.143.2.2: icmp_seq=2 ttl=61 time=102 ms
#
# --- 10.143.2.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1001ms
# rtt min/avg/max/mdev = 102.155/102.163/102.172/0.319 ms
#
# *****10.131.3.2 (MICH) --> 10.129.129.2 (STAR)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.129.129.2 (10.129.129.2) 56(84) bytes of data.
# 64 bytes from 10.129.129.2: icmp_seq=1 ttl=62 time=5.41 ms
# 64 bytes from 10.129.129.2: icmp_seq=2 ttl=62 time=5.29 ms
#
# --- 10.129.129.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1001ms
# rtt min/avg/max/mdev = 5.294/5.354/5.414/0.060 ms
#
# *****10.131.3.2 (MICH) --> 10.130.7.2 (MAX)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.130.7.2 (10.130.7.2) 56(84) bytes of data.
# 64 bytes from 10.130.7.2: icmp_seq=1 ttl=60 time=22.2 ms
# 64 bytes from 10.130.7.2: icmp_seq=2 ttl=60 time=22.2 ms
#
# --- 10.130.7.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1001ms
# rtt min/avg/max/mdev = 22.205/22.211/22.217/0.006 ms
#
# *****10.131.3.2 (MICH) --> 10.131.3.2 (MICH)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.131.3.2 (10.131.3.2) 56(84) bytes of data.
# 64 bytes from 10.131.3.2: icmp_seq=1 ttl=64 time=0.032 ms
# 64 bytes from 10.131.3.2: icmp_seq=2 ttl=64 time=0.022 ms
#
# --- 10.131.3.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1037ms
# rtt min/avg/max/mdev = 0.022/0.027/0.032/0.005 ms
#
# *****10.131.3.2 (MICH) --> 10.131.132.2 (MASS)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.131.132.2 (10.131.132.2) 56(84) bytes of data.
# From 10.131.128.133 icmp_seq=1 Destination Host Unreachable
#
# --- 10.131.132.2 ping statistics ---
# 2 packets transmitted, 0 received, +1 errors, 100% packet loss, time 1060ms
# pipe 2
#
# *****10.131.3.2 (MICH) --> 10.132.5.2 (UTAH)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.132.5.2 (10.132.5.2) 56(84) bytes of data.
# 64 bytes from 10.132.5.2: icmp_seq=1 ttl=60 time=36.3 ms
# 64 bytes from 10.132.5.2: icmp_seq=2 ttl=60 time=36.3 ms
#
# --- 10.132.5.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1001ms
# rtt min/avg/max/mdev = 36.250/36.266/36.283/0.191 ms
#
# *****10.131.3.2 (MICH) --> 10.132.131.2 (NCSA)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.132.131.2 (10.132.131.2) 56(84) bytes of data.
# 64 bytes from 10.132.131.2: icmp_seq=1 ttl=61 time=7.76 ms
# 64 bytes from 10.132.131.2: icmp_seq=2 ttl=61 time=7.73 ms
#
# --- 10.132.131.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1002ms
# rtt min/avg/max/mdev = 7.726/7.742/7.758/0.016 ms
#
# *****10.131.3.2 (MICH) --> 10.134.130.2 (UCSD)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.134.130.2 (10.134.130.2) 56(84) bytes of data.
#
# --- 10.134.130.2 ping statistics ---
# 2 packets transmitted, 0 received, 100% packet loss, time 1058ms
#
#
# *****10.131.3.2 (MICH) --> 10.135.133.2 (FIU)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.135.133.2 (10.135.133.2) 56(84) bytes of data.
# From 10.133.0.178 icmp_seq=1 Destination Host Unreachable
#
# --- 10.135.133.2 ping statistics ---
# 2 packets transmitted, 0 received, +1 errors, 100% packet loss, time 1053ms
# pipe 2
#
# *****10.131.3.2 (MICH) --> 10.136.2.2 (CLEM)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.136.2.2 (10.136.2.2) 56(84) bytes of data.
# From 10.133.0.174 icmp_seq=1 Time to live exceeded
# From 10.133.0.174 icmp_seq=2 Time to live exceeded
#
# --- 10.136.2.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1001ms
#
#
# *****10.131.3.2 (MICH) --> 10.143.2.2 (CERN)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.143.2.2 (10.143.2.2) 56(84) bytes of data.
# 64 bytes from 10.143.2.2: icmp_seq=1 ttl=60 time=128 ms
# 64 bytes from 10.143.2.2: icmp_seq=2 ttl=60 time=128 ms
#
# --- 10.143.2.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1001ms
# rtt min/avg/max/mdev = 128.299/128.317/128.336/0.358 ms
#
# *****10.131.132.2 (MASS) --> 10.129.129.2 (STAR)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.129.129.2 (10.129.129.2) 56(84) bytes of data.
#
# --- 10.129.129.2 ping statistics ---
# 2 packets transmitted, 0 received, 100% packet loss, time 1014ms
#
#
# *****10.131.132.2 (MASS) --> 10.130.7.2 (MAX)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.130.7.2 (10.130.7.2) 56(84) bytes of data.
#
# --- 10.130.7.2 ping statistics ---
# 2 packets transmitted, 0 received, 100% packet loss, time 1016ms
#
#
# *****10.131.132.2 (MASS) --> 10.131.3.2 (MICH)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.131.3.2 (10.131.3.2) 56(84) bytes of data.
#
# --- 10.131.3.2 ping statistics ---
# 2 packets transmitted, 0 received, 100% packet loss, time 1040ms
#
#
# *****10.131.132.2 (MASS) --> 10.131.132.2 (MASS)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.131.132.2 (10.131.132.2) 56(84) bytes of data.
#
# --- 10.131.132.2 ping statistics ---
# 2 packets transmitted, 0 received, 100% packet loss, time 1011ms
#
#
# *****10.131.132.2 (MASS) --> 10.132.5.2 (UTAH)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.132.5.2 (10.132.5.2) 56(84) bytes of data.
#
# --- 10.132.5.2 ping statistics ---
# 2 packets transmitted, 0 received, 100% packet loss, time 1055ms
#
#
# *****10.131.132.2 (MASS) --> 10.132.131.2 (NCSA)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.132.131.2 (10.132.131.2) 56(84) bytes of data.
#
# --- 10.132.131.2 ping statistics ---
# 2 packets transmitted, 0 received, 100% packet loss, time 1060ms
#
#
# *****10.131.132.2 (MASS) --> 10.134.130.2 (UCSD)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.134.130.2 (10.134.130.2) 56(84) bytes of data.
#
# --- 10.134.130.2 ping statistics ---
# 2 packets transmitted, 0 received, 100% packet loss, time 1035ms
#
#
# *****10.131.132.2 (MASS) --> 10.135.133.2 (FIU)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.135.133.2 (10.135.133.2) 56(84) bytes of data.
#
# --- 10.135.133.2 ping statistics ---
# 2 packets transmitted, 0 received, 100% packet loss, time 1002ms
#
#
# *****10.131.132.2 (MASS) --> 10.136.2.2 (CLEM)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.136.2.2 (10.136.2.2) 56(84) bytes of data.
#
# --- 10.136.2.2 ping statistics ---
# 2 packets transmitted, 0 received, 100% packet loss, time 1063ms
#
#
# *****10.131.132.2 (MASS) --> 10.143.2.2 (CERN)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.143.2.2 (10.143.2.2) 56(84) bytes of data.
#
# --- 10.143.2.2 ping statistics ---
# 2 packets transmitted, 0 received, 100% packet loss, time 1036ms
#
#
# *****10.132.5.2 (UTAH) --> 10.129.129.2 (STAR)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.129.129.2 (10.129.129.2) 56(84) bytes of data.
# 64 bytes from 10.129.129.2: icmp_seq=1 ttl=61 time=31.1 ms
# 64 bytes from 10.129.129.2: icmp_seq=2 ttl=61 time=31.0 ms
#
# --- 10.129.129.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1000ms
# rtt min/avg/max/mdev = 31.039/31.067/31.095/0.028 ms
#
# *****10.132.5.2 (UTAH) --> 10.130.7.2 (MAX)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.130.7.2 (10.130.7.2) 56(84) bytes of data.
# 64 bytes from 10.130.7.2: icmp_seq=1 ttl=59 time=47.9 ms
# 64 bytes from 10.130.7.2: icmp_seq=2 ttl=59 time=47.9 ms
#
# --- 10.130.7.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1001ms
# rtt min/avg/max/mdev = 47.882/47.914/47.947/0.221 ms
#
# *****10.132.5.2 (UTAH) --> 10.131.3.2 (MICH)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.131.3.2 (10.131.3.2) 56(84) bytes of data.
# 64 bytes from 10.131.3.2: icmp_seq=1 ttl=60 time=36.3 ms
# 64 bytes from 10.131.3.2: icmp_seq=2 ttl=60 time=36.2 ms
#
# --- 10.131.3.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1001ms
# rtt min/avg/max/mdev = 36.221/36.236/36.251/0.015 ms
#
# *****10.132.5.2 (UTAH) --> 10.131.132.2 (MASS)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.131.132.2 (10.131.132.2) 56(84) bytes of data.
# From 10.131.128.133 icmp_seq=1 Destination Host Unreachable
#
# --- 10.131.132.2 ping statistics ---
# 2 packets transmitted, 0 received, +1 errors, 100% packet loss, time 1061ms
# pipe 2
#
# *****10.132.5.2 (UTAH) --> 10.132.5.2 (UTAH)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.132.5.2 (10.132.5.2) 56(84) bytes of data.
# 64 bytes from 10.132.5.2: icmp_seq=1 ttl=64 time=0.027 ms
# 64 bytes from 10.132.5.2: icmp_seq=2 ttl=64 time=0.012 ms
#
# --- 10.132.5.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1023ms
# rtt min/avg/max/mdev = 0.012/0.019/0.027/0.008 ms
#
# *****10.132.5.2 (UTAH) --> 10.132.131.2 (NCSA)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.132.131.2 (10.132.131.2) 56(84) bytes of data.
# 64 bytes from 10.132.131.2: icmp_seq=1 ttl=60 time=33.5 ms
# 64 bytes from 10.132.131.2: icmp_seq=2 ttl=60 time=33.4 ms
#
# --- 10.132.131.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1001ms
# rtt min/avg/max/mdev = 33.436/33.454/33.472/0.018 ms
#
# *****10.132.5.2 (UTAH) --> 10.134.130.2 (UCSD)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.134.130.2 (10.134.130.2) 56(84) bytes of data.
#
# --- 10.134.130.2 ping statistics ---
# 2 packets transmitted, 0 received, 100% packet loss, time 1005ms
#
#
# *****10.132.5.2 (UTAH) --> 10.135.133.2 (FIU)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.135.133.2 (10.135.133.2) 56(84) bytes of data.
# From 10.133.0.178 icmp_seq=1 Destination Host Unreachable
#
# --- 10.135.133.2 ping statistics ---
# 2 packets transmitted, 0 received, +1 errors, 100% packet loss, time 1006ms
# pipe 2
#
# *****10.132.5.2 (UTAH) --> 10.136.2.2 (CLEM)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.136.2.2 (10.136.2.2) 56(84) bytes of data.
# From 10.133.0.173 icmp_seq=1 Time to live exceeded
# From 10.133.0.173 icmp_seq=2 Time to live exceeded
#
# --- 10.136.2.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1000ms
#
#
# *****10.132.5.2 (UTAH) --> 10.143.2.2 (CERN)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.143.2.2 (10.143.2.2) 56(84) bytes of data.
# 64 bytes from 10.143.2.2: icmp_seq=1 ttl=59 time=144 ms
# 64 bytes from 10.143.2.2: icmp_seq=2 ttl=59 time=144 ms
#
# --- 10.143.2.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1000ms
# rtt min/avg/max/mdev = 144.172/144.232/144.293/0.384 ms
#
# *****10.132.131.2 (NCSA) --> 10.129.129.2 (STAR)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.129.129.2 (10.129.129.2) 56(84) bytes of data.
# 64 bytes from 10.129.129.2: icmp_seq=1 ttl=62 time=2.57 ms
# 64 bytes from 10.129.129.2: icmp_seq=2 ttl=62 time=2.52 ms
#
# --- 10.129.129.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1002ms
# rtt min/avg/max/mdev = 2.518/2.542/2.567/0.056 ms
#
# *****10.132.131.2 (NCSA) --> 10.130.7.2 (MAX)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.130.7.2 (10.130.7.2) 56(84) bytes of data.
# 64 bytes from 10.130.7.2: icmp_seq=1 ttl=60 time=19.6 ms
# 64 bytes from 10.130.7.2: icmp_seq=2 ttl=60 time=19.6 ms
#
# --- 10.130.7.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1002ms
# rtt min/avg/max/mdev = 19.581/19.597/19.614/0.140 ms
#
# *****10.132.131.2 (NCSA) --> 10.131.3.2 (MICH)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.131.3.2 (10.131.3.2) 56(84) bytes of data.
# 64 bytes from 10.131.3.2: icmp_seq=1 ttl=61 time=7.77 ms
# 64 bytes from 10.131.3.2: icmp_seq=2 ttl=61 time=7.69 ms
#
# --- 10.131.3.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1002ms
# rtt min/avg/max/mdev = 7.692/7.729/7.767/0.095 ms
#
# *****10.132.131.2 (NCSA) --> 10.131.132.2 (MASS)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.131.132.2 (10.131.132.2) 56(84) bytes of data.
# From 10.131.128.133 icmp_seq=1 Destination Host Unreachable
#
# --- 10.131.132.2 ping statistics ---
# 2 packets transmitted, 0 received, +1 errors, 100% packet loss, time 1018ms
# pipe 2
#
# *****10.132.131.2 (NCSA) --> 10.132.5.2 (UTAH)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.132.5.2 (10.132.5.2) 56(84) bytes of data.
# 64 bytes from 10.132.5.2: icmp_seq=1 ttl=60 time=33.5 ms
# 64 bytes from 10.132.5.2: icmp_seq=2 ttl=60 time=33.4 ms
#
# --- 10.132.5.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1002ms
# rtt min/avg/max/mdev = 33.444/33.464/33.485/0.184 ms
#
# *****10.132.131.2 (NCSA) --> 10.132.131.2 (NCSA)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.132.131.2 (10.132.131.2) 56(84) bytes of data.
# 64 bytes from 10.132.131.2: icmp_seq=1 ttl=64 time=0.028 ms
# 64 bytes from 10.132.131.2: icmp_seq=2 ttl=64 time=0.020 ms
#
# --- 10.132.131.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1012ms
# rtt min/avg/max/mdev = 0.020/0.024/0.028/0.004 ms
#
# *****10.132.131.2 (NCSA) --> 10.134.130.2 (UCSD)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.134.130.2 (10.134.130.2) 56(84) bytes of data.
#
# --- 10.134.130.2 ping statistics ---
# 2 packets transmitted, 0 received, 100% packet loss, time 1034ms
#
#
# *****10.132.131.2 (NCSA) --> 10.135.133.2 (FIU)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.135.133.2 (10.135.133.2) 56(84) bytes of data.
# From 10.133.0.178 icmp_seq=1 Destination Host Unreachable
#
# --- 10.135.133.2 ping statistics ---
# 2 packets transmitted, 0 received, +1 errors, 100% packet loss, time 1040ms
# pipe 2
#
# *****10.132.131.2 (NCSA) --> 10.136.2.2 (CLEM)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.136.2.2 (10.136.2.2) 56(84) bytes of data.
# From 10.133.0.174 icmp_seq=1 Time to live exceeded
# From 10.133.0.174 icmp_seq=2 Time to live exceeded
#
# --- 10.136.2.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1000ms
#
#
# *****10.132.131.2 (NCSA) --> 10.143.2.2 (CERN)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.143.2.2 (10.143.2.2) 56(84) bytes of data.
# 64 bytes from 10.143.2.2: icmp_seq=1 ttl=60 time=106 ms
# 64 bytes from 10.143.2.2: icmp_seq=2 ttl=60 time=106 ms
#
# --- 10.143.2.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1002ms
# rtt min/avg/max/mdev = 105.805/105.847/105.889/0.042 ms
#
# *****10.134.130.2 (UCSD) --> 10.129.129.2 (STAR)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.129.129.2 (10.129.129.2) 56(84) bytes of data.
# From 10.134.130.2 icmp_seq=1 Destination Host Unreachable
# From 10.134.130.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.129.129.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1035ms
# pipe 2
#
# *****10.134.130.2 (UCSD) --> 10.130.7.2 (MAX)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.130.7.2 (10.130.7.2) 56(84) bytes of data.
# From 10.134.130.2 icmp_seq=1 Destination Host Unreachable
# From 10.134.130.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.130.7.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1046ms
# pipe 2
#
# *****10.134.130.2 (UCSD) --> 10.131.3.2 (MICH)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.131.3.2 (10.131.3.2) 56(84) bytes of data.
# From 10.134.130.2 icmp_seq=1 Destination Host Unreachable
# From 10.134.130.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.131.3.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1016ms
# pipe 2
#
# *****10.134.130.2 (UCSD) --> 10.131.132.2 (MASS)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.131.132.2 (10.131.132.2) 56(84) bytes of data.
# From 10.134.130.2 icmp_seq=1 Destination Host Unreachable
# From 10.134.130.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.131.132.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1052ms
# pipe 2
#
# *****10.134.130.2 (UCSD) --> 10.132.5.2 (UTAH)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.132.5.2 (10.132.5.2) 56(84) bytes of data.
# From 10.134.130.2 icmp_seq=1 Destination Host Unreachable
# From 10.134.130.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.132.5.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1030ms
# pipe 2
#
# *****10.134.130.2 (UCSD) --> 10.132.131.2 (NCSA)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.132.131.2 (10.132.131.2) 56(84) bytes of data.
# From 10.134.130.2 icmp_seq=1 Destination Host Unreachable
# From 10.134.130.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.132.131.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1053ms
# pipe 2
#
# *****10.134.130.2 (UCSD) --> 10.134.130.2 (UCSD)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.134.130.2 (10.134.130.2) 56(84) bytes of data.
# 64 bytes from 10.134.130.2: icmp_seq=1 ttl=64 time=0.025 ms
# 64 bytes from 10.134.130.2: icmp_seq=2 ttl=64 time=0.010 ms
#
# --- 10.134.130.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1046ms
# rtt min/avg/max/mdev = 0.010/0.017/0.025/0.008 ms
#
# *****10.134.130.2 (UCSD) --> 10.135.133.2 (FIU)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.135.133.2 (10.135.133.2) 56(84) bytes of data.
# From 10.134.130.2 icmp_seq=1 Destination Host Unreachable
# From 10.134.130.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.135.133.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1039ms
# pipe 2
#
# *****10.134.130.2 (UCSD) --> 10.136.2.2 (CLEM)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.136.2.2 (10.136.2.2) 56(84) bytes of data.
# From 10.134.130.2 icmp_seq=1 Destination Host Unreachable
# From 10.134.130.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.136.2.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1002ms
# pipe 2
#
# *****10.134.130.2 (UCSD) --> 10.143.2.2 (CERN)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.143.2.2 (10.143.2.2) 56(84) bytes of data.
# From 10.134.130.2 icmp_seq=1 Destination Host Unreachable
# From 10.134.130.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.143.2.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1029ms
# pipe 2
#
# *****10.135.133.2 (FIU) --> 10.129.129.2 (STAR)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.129.129.2 (10.129.129.2) 56(84) bytes of data.
# From 10.135.133.2 icmp_seq=1 Destination Host Unreachable
# From 10.135.133.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.129.129.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1007ms
# pipe 2
#
# *****10.135.133.2 (FIU) --> 10.130.7.2 (MAX)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.130.7.2 (10.130.7.2) 56(84) bytes of data.
# From 10.135.133.2 icmp_seq=1 Destination Host Unreachable
# From 10.135.133.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.130.7.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1053ms
# pipe 2
#
# *****10.135.133.2 (FIU) --> 10.131.3.2 (MICH)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.131.3.2 (10.131.3.2) 56(84) bytes of data.
# From 10.135.133.2 icmp_seq=1 Destination Host Unreachable
# From 10.135.133.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.131.3.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1044ms
# pipe 2
#
# *****10.135.133.2 (FIU) --> 10.131.132.2 (MASS)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.131.132.2 (10.131.132.2) 56(84) bytes of data.
# From 10.135.133.2 icmp_seq=1 Destination Host Unreachable
# From 10.135.133.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.131.132.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1003ms
# pipe 2
#
# *****10.135.133.2 (FIU) --> 10.132.5.2 (UTAH)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.132.5.2 (10.132.5.2) 56(84) bytes of data.
# From 10.135.133.2 icmp_seq=1 Destination Host Unreachable
# From 10.135.133.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.132.5.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1011ms
# pipe 2
#
# *****10.135.133.2 (FIU) --> 10.132.131.2 (NCSA)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.132.131.2 (10.132.131.2) 56(84) bytes of data.
# From 10.135.133.2 icmp_seq=1 Destination Host Unreachable
# From 10.135.133.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.132.131.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1050ms
# pipe 2
#
# *****10.135.133.2 (FIU) --> 10.134.130.2 (UCSD)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.134.130.2 (10.134.130.2) 56(84) bytes of data.
# From 10.135.133.2 icmp_seq=1 Destination Host Unreachable
# From 10.135.133.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.134.130.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1050ms
# pipe 2
#
# *****10.135.133.2 (FIU) --> 10.135.133.2 (FIU)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.135.133.2 (10.135.133.2) 56(84) bytes of data.
# 64 bytes from 10.135.133.2: icmp_seq=1 ttl=64 time=0.045 ms
# 64 bytes from 10.135.133.2: icmp_seq=2 ttl=64 time=0.019 ms
#
# --- 10.135.133.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1008ms
# rtt min/avg/max/mdev = 0.019/0.032/0.045/0.013 ms
#
# *****10.135.133.2 (FIU) --> 10.136.2.2 (CLEM)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.136.2.2 (10.136.2.2) 56(84) bytes of data.
# From 10.135.133.2 icmp_seq=1 Destination Host Unreachable
# From 10.135.133.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.136.2.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1044ms
# pipe 2
#
# *****10.135.133.2 (FIU) --> 10.143.2.2 (CERN)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.143.2.2 (10.143.2.2) 56(84) bytes of data.
# From 10.135.133.2 icmp_seq=1 Destination Host Unreachable
# From 10.135.133.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.143.2.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1024ms
# pipe 2
#
# *****10.136.2.2 (CLEM) --> 10.129.129.2 (STAR)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.129.129.2 (10.129.129.2) 56(84) bytes of data.
# From 10.136.2.2 icmp_seq=1 Destination Host Unreachable
# From 10.136.2.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.129.129.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1007ms
# pipe 2
#
# *****10.136.2.2 (CLEM) --> 10.130.7.2 (MAX)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.130.7.2 (10.130.7.2) 56(84) bytes of data.
# From 10.136.2.2 icmp_seq=1 Destination Host Unreachable
# From 10.136.2.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.130.7.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1039ms
# pipe 2
#
# *****10.136.2.2 (CLEM) --> 10.131.3.2 (MICH)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.131.3.2 (10.131.3.2) 56(84) bytes of data.
# From 10.136.2.2 icmp_seq=1 Destination Host Unreachable
# From 10.136.2.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.131.3.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1020ms
# pipe 2
#
# *****10.136.2.2 (CLEM) --> 10.131.132.2 (MASS)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.131.132.2 (10.131.132.2) 56(84) bytes of data.
# From 10.136.2.2 icmp_seq=1 Destination Host Unreachable
# From 10.136.2.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.131.132.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1063ms
# pipe 2
#
# *****10.136.2.2 (CLEM) --> 10.132.5.2 (UTAH)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.132.5.2 (10.132.5.2) 56(84) bytes of data.
# From 10.136.2.2 icmp_seq=1 Destination Host Unreachable
# From 10.136.2.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.132.5.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1045ms
# pipe 2
#
# *****10.136.2.2 (CLEM) --> 10.132.131.2 (NCSA)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.132.131.2 (10.132.131.2) 56(84) bytes of data.
# From 10.136.2.2 icmp_seq=1 Destination Host Unreachable
# From 10.136.2.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.132.131.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1058ms
# pipe 2
#
# *****10.136.2.2 (CLEM) --> 10.134.130.2 (UCSD)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.134.130.2 (10.134.130.2) 56(84) bytes of data.
# From 10.136.2.2 icmp_seq=1 Destination Host Unreachable
# From 10.136.2.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.134.130.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1008ms
# pipe 2
#
# *****10.136.2.2 (CLEM) --> 10.135.133.2 (FIU)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.135.133.2 (10.135.133.2) 56(84) bytes of data.
# From 10.136.2.2 icmp_seq=1 Destination Host Unreachable
# From 10.136.2.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.135.133.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1041ms
# pipe 2
#
# *****10.136.2.2 (CLEM) --> 10.136.2.2 (CLEM)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.136.2.2 (10.136.2.2) 56(84) bytes of data.
# 64 bytes from 10.136.2.2: icmp_seq=1 ttl=64 time=0.028 ms
# 64 bytes from 10.136.2.2: icmp_seq=2 ttl=64 time=0.017 ms
#
# --- 10.136.2.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1003ms
# rtt min/avg/max/mdev = 0.017/0.022/0.028/0.007 ms
#
# *****10.136.2.2 (CLEM) --> 10.143.2.2 (CERN)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.143.2.2 (10.143.2.2) 56(84) bytes of data.
# From 10.136.2.2 icmp_seq=1 Destination Host Unreachable
# From 10.136.2.2 icmp_seq=2 Destination Host Unreachable
#
# --- 10.143.2.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1046ms
# pipe 2
#
# *****10.143.2.2 (CERN) --> 10.129.129.2 (STAR)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.129.129.2 (10.129.129.2) 56(84) bytes of data.
# 64 bytes from 10.129.129.2: icmp_seq=1 ttl=61 time=104 ms
# 64 bytes from 10.129.129.2: icmp_seq=2 ttl=61 time=104 ms
#
# --- 10.129.129.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1002ms
# rtt min/avg/max/mdev = 103.740/103.773/103.806/0.033 ms
#
# *****10.143.2.2 (CERN) --> 10.130.7.2 (MAX)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.130.7.2 (10.130.7.2) 56(84) bytes of data.
# 64 bytes from 10.130.7.2: icmp_seq=1 ttl=61 time=102 ms
# 64 bytes from 10.130.7.2: icmp_seq=2 ttl=61 time=102 ms
#
# --- 10.130.7.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1001ms
# rtt min/avg/max/mdev = 102.167/102.180/102.193/0.013 ms
#
# *****10.143.2.2 (CERN) --> 10.131.3.2 (MICH)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.131.3.2 (10.131.3.2) 56(84) bytes of data.
# 64 bytes from 10.131.3.2: icmp_seq=1 ttl=60 time=128 ms
# 64 bytes from 10.131.3.2: icmp_seq=2 ttl=60 time=128 ms
#
# --- 10.131.3.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1001ms
# rtt min/avg/max/mdev = 128.313/128.359/128.406/0.361 ms
#
# *****10.143.2.2 (CERN) --> 10.131.132.2 (MASS)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.131.132.2 (10.131.132.2) 56(84) bytes of data.
# From 10.131.128.133 icmp_seq=1 Destination Host Unreachable
#
# --- 10.131.132.2 ping statistics ---
# 2 packets transmitted, 0 received, +1 errors, 100% packet loss, time 1026ms
# pipe 2
#
# *****10.143.2.2 (CERN) --> 10.132.5.2 (UTAH)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.132.5.2 (10.132.5.2) 56(84) bytes of data.
# 64 bytes from 10.132.5.2: icmp_seq=1 ttl=59 time=144 ms
# 64 bytes from 10.132.5.2: icmp_seq=2 ttl=59 time=144 ms
#
# --- 10.132.5.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1000ms
# rtt min/avg/max/mdev = 144.198/144.257/144.316/0.059 ms
#
# *****10.143.2.2 (CERN) --> 10.132.131.2 (NCSA)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.132.131.2 (10.132.131.2) 56(84) bytes of data.
# 64 bytes from 10.132.131.2: icmp_seq=1 ttl=60 time=106 ms
# 64 bytes from 10.132.131.2: icmp_seq=2 ttl=60 time=106 ms
#
# --- 10.132.131.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1002ms
# rtt min/avg/max/mdev = 105.829/105.863/105.897/0.034 ms
#
# *****10.143.2.2 (CERN) --> 10.134.130.2 (UCSD)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.134.130.2 (10.134.130.2) 56(84) bytes of data.
#
# --- 10.134.130.2 ping statistics ---
# 2 packets transmitted, 0 received, 100% packet loss, time 1020ms
#
#
# *****10.143.2.2 (CERN) --> 10.135.133.2 (FIU)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.135.133.2 (10.135.133.2) 56(84) bytes of data.
#
# --- 10.135.133.2 ping statistics ---
# 2 packets transmitted, 0 received, 100% packet loss, time 1043ms
#
#
# *****10.143.2.2 (CERN) --> 10.136.2.2 (CLEM)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.136.2.2 (10.136.2.2) 56(84) bytes of data.
# From 10.133.0.173 icmp_seq=1 Time to live exceeded
# From 10.133.0.173 icmp_seq=2 Time to live exceeded
#
# --- 10.136.2.2 ping statistics ---
# 2 packets transmitted, 0 received, +2 errors, 100% packet loss, time 1000ms
#
#
# *****10.143.2.2 (CERN) --> 10.143.2.2 (CERN)
# Number of samples 0
# Median Latency (ns): nan
# Median Latency (micros): nan
# Median Latency (ms): nan
# Median Latency (s): nan
# max latency (ns): nan
# min latency (ns): nan
#
# ***Compare the result to ping
# PING 10.143.2.2 (10.143.2.2) 56(84) bytes of data.
# 64 bytes from 10.143.2.2: icmp_seq=1 ttl=64 time=0.028 ms
# 64 bytes from 10.143.2.2: icmp_seq=2 ttl=64 time=0.038 ms
#
# --- 10.143.2.2 ping statistics ---
# 2 packets transmitted, 2 received, 0% packet loss, time 1024ms
# rtt min/avg/max/mdev = 0.028/0.033/0.038/0.005 ms

# %%
owl_data_analyzer.summarize_data(src_node=node2, dst_node=node1)

# %%
owl_data_analyzer.summarize_data(src_node=node3, dst_node=node2)

# %%
owl_data_analyzer.summarize_data(src_node=node1, dst_node=node3)

# %% [markdown]
# ## Graph the latency over time

# %%
owl_data_analyzer.graph_latency_data(nodes[0], nodes[1])
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_26.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %%
owl_data_analyzer.graph_latency_data(node2, node1)

# %%
owl_data_analyzer.graph_latency_data(node3, node2)

# %%
owl_data_analyzer.graph_latency_data(node1, node3)
