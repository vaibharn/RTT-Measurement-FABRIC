# %% [markdown]
# # Create a slice with PTP for precise time measurements
#
# For running MF timestamp or OWL (one-way latency measurement) tools, slice nodes must meet prerequisites:
#
# + Git and Dockerhub must be reachable
# + Docker has to be running
# + PTP (Precision Time Protocol) clock must be running/
#
# This notebook creates a 3-node slice and sets up all the the above
#
# (Tested on 2023/08/18)

# %% [markdown]
# ## Import the FABlib Library

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

try:
    fablib = fablib_manager()
                     
    fablib.show_config()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_a321a tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_a321a tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_a321a caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_a321a_row0_col0, #T_a321a_row0_col1, #T_a321a_row1_col0, #T_a321a_row1_col1, #T_a321a_row2_col0, #T_a321a_row2_col1, #T_a321a_row3_col0, #T_a321a_row3_col1, #T_a321a_row4_col0, #T_a321a_row4_col1, #T_a321a_row5_col0, #T_a321a_row5_col1, #T_a321a_row6_col0, #T_a321a_row6_col1, #T_a321a_row7_col0, #T_a321a_row7_col1, #T_a321a_row8_col0, #T_a321a_row8_col1, #T_a321a_row9_col0, #T_a321a_row9_col1, #T_a321a_row10_col0, #T_a321a_row10_col1, #T_a321a_row11_col0, #T_a321a_row11_col1, #T_a321a_row12_col0, #T_a321a_row12_col1, #T_a321a_row13_col0, #T_a321a_row13_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_a321a">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a321a_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_a321a_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_a321a_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_a321a_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_a321a_row2_col0" class="data row2 col0" >Token File</td>
#       <td id="T_a321a_row2_col1" class="data row2 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_a321a_row3_col0" class="data row3 col0" >Project ID</td>
#       <td id="T_a321a_row3_col1" class="data row3 col1" >6ce270de-788d-4e07-8bae-3206860a6387</td>
#     </tr>
#     <tr>
#       <td id="T_a321a_row4_col0" class="data row4 col0" >Bastion Username</td>
#       <td id="T_a321a_row4_col1" class="data row4 col1" >vsharan1_0000106410</td>
#     </tr>
#     <tr>
#       <td id="T_a321a_row5_col0" class="data row5 col0" >Bastion Private Key File</td>
#       <td id="T_a321a_row5_col1" class="data row5 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_a321a_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_a321a_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_a321a_row7_col0" class="data row7 col0" >Bastion Private Key Passphrase</td>
#       <td id="T_a321a_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_a321a_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_a321a_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_a321a_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_a321a_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_a321a_row10_col0" class="data row10 col0" >Slice Private Key Passphrase</td>
#       <td id="T_a321a_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_a321a_row11_col0" class="data row11 col0" >Log File</td>
#       <td id="T_a321a_row11_col1" class="data row11 col1" >/home/fabric/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_a321a_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_a321a_row12_col1" class="data row12 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_a321a_row13_col0" class="data row13 col0" >Version</td>
#       <td id="T_a321a_row13_col1" class="data row13 col1" >1.5.5</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Create an Experiment Slice
#
# The following creates three nodes, on different sites, with basic NICs connected to FABRIC's FABnetv4 internet. Sites can be changed, but make sure that the site is PTP-compatible.
#
# Current list of PTP-compatible sites:
#
# - STAR
# - MAX
# - MICH
# - MASS
# - UTAH
# - NCSA
# - UCSD
# - FIU
# - CLEM
# - CERN

# %%
slice_name = 'PTP_slice_All'

#[site1,site2,site3] = fablib.get_random_sites(count=2, 
#        avoid=["DALL","GPN","LBNL","RENC","SALT","TACC","UKY","WASH","NCSA","LOSA","GATECH","INDI","MAX", "MASS","NEWY","SRI","UCSD"])

sites = ["STAR", "MAX", "MICH", "MASS", "UTAH", "NCSA", "UCSD", "FIU", "CLEM", "CERN"]
node_names  =  ["STAR", "MAX", "MICH", "MASS", "UTAH", "NCSA", "UCSD", "FIU", "CLEM", "CERN"]
print(node_names, sites)
# Out:
# ['STAR', 'MAX', 'MICH', 'MASS', 'UTAH', 'NCSA', 'UCSD', 'FIU', 'CLEM', 'CERN'] ['STAR', 'MAX', 'MICH', 'MASS', 'UTAH', 'NCSA', 'UCSD', 'FIU', 'CLEM', 'CERN']

# %%
slice_name = "PTP_slice_All"

try:
    slice = fablib.get_slice(name=slice_name)
except Exception as e:
    print(f"Fail: {e}")
print (slice)
# Out:
# -----------  ------------------------------------
# Slice Name   PTP_slice_All
# Slice ID     c2c2c7fa-5edd-40e6-979e-282e204fb892
# Slice State  ModifyError
# Lease End    2023-11-19 06:01:27 +0000
# -----------  ------------------------------------

# %%
#Create Slice. add_fabnet() automatically adds an L3 interface on each node and assigns an IP address.
slice = fablib.new_slice(name=slice_name)

nodes = []
for i in range(10):
    nodes.append(slice.add_node(name=node_names[i], site=sites[i], image='docker_rocky_8'))

for node in nodes:
    node.add_fabnet()

# %%
slice.submit();
# Out:
# <style type="text/css">
# #T_ca953 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_ca953 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_ca953 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_ca953_row0_col0, #T_ca953_row0_col1, #T_ca953_row1_col0, #T_ca953_row1_col1, #T_ca953_row2_col0, #T_ca953_row2_col1, #T_ca953_row3_col0, #T_ca953_row3_col1, #T_ca953_row4_col0, #T_ca953_row4_col1, #T_ca953_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_ca953_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #ffb7b9;
# }
# </style>
# <table id="T_ca953">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ca953_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_ca953_row0_col1" class="data row0 col1" >c2c2c7fa-5edd-40e6-979e-282e204fb892</td>
#     </tr>
#     <tr>
#       <td id="T_ca953_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_ca953_row1_col1" class="data row1 col1" >PTP_slice_All</td>
#     </tr>
#     <tr>
#       <td id="T_ca953_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_ca953_row2_col1" class="data row2 col1" >2023-11-19 06:01:27 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_ca953_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_ca953_row3_col1" class="data row3 col1" >2023-11-18 06:01:27 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_ca953_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_ca953_row4_col1" class="data row4 col1" >6ce270de-788d-4e07-8bae-3206860a6387</td>
#     </tr>
#     <tr>
#       <td id="T_ca953_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_ca953_row5_col1" class="data row5 col1" >StableError</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_0a1b5 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_0a1b5 th {
#   text-align: left;
# }
# #T_0a1b5 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0a1b5 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_0a1b5 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_0a1b5_row0_col0, #T_0a1b5_row0_col1, #T_0a1b5_row0_col2, #T_0a1b5_row0_col3, #T_0a1b5_row0_col4, #T_0a1b5_row0_col5, #T_0a1b5_row0_col6, #T_0a1b5_row0_col7, #T_0a1b5_row0_col8, #T_0a1b5_row0_col9, #T_0a1b5_row0_col10, #T_0a1b5_row0_col13, #T_0a1b5_row0_col14, #T_0a1b5_row0_col15, #T_0a1b5_row1_col0, #T_0a1b5_row1_col1, #T_0a1b5_row1_col2, #T_0a1b5_row1_col3, #T_0a1b5_row1_col4, #T_0a1b5_row1_col5, #T_0a1b5_row1_col6, #T_0a1b5_row1_col7, #T_0a1b5_row1_col8, #T_0a1b5_row1_col9, #T_0a1b5_row1_col10, #T_0a1b5_row1_col13, #T_0a1b5_row1_col14, #T_0a1b5_row1_col15, #T_0a1b5_row2_col0, #T_0a1b5_row2_col1, #T_0a1b5_row2_col2, #T_0a1b5_row2_col3, #T_0a1b5_row2_col4, #T_0a1b5_row2_col5, #T_0a1b5_row2_col6, #T_0a1b5_row2_col7, #T_0a1b5_row2_col8, #T_0a1b5_row2_col9, #T_0a1b5_row2_col10, #T_0a1b5_row2_col13, #T_0a1b5_row2_col14, #T_0a1b5_row2_col15, #T_0a1b5_row3_col0, #T_0a1b5_row3_col1, #T_0a1b5_row3_col2, #T_0a1b5_row3_col3, #T_0a1b5_row3_col4, #T_0a1b5_row3_col5, #T_0a1b5_row3_col6, #T_0a1b5_row3_col7, #T_0a1b5_row3_col8, #T_0a1b5_row3_col9, #T_0a1b5_row3_col10, #T_0a1b5_row3_col13, #T_0a1b5_row3_col14, #T_0a1b5_row3_col15, #T_0a1b5_row4_col0, #T_0a1b5_row4_col1, #T_0a1b5_row4_col2, #T_0a1b5_row4_col3, #T_0a1b5_row4_col4, #T_0a1b5_row4_col5, #T_0a1b5_row4_col6, #T_0a1b5_row4_col7, #T_0a1b5_row4_col8, #T_0a1b5_row4_col9, #T_0a1b5_row4_col10, #T_0a1b5_row4_col13, #T_0a1b5_row4_col14, #T_0a1b5_row4_col15, #T_0a1b5_row5_col0, #T_0a1b5_row5_col1, #T_0a1b5_row5_col2, #T_0a1b5_row5_col3, #T_0a1b5_row5_col4, #T_0a1b5_row5_col5, #T_0a1b5_row5_col6, #T_0a1b5_row5_col7, #T_0a1b5_row5_col8, #T_0a1b5_row5_col9, #T_0a1b5_row5_col10, #T_0a1b5_row5_col13, #T_0a1b5_row5_col14, #T_0a1b5_row5_col15, #T_0a1b5_row6_col0, #T_0a1b5_row6_col1, #T_0a1b5_row6_col2, #T_0a1b5_row6_col3, #T_0a1b5_row6_col4, #T_0a1b5_row6_col5, #T_0a1b5_row6_col6, #T_0a1b5_row6_col7, #T_0a1b5_row6_col8, #T_0a1b5_row6_col9, #T_0a1b5_row6_col10, #T_0a1b5_row6_col13, #T_0a1b5_row6_col14, #T_0a1b5_row6_col15, #T_0a1b5_row7_col0, #T_0a1b5_row7_col1, #T_0a1b5_row7_col2, #T_0a1b5_row7_col3, #T_0a1b5_row7_col4, #T_0a1b5_row7_col5, #T_0a1b5_row7_col6, #T_0a1b5_row7_col7, #T_0a1b5_row7_col8, #T_0a1b5_row7_col9, #T_0a1b5_row7_col10, #T_0a1b5_row7_col13, #T_0a1b5_row7_col14, #T_0a1b5_row7_col15, #T_0a1b5_row8_col0, #T_0a1b5_row8_col1, #T_0a1b5_row8_col2, #T_0a1b5_row8_col3, #T_0a1b5_row8_col4, #T_0a1b5_row8_col5, #T_0a1b5_row8_col6, #T_0a1b5_row8_col7, #T_0a1b5_row8_col8, #T_0a1b5_row8_col9, #T_0a1b5_row8_col10, #T_0a1b5_row8_col13, #T_0a1b5_row8_col14, #T_0a1b5_row8_col15, #T_0a1b5_row9_col0, #T_0a1b5_row9_col1, #T_0a1b5_row9_col2, #T_0a1b5_row9_col3, #T_0a1b5_row9_col4, #T_0a1b5_row9_col5, #T_0a1b5_row9_col6, #T_0a1b5_row9_col7, #T_0a1b5_row9_col8, #T_0a1b5_row9_col9, #T_0a1b5_row9_col10, #T_0a1b5_row9_col13, #T_0a1b5_row9_col14, #T_0a1b5_row9_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_0a1b5_row0_col11, #T_0a1b5_row1_col11, #T_0a1b5_row2_col11, #T_0a1b5_row3_col11, #T_0a1b5_row4_col11, #T_0a1b5_row5_col11, #T_0a1b5_row6_col11, #T_0a1b5_row7_col11, #T_0a1b5_row8_col11, #T_0a1b5_row9_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_0a1b5_row0_col12, #T_0a1b5_row1_col12, #T_0a1b5_row2_col12, #T_0a1b5_row3_col12, #T_0a1b5_row4_col12, #T_0a1b5_row5_col12, #T_0a1b5_row6_col12, #T_0a1b5_row7_col12, #T_0a1b5_row8_col12, #T_0a1b5_row9_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_0a1b5">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_0a1b5_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_0a1b5_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_0a1b5_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_0a1b5_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_0a1b5_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_0a1b5_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_0a1b5_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_0a1b5_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_0a1b5_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_0a1b5_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_0a1b5_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_0a1b5_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_0a1b5_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_0a1b5_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_0a1b5_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_0a1b5_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0a1b5_row0_col0" class="data row0 col0" >a9af57bf-e4d3-4b30-8658-47649be370f4</td>
#       <td id="T_0a1b5_row0_col1" class="data row0 col1" >CERN</td>
#       <td id="T_0a1b5_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_0a1b5_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_0a1b5_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_0a1b5_row0_col5" class="data row0 col5" >docker_rocky_8</td>
#       <td id="T_0a1b5_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_0a1b5_row0_col7" class="data row0 col7" >cern-w1.fabric-testbed.net</td>
#       <td id="T_0a1b5_row0_col8" class="data row0 col8" >CERN</td>
#       <td id="T_0a1b5_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_0a1b5_row0_col10" class="data row0 col10" >2001:400:a100:3090:f816:3eff:fe54:7f7b</td>
#       <td id="T_0a1b5_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_0a1b5_row0_col12" class="data row0 col12" ></td>
#       <td id="T_0a1b5_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3090:f816:3eff:fe54:7f7b</td>
#       <td id="T_0a1b5_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_0a1b5_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_0a1b5_row1_col0" class="data row1 col0" >44a89af0-0e5c-4b0f-921c-5531854aac63</td>
#       <td id="T_0a1b5_row1_col1" class="data row1 col1" >CLEM</td>
#       <td id="T_0a1b5_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_0a1b5_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_0a1b5_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_0a1b5_row1_col5" class="data row1 col5" >docker_rocky_8</td>
#       <td id="T_0a1b5_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_0a1b5_row1_col7" class="data row1 col7" >clem-w1.fabric-testbed.net</td>
#       <td id="T_0a1b5_row1_col8" class="data row1 col8" >CLEM</td>
#       <td id="T_0a1b5_row1_col9" class="data row1 col9" >rocky</td>
#       <td id="T_0a1b5_row1_col10" class="data row1 col10" >2620:103:a006:12:f816:3eff:fed4:3565</td>
#       <td id="T_0a1b5_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_0a1b5_row1_col12" class="data row1 col12" ></td>
#       <td id="T_0a1b5_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2620:103:a006:12:f816:3eff:fed4:3565</td>
#       <td id="T_0a1b5_row1_col14" class="data
# <style type="text/css">
# #T_d5868 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_d5868 th {
#   text-align: left;
# }
# #T_d5868 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_d5868 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_d5868 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_d5868_row0_col0, #T_d5868_row0_col1, #T_d5868_row0_col2, #T_d5868_row0_col3, #T_d5868_row0_col4, #T_d5868_row0_col5, #T_d5868_row0_col6, #T_d5868_row1_col0, #T_d5868_row1_col1, #T_d5868_row1_col2, #T_d5868_row1_col3, #T_d5868_row1_col4, #T_d5868_row1_col5, #T_d5868_row1_col6, #T_d5868_row2_col0, #T_d5868_row2_col1, #T_d5868_row2_col2, #T_d5868_row2_col3, #T_d5868_row2_col4, #T_d5868_row2_col5, #T_d5868_row2_col6, #T_d5868_row3_col0, #T_d5868_row3_col1, #T_d5868_row3_col2, #T_d5868_row3_col3, #T_d5868_row3_col4, #T_d5868_row3_col5, #T_d5868_row3_col6, #T_d5868_row4_col0, #T_d5868_row4_col1, #T_d5868_row4_col2, #T_d5868_row4_col3, #T_d5868_row4_col4, #T_d5868_row4_col5, #T_d5868_row4_col6, #T_d5868_row5_col0, #T_d5868_row5_col1, #T_d5868_row5_col2, #T_d5868_row5_col3, #T_d5868_row5_col4, #T_d5868_row5_col5, #T_d5868_row5_col6, #T_d5868_row6_col0, #T_d5868_row6_col1, #T_d5868_row6_col2, #T_d5868_row6_col3, #T_d5868_row6_col4, #T_d5868_row6_col5, #T_d5868_row6_col6, #T_d5868_row7_col0, #T_d5868_row7_col1, #T_d5868_row7_col2, #T_d5868_row7_col3, #T_d5868_row7_col4, #T_d5868_row7_col5, #T_d5868_row7_col6, #T_d5868_row8_col0, #T_d5868_row8_col1, #T_d5868_row8_col2, #T_d5868_row8_col3, #T_d5868_row8_col4, #T_d5868_row8_col5, #T_d5868_row8_col6, #T_d5868_row9_col0, #T_d5868_row9_col1, #T_d5868_row9_col2, #T_d5868_row9_col3, #T_d5868_row9_col4, #T_d5868_row9_col5, #T_d5868_row9_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_d5868_row0_col7, #T_d5868_row2_col7, #T_d5868_row3_col7, #T_d5868_row4_col7, #T_d5868_row5_col7, #T_d5868_row6_col7, #T_d5868_row7_col7, #T_d5868_row9_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_d5868_row0_col8, #T_d5868_row2_col8, #T_d5868_row3_col8, #T_d5868_row4_col8, #T_d5868_row5_col8, #T_d5868_row6_col8, #T_d5868_row7_col8, #T_d5868_row8_col7, #T_d5868_row9_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_d5868_row1_col7, #T_d5868_row1_col8, #T_d5868_row8_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #ffb7b9;
# }
# </style>
# <table id="T_d5868">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_d5868_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_d5868_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_d5868_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_d5868_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_d5868_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_d5868_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_d5868_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_d5868_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_d5868_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d5868_row0_col0" class="data row0 col0" >eca967b3-2ac6-4c99-9c3a-20709547761b</td>
#       <td id="T_d5868_row0_col1" class="data row0 col1" >FABNET_IPv4_CERN</td>
#       <td id="T_d5868_row0_col2" class="data row0 col2" >L3</td>
#       <td id="T_d5868_row0_col3" class="data row0 col3" >FABNetv4</td>
#       <td id="T_d5868_row0_col4" class="data row0 col4" >CERN</td>
#       <td id="T_d5868_row0_col5" class="data row0 col5" >FABNET_IPv4_CERN.subnet</td>
#       <td id="T_d5868_row0_col6" class="data row0 col6" >FABNET_IPv4_CERN.gateway</td>
#       <td id="T_d5868_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_d5868_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_d5868_row1_col0" class="data row1 col0" >a9602627-ac96-413e-9d2f-d32535764765</td>
#       <td id="T_d5868_row1_col1" class="data row1 col1" >FABNET_IPv4_CLEM</td>
#       <td id="T_d5868_row1_col2" class="data row1 col2" >L3</td>
#       <td id="T_d5868_row1_col3" class="data row1 col3" >FABNetv4</td>
#       <td id="T_d5868_row1_col4" class="data row1 col4" >CLEM</td>
#       <td id="T_d5868_row1_col5" class="data row1 col5" >FABNET_IPv4_CLEM.subnet</td>
#       <td id="T_d5868_row1_col6" class="data row1 col6" >FABNET_IPv4_CLEM.gateway</td>
#       <td id="T_d5868_row1_col7" class="data row1 col7" >Failed</td>
#       <td id="T_d5868_row1_col8" class="data row1 col8" >failed lease update- all units failed priming: Exception during create for unit: a9602627-ac96-413e-9d2f-d32535764765 Playbook has failed tasks: NSO commit returned JSON-RPC error: type: rpc.method.failed, code: -32000, message: Method failed, data: message: Network Element Driver: device clem-data-sw: out of sync, internal: jsonrpc_tx_commit357#all units failed priming: Exception during create for unit: a9602627-ac96-413e-9d2f-d32535764765 Playbook has failed tasks: NSO commit returned JSON-RPC error: type: rpc.method.failed, code: -32000, message: Method failed, data: message: Network Element Driver: device clem-data-sw: out of sync, internal: jsonrpc_tx_commit357#</td>
#     </tr>
#     <tr>
#       <td id="T_d5868_row2_col0" class="data row2 col0" >af2e6052-892f-4400-a59b-2455d82734fb</td>
#       <td id="T_d5868_row2_col1" class="data row2 col1" >FABNET_IPv4_FIU</td>
#       <td id="T_d5868_row2_col2" class="data row2 col2" >L3</td>
#       <td id="T_d5868_row2_col3" class="data row2 col3" >FABNetv4</td>
#       <td id="T_d5868_row2_col4" class="data row2 col4" >FIU</td>
#       <td id="T_d5868_row2_col5" class="data row2 col5" >FABNET_IPv4_FIU.subnet</td>
#       <td id="T_d5868_row2_col6" class="data row2 col6" >FABNET_IPv4_FIU.gateway</td>
#       <td id="T_d5868_row2_col7" class="data row2 col7" >Active</td>
#       <td id="T_d5868_row2_col8" class="data row2 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_d5868_row3_col0" class="data row3 col0" >000dd82d-53b3-4a0c-bd3c-690022fa7bb8</td>
#       <td id="T_d5868_row3_col1" class="data row3 col1" >FABNET_IPv4_MASS</td>
#       <td id="T_d5868_row3_col2" class="data row3 col2" >L3</td>
#       <td id="T_d5868_row3_col3" class="data row3 col3" >FABNetv4</td>
#       <td id="T_d5868_row3_col4" class="data row3 col4" >MASS</td>
#       <td id="T_d5868_row3_col5" class="data row3 col5" >FABNET_IPv4_MASS.subnet</td>
#       <td id="T_d5868_row3_col6" class="data row3 col6" >FABNET_IPv4_MASS.gateway</td>
#       <td id="T_d5868_row3_col7" class="data row3 col7" >Active</td>
#       <td id="T_d5868_row3_col8" class="data row3 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_d5868_row4_col0" class="data row4 col0" >da068637-f792-461a-8b9c-a9c380804612</td>
#       <td id="T_d5868_row4_col1" class="data row4 col1" >FABNET_IPv4_MAX</td>
#       <td id="T_d5868_row4_col2" class="data row4 col2" >L3</td>
#       <td id="T_d5868_row4_col3" class="data row4 col3" >FABNetv4</td>
#       <td id="T_d5868_row4_col4" class="data row4 col4" >MAX</td>
#       <td id="T_d5868_row4_col5" class="data row4 col5" >FABNET_IPv4_MAX.subnet</td>
#       <td id="T_d5868_row4_col6" class="data row4 col6" >FABNET_IPv4_MAX.gateway</td>
#       <td id="T_d5868_row4_col7" class="data row4 col7" >Active</td>
#       <td id="T_d5868_row4_col8" class="data row4 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_d5868_row5_col0" class="data row5 col0" >71b81cfb-15c1-4c9d-b267-65127e3f9944</td>
#       <td id="T_d5868_row5_col1" class="data row5 col1" >FABNET_IPv4_MICH</td>
#       <td id="T_d5868_row5_col2" class="data row5 col2" >L3</td>
#       <td id="T_d5868_row5_col3" class="data row5 col3" >FABNetv4</td>
#       <td id="T_d5868_row5_col4" class="data row5 col4" >MICH</td>
# Time to stable 464 seconds
# Running post_boot_config ...
# Running post boot config threads ...
# Post boot config FIU, Done! (12 sec)
# Post boot config MASS, Done! (12 sec)
# Post boot config UTAH, Done! (12 sec)
# Post boot config MICH, Done! (13 sec)
# Post boot config CLEM, Done! (13 sec)
# Post boot config UCSD, Done! (13 sec)
# Post boot config NCSA, Done! (13 sec)
# Post boot config MAX, Done! (13 sec)
# Post boot config STAR, Done! (14 sec)
# Post boot config CERN, Done! (16 sec)
# Saving fablib data...

# %% [markdown]
# ## (Optional) Observe the Slice's Attributes

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    slice.show()
    slice.list_nodes()
    slice.list_networks()
    slice.list_interfaces()
except Exception as e:
    print(f"Exception: {e}")
# Out:
# <style type="text/css">
# #T_e5e5b tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_e5e5b tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e5e5b caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_e5e5b_row0_col0, #T_e5e5b_row0_col1, #T_e5e5b_row1_col0, #T_e5e5b_row1_col1, #T_e5e5b_row2_col0, #T_e5e5b_row2_col1, #T_e5e5b_row3_col0, #T_e5e5b_row3_col1, #T_e5e5b_row4_col0, #T_e5e5b_row4_col1, #T_e5e5b_row5_col0, #T_e5e5b_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_e5e5b">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e5e5b_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_e5e5b_row0_col1" class="data row0 col1" >c2c2c7fa-5edd-40e6-979e-282e204fb892</td>
#     </tr>
#     <tr>
#       <td id="T_e5e5b_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_e5e5b_row1_col1" class="data row1 col1" >PTP_slice_All</td>
#     </tr>
#     <tr>
#       <td id="T_e5e5b_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_e5e5b_row2_col1" class="data row2 col1" >2023-11-19 06:01:27 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_e5e5b_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_e5e5b_row3_col1" class="data row3 col1" >2023-11-18 06:01:27 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_e5e5b_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_e5e5b_row4_col1" class="data row4 col1" >6ce270de-788d-4e07-8bae-3206860a6387</td>
#     </tr>
#     <tr>
#       <td id="T_e5e5b_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_e5e5b_row5_col1" class="data row5 col1" >ModifyError</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_88bcb caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_88bcb th {
#   text-align: left;
# }
# #T_88bcb tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_88bcb tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_88bcb .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_88bcb_row0_col0, #T_88bcb_row0_col1, #T_88bcb_row0_col2, #T_88bcb_row0_col3, #T_88bcb_row0_col4, #T_88bcb_row0_col5, #T_88bcb_row0_col6, #T_88bcb_row0_col7, #T_88bcb_row0_col8, #T_88bcb_row0_col9, #T_88bcb_row0_col10, #T_88bcb_row0_col11, #T_88bcb_row0_col12, #T_88bcb_row0_col13, #T_88bcb_row0_col14, #T_88bcb_row0_col15, #T_88bcb_row1_col0, #T_88bcb_row1_col1, #T_88bcb_row1_col2, #T_88bcb_row1_col3, #T_88bcb_row1_col4, #T_88bcb_row1_col5, #T_88bcb_row1_col6, #T_88bcb_row1_col7, #T_88bcb_row1_col8, #T_88bcb_row1_col9, #T_88bcb_row1_col10, #T_88bcb_row1_col11, #T_88bcb_row1_col12, #T_88bcb_row1_col13, #T_88bcb_row1_col14, #T_88bcb_row1_col15, #T_88bcb_row2_col0, #T_88bcb_row2_col1, #T_88bcb_row2_col2, #T_88bcb_row2_col3, #T_88bcb_row2_col4, #T_88bcb_row2_col5, #T_88bcb_row2_col6, #T_88bcb_row2_col7, #T_88bcb_row2_col8, #T_88bcb_row2_col9, #T_88bcb_row2_col10, #T_88bcb_row2_col11, #T_88bcb_row2_col12, #T_88bcb_row2_col13, #T_88bcb_row2_col14, #T_88bcb_row2_col15, #T_88bcb_row3_col0, #T_88bcb_row3_col1, #T_88bcb_row3_col2, #T_88bcb_row3_col3, #T_88bcb_row3_col4, #T_88bcb_row3_col5, #T_88bcb_row3_col6, #T_88bcb_row3_col7, #T_88bcb_row3_col8, #T_88bcb_row3_col9, #T_88bcb_row3_col10, #T_88bcb_row3_col11, #T_88bcb_row3_col12, #T_88bcb_row3_col13, #T_88bcb_row3_col14, #T_88bcb_row3_col15, #T_88bcb_row4_col0, #T_88bcb_row4_col1, #T_88bcb_row4_col2, #T_88bcb_row4_col3, #T_88bcb_row4_col4, #T_88bcb_row4_col5, #T_88bcb_row4_col6, #T_88bcb_row4_col7, #T_88bcb_row4_col8, #T_88bcb_row4_col9, #T_88bcb_row4_col10, #T_88bcb_row4_col11, #T_88bcb_row4_col12, #T_88bcb_row4_col13, #T_88bcb_row4_col14, #T_88bcb_row4_col15, #T_88bcb_row5_col0, #T_88bcb_row5_col1, #T_88bcb_row5_col2, #T_88bcb_row5_col3, #T_88bcb_row5_col4, #T_88bcb_row5_col5, #T_88bcb_row5_col6, #T_88bcb_row5_col7, #T_88bcb_row5_col8, #T_88bcb_row5_col9, #T_88bcb_row5_col10, #T_88bcb_row5_col11, #T_88bcb_row5_col12, #T_88bcb_row5_col13, #T_88bcb_row5_col14, #T_88bcb_row5_col15, #T_88bcb_row6_col0, #T_88bcb_row6_col1, #T_88bcb_row6_col2, #T_88bcb_row6_col3, #T_88bcb_row6_col4, #T_88bcb_row6_col5, #T_88bcb_row6_col6, #T_88bcb_row6_col7, #T_88bcb_row6_col8, #T_88bcb_row6_col9, #T_88bcb_row6_col10, #T_88bcb_row6_col11, #T_88bcb_row6_col12, #T_88bcb_row6_col13, #T_88bcb_row6_col14, #T_88bcb_row6_col15, #T_88bcb_row7_col0, #T_88bcb_row7_col1, #T_88bcb_row7_col2, #T_88bcb_row7_col3, #T_88bcb_row7_col4, #T_88bcb_row7_col5, #T_88bcb_row7_col6, #T_88bcb_row7_col7, #T_88bcb_row7_col8, #T_88bcb_row7_col9, #T_88bcb_row7_col10, #T_88bcb_row7_col11, #T_88bcb_row7_col12, #T_88bcb_row7_col13, #T_88bcb_row7_col14, #T_88bcb_row7_col15, #T_88bcb_row8_col0, #T_88bcb_row8_col1, #T_88bcb_row8_col2, #T_88bcb_row8_col3, #T_88bcb_row8_col4, #T_88bcb_row8_col5, #T_88bcb_row8_col6, #T_88bcb_row8_col7, #T_88bcb_row8_col8, #T_88bcb_row8_col9, #T_88bcb_row8_col10, #T_88bcb_row8_col11, #T_88bcb_row8_col12, #T_88bcb_row8_col13, #T_88bcb_row8_col14, #T_88bcb_row8_col15, #T_88bcb_row9_col0, #T_88bcb_row9_col1, #T_88bcb_row9_col2, #T_88bcb_row9_col3, #T_88bcb_row9_col4, #T_88bcb_row9_col5, #T_88bcb_row9_col6, #T_88bcb_row9_col7, #T_88bcb_row9_col8, #T_88bcb_row9_col9, #T_88bcb_row9_col10, #T_88bcb_row9_col11, #T_88bcb_row9_col12, #T_88bcb_row9_col13, #T_88bcb_row9_col14, #T_88bcb_row9_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_88bcb">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_88bcb_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_88bcb_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_88bcb_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_88bcb_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_88bcb_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_88bcb_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_88bcb_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_88bcb_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_88bcb_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_88bcb_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_88bcb_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_88bcb_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_88bcb_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_88bcb_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_88bcb_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_88bcb_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_88bcb_row0_col0" class="data row0 col0" >a9af57bf-e4d3-4b30-8658-47649be370f4</td>
#       <td id="T_88bcb_row0_col1" class="data row0 col1" >CERN</td>
#       <td id="T_88bcb_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_88bcb_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_88bcb_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_88bcb_row0_col5" class="data row0 col5" >docker_rocky_8</td>
#       <td id="T_88bcb_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_88bcb_row0_col7" class="data row0 col7" >cern-w1.fabric-testbed.net</td>
#       <td id="T_88bcb_row0_col8" class="data row0 col8" >CERN</td>
#       <td id="T_88bcb_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_88bcb_row0_col10" class="data row0 col10" >2001:400:a100:3090:f816:3eff:fe54:7f7b</td>
#       <td id="T_88bcb_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_88bcb_row0_col12" class="data row0 col12" ></td>
#       <td id="T_88bcb_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2001:400:a100:3090:f816:3eff:fe54:7f7b</td>
#       <td id="T_88bcb_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_88bcb_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_88bcb_row1_col0" class="data row1 col0" >44a89af0-0e5c-4b0f-921c-5531854aac63</td>
#       <td id="T_88bcb_row1_col1" class="data row1 col1" >CLEM</td>
#       <td id="T_88bcb_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_88bcb_row1_col3" class="data row1 col3" >8</td>
#       <td id="T_88bcb_row1_col4" class="data row1 col4" >10</td>
#       <td id="T_88bcb_row1_col5" class="data row1 col5" >docker_rocky_8</td>
#       <td id="T_88bcb_row1_col6" class="data row1 col6" >qcow2</td>
#       <td id="T_88bcb_row1_col7" class="data row1 col7" >clem-w1.fabric-testbed.net</td>
#       <td id="T_88bcb_row1_col8" class="data row1 col8" >CLEM</td>
#       <td id="T_88bcb_row1_col9" class="data row1 col9" >rocky</td>
#       <td id="T_88bcb_row1_col10" class="data row1 col10" >2620:103:a006:12:f816:3eff:fed4:3565</td>
#       <td id="T_88bcb_row1_col11" class="data row1 col11" >Active</td>
#       <td id="T_88bcb_row1_col12" class="data row1 col12" ></td>
#       <td id="T_88bcb_row1_col13" class="data row1 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@2620:103:a006:12:f816:3eff:fed4:3565</td>
#       <td id="T_88bcb_row1_col14" class="data row1 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_88bcb_row1_col15" class="data row1 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_88bcb_row2_
# <style type="text/css">
# #T_081d2 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_081d2 th {
#   text-align: left;
# }
# #T_081d2 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_081d2 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_081d2 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_081d2_row0_col0, #T_081d2_row0_col1, #T_081d2_row0_col2, #T_081d2_row0_col3, #T_081d2_row0_col4, #T_081d2_row0_col5, #T_081d2_row0_col6, #T_081d2_row0_col7, #T_081d2_row0_col8, #T_081d2_row1_col0, #T_081d2_row1_col1, #T_081d2_row1_col2, #T_081d2_row1_col3, #T_081d2_row1_col4, #T_081d2_row1_col5, #T_081d2_row1_col6, #T_081d2_row1_col7, #T_081d2_row1_col8, #T_081d2_row2_col0, #T_081d2_row2_col1, #T_081d2_row2_col2, #T_081d2_row2_col3, #T_081d2_row2_col4, #T_081d2_row2_col5, #T_081d2_row2_col6, #T_081d2_row2_col7, #T_081d2_row2_col8, #T_081d2_row3_col0, #T_081d2_row3_col1, #T_081d2_row3_col2, #T_081d2_row3_col3, #T_081d2_row3_col4, #T_081d2_row3_col5, #T_081d2_row3_col6, #T_081d2_row3_col7, #T_081d2_row3_col8, #T_081d2_row4_col0, #T_081d2_row4_col1, #T_081d2_row4_col2, #T_081d2_row4_col3, #T_081d2_row4_col4, #T_081d2_row4_col5, #T_081d2_row4_col6, #T_081d2_row4_col7, #T_081d2_row4_col8, #T_081d2_row5_col0, #T_081d2_row5_col1, #T_081d2_row5_col2, #T_081d2_row5_col3, #T_081d2_row5_col4, #T_081d2_row5_col5, #T_081d2_row5_col6, #T_081d2_row5_col7, #T_081d2_row5_col8, #T_081d2_row6_col0, #T_081d2_row6_col1, #T_081d2_row6_col2, #T_081d2_row6_col3, #T_081d2_row6_col4, #T_081d2_row6_col5, #T_081d2_row6_col6, #T_081d2_row6_col7, #T_081d2_row6_col8, #T_081d2_row7_col0, #T_081d2_row7_col1, #T_081d2_row7_col2, #T_081d2_row7_col3, #T_081d2_row7_col4, #T_081d2_row7_col5, #T_081d2_row7_col6, #T_081d2_row7_col7, #T_081d2_row7_col8, #T_081d2_row8_col0, #T_081d2_row8_col1, #T_081d2_row8_col2, #T_081d2_row8_col3, #T_081d2_row8_col4, #T_081d2_row8_col5, #T_081d2_row8_col6, #T_081d2_row8_col7, #T_081d2_row8_col8, #T_081d2_row9_col0, #T_081d2_row9_col1, #T_081d2_row9_col2, #T_081d2_row9_col3, #T_081d2_row9_col4, #T_081d2_row9_col5, #T_081d2_row9_col6, #T_081d2_row9_col7, #T_081d2_row9_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_081d2">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_081d2_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_081d2_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_081d2_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_081d2_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_081d2_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_081d2_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_081d2_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_081d2_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_081d2_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_081d2_row0_col0" class="data row0 col0" >eca967b3-2ac6-4c99-9c3a-20709547761b</td>
#       <td id="T_081d2_row0_col1" class="data row0 col1" >FABNET_IPv4_CERN</td>
#       <td id="T_081d2_row0_col2" class="data row0 col2" >L3</td>
#       <td id="T_081d2_row0_col3" class="data row0 col3" >FABNetv4</td>
#       <td id="T_081d2_row0_col4" class="data row0 col4" >CERN</td>
#       <td id="T_081d2_row0_col5" class="data row0 col5" >10.143.2.0/24</td>
#       <td id="T_081d2_row0_col6" class="data row0 col6" >10.143.2.1</td>
#       <td id="T_081d2_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_081d2_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_081d2_row1_col0" class="data row1 col0" >a9602627-ac96-413e-9d2f-d32535764765</td>
#       <td id="T_081d2_row1_col1" class="data row1 col1" >FABNET_IPv4_CLEM</td>
#       <td id="T_081d2_row1_col2" class="data row1 col2" >L3</td>
#       <td id="T_081d2_row1_col3" class="data row1 col3" >FABNetv4</td>
#       <td id="T_081d2_row1_col4" class="data row1 col4" >CLEM</td>
#       <td id="T_081d2_row1_col5" class="data row1 col5" >10.136.2.0/24</td>
#       <td id="T_081d2_row1_col6" class="data row1 col6" >10.136.2.1</td>
#       <td id="T_081d2_row1_col7" class="data row1 col7" >Failed</td>
#       <td id="T_081d2_row1_col8" class="data row1 col8" >failed lease update- all units failed priming: Exception during create for unit: a9602627-ac96-413e-9d2f-d32535764765 Playbook has failed tasks: NSO commit returned JSON-RPC error: type: rpc.method.failed, code: -32000, message: Method failed, data: message: Network Element Driver: device clem-data-sw: out of sync, internal: jsonrpc_tx_commit357#all units failed priming: Exception during create for unit: a9602627-ac96-413e-9d2f-d32535764765 Playbook has failed tasks: NSO commit returned JSON-RPC error: type: rpc.method.failed, code: -32000, message: Method failed, data: message: Network Element Driver: device clem-data-sw: out of sync, internal: jsonrpc_tx_commit357#</td>
#     </tr>
#     <tr>
#       <td id="T_081d2_row2_col0" class="data row2 col0" >af2e6052-892f-4400-a59b-2455d82734fb</td>
#       <td id="T_081d2_row2_col1" class="data row2 col1" >FABNET_IPv4_FIU</td>
#       <td id="T_081d2_row2_col2" class="data row2 col2" >L3</td>
#       <td id="T_081d2_row2_col3" class="data row2 col3" >FABNetv4</td>
#       <td id="T_081d2_row2_col4" class="data row2 col4" >FIU</td>
#       <td id="T_081d2_row2_col5" class="data row2 col5" >10.135.133.0/24</td>
#       <td id="T_081d2_row2_col6" class="data row2 col6" >10.135.133.1</td>
#       <td id="T_081d2_row2_col7" class="data row2 col7" >Active</td>
#       <td id="T_081d2_row2_col8" class="data row2 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_081d2_row3_col0" class="data row3 col0" >000dd82d-53b3-4a0c-bd3c-690022fa7bb8</td>
#       <td id="T_081d2_row3_col1" class="data row3 col1" >FABNET_IPv4_MASS</td>
#       <td id="T_081d2_row3_col2" class="data row3 col2" >L3</td>
#       <td id="T_081d2_row3_col3" class="data row3 col3" >FABNetv4</td>
#       <td id="T_081d2_row3_col4" class="data row3 col4" >MASS</td>
#       <td id="T_081d2_row3_col5" class="data row3 col5" >10.131.132.0/24</td>
#       <td id="T_081d2_row3_col6" class="data row3 col6" >10.131.132.1</td>
#       <td id="T_081d2_row3_col7" class="data row3 col7" >Active</td>
#       <td id="T_081d2_row3_col8" class="data row3 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_081d2_row4_col0" class="data row4 col0" >da068637-f792-461a-8b9c-a9c380804612</td>
#       <td id="T_081d2_row4_col1" class="data row4 col1" >FABNET_IPv4_MAX</td>
#       <td id="T_081d2_row4_col2" class="data row4 col2" >L3</td>
#       <td id="T_081d2_row4_col3" class="data row4 col3" >FABNetv4</td>
#       <td id="T_081d2_row4_col4" class="data row4 col4" >MAX</td>
#       <td id="T_081d2_row4_col5" class="data row4 col5" >10.130.7.0/24</td>
#       <td id="T_081d2_row4_col6" class="data row4 col6" >10.130.7.1</td>
#       <td id="T_081d2_row4_col7" class="data row4 col7" >Active</td>
#       <td id="T_081d2_row4_col8" class="data row4 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_081d2_row5_col0" class="data row5 col0" >71b81cfb-15c1-4c9d-b267-65127e3f9944</td>
#       <td id="T_081d2_row5_col1" class="data row5 col1" >FABNET_IPv4_MICH</td>
#       <td id="T_081d2_row5_col2" class="data row5 col2" >L3</td>
#       <td id="T_081d2_row5_col3" class="data row5 col3" >FABNetv4</td>
#       <td id="T_081d2_row5_col4" class="data row5 col4" >MICH</td>
#       <td id="T_081d2_row5_col5" class="data row5 col5" >10.131.3.0/24</td>
#       <td id="T_081d2_row5_col6" class="data row5 col6" >10.131.3.1</td>
#       <td id="T_081d2_row5_col7" class="data row5 col7" >Active</td>
#       <td id="T_081d2_row5_col8" class="data row5 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_081d2_row6_col0" class="data row6 col0" >92fa8ea7-6ad0-4c47-bdb2-5e58b32ac8dc</td>
#       <td id="T_081d2_row6_col1" class
# <style type="text/css">
# #T_e360a caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_e360a th {
#   text-align: left;
# }
# #T_e360a tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e360a tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_e360a .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_e360a_row0_col0, #T_e360a_row0_col1, #T_e360a_row0_col2, #T_e360a_row0_col3, #T_e360a_row0_col4, #T_e360a_row0_col5, #T_e360a_row0_col6, #T_e360a_row0_col7, #T_e360a_row0_col8, #T_e360a_row0_col9, #T_e360a_row0_col10, #T_e360a_row0_col11, #T_e360a_row1_col0, #T_e360a_row1_col1, #T_e360a_row1_col2, #T_e360a_row1_col3, #T_e360a_row1_col4, #T_e360a_row1_col5, #T_e360a_row1_col6, #T_e360a_row1_col7, #T_e360a_row1_col8, #T_e360a_row1_col9, #T_e360a_row1_col10, #T_e360a_row1_col11, #T_e360a_row2_col0, #T_e360a_row2_col1, #T_e360a_row2_col2, #T_e360a_row2_col3, #T_e360a_row2_col4, #T_e360a_row2_col5, #T_e360a_row2_col6, #T_e360a_row2_col7, #T_e360a_row2_col8, #T_e360a_row2_col9, #T_e360a_row2_col10, #T_e360a_row2_col11, #T_e360a_row3_col0, #T_e360a_row3_col1, #T_e360a_row3_col2, #T_e360a_row3_col3, #T_e360a_row3_col4, #T_e360a_row3_col5, #T_e360a_row3_col6, #T_e360a_row3_col7, #T_e360a_row3_col8, #T_e360a_row3_col9, #T_e360a_row3_col10, #T_e360a_row3_col11, #T_e360a_row4_col0, #T_e360a_row4_col1, #T_e360a_row4_col2, #T_e360a_row4_col3, #T_e360a_row4_col4, #T_e360a_row4_col5, #T_e360a_row4_col6, #T_e360a_row4_col7, #T_e360a_row4_col8, #T_e360a_row4_col9, #T_e360a_row4_col10, #T_e360a_row4_col11, #T_e360a_row5_col0, #T_e360a_row5_col1, #T_e360a_row5_col2, #T_e360a_row5_col3, #T_e360a_row5_col4, #T_e360a_row5_col5, #T_e360a_row5_col6, #T_e360a_row5_col7, #T_e360a_row5_col8, #T_e360a_row5_col9, #T_e360a_row5_col10, #T_e360a_row5_col11, #T_e360a_row6_col0, #T_e360a_row6_col1, #T_e360a_row6_col2, #T_e360a_row6_col3, #T_e360a_row6_col4, #T_e360a_row6_col5, #T_e360a_row6_col6, #T_e360a_row6_col7, #T_e360a_row6_col8, #T_e360a_row6_col9, #T_e360a_row6_col10, #T_e360a_row6_col11, #T_e360a_row7_col0, #T_e360a_row7_col1, #T_e360a_row7_col2, #T_e360a_row7_col3, #T_e360a_row7_col4, #T_e360a_row7_col5, #T_e360a_row7_col6, #T_e360a_row7_col7, #T_e360a_row7_col8, #T_e360a_row7_col9, #T_e360a_row7_col10, #T_e360a_row7_col11, #T_e360a_row8_col0, #T_e360a_row8_col1, #T_e360a_row8_col2, #T_e360a_row8_col3, #T_e360a_row8_col4, #T_e360a_row8_col5, #T_e360a_row8_col6, #T_e360a_row8_col7, #T_e360a_row8_col8, #T_e360a_row8_col9, #T_e360a_row8_col10, #T_e360a_row8_col11, #T_e360a_row9_col0, #T_e360a_row9_col1, #T_e360a_row9_col2, #T_e360a_row9_col3, #T_e360a_row9_col4, #T_e360a_row9_col5, #T_e360a_row9_col6, #T_e360a_row9_col7, #T_e360a_row9_col8, #T_e360a_row9_col9, #T_e360a_row9_col10, #T_e360a_row9_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_e360a">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_e360a_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_e360a_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_e360a_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_e360a_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_e360a_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_e360a_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_e360a_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_e360a_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_e360a_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_e360a_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_e360a_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_e360a_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e360a_row0_col0" class="data row0 col0" >STAR-FABNET_IPv4_STAR_nic-p1</td>
#       <td id="T_e360a_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_e360a_row0_col2" class="data row0 col2" >STAR</td>
#       <td id="T_e360a_row0_col3" class="data row0 col3" >FABNET_IPv4_STAR</td>
#       <td id="T_e360a_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_e360a_row0_col5" class="data row0 col5" >auto</td>
#       <td id="T_e360a_row0_col6" class="data row0 col6" ></td>
#       <td id="T_e360a_row0_col7" class="data row0 col7" >4E:10:D1:27:F2:48</td>
#       <td id="T_e360a_row0_col8" class="data row0 col8" >enp7s0</td>
#       <td id="T_e360a_row0_col9" class="data row0 col9" >enp7s0</td>
#       <td id="T_e360a_row0_col10" class="data row0 col10" >10.129.129.2</td>
#       <td id="T_e360a_row0_col11" class="data row0 col11" >6</td>
#     </tr>
#     <tr>
#       <td id="T_e360a_row1_col0" class="data row1 col0" >MAX-FABNET_IPv4_MAX_nic-p1</td>
#       <td id="T_e360a_row1_col1" class="data row1 col1" >p1</td>
#       <td id="T_e360a_row1_col2" class="data row1 col2" >MAX</td>
#       <td id="T_e360a_row1_col3" class="data row1 col3" >FABNET_IPv4_MAX</td>
#       <td id="T_e360a_row1_col4" class="data row1 col4" >100</td>
#       <td id="T_e360a_row1_col5" class="data row1 col5" >auto</td>
#       <td id="T_e360a_row1_col6" class="data row1 col6" ></td>
#       <td id="T_e360a_row1_col7" class="data row1 col7" >06:3B:31:3D:E8:28</td>
#       <td id="T_e360a_row1_col8" class="data row1 col8" >enp7s0</td>
#       <td id="T_e360a_row1_col9" class="data row1 col9" >enp7s0</td>
#       <td id="T_e360a_row1_col10" class="data row1 col10" >10.130.7.2</td>
#       <td id="T_e360a_row1_col11" class="data row1 col11" >4</td>
#     </tr>
#     <tr>
#       <td id="T_e360a_row2_col0" class="data row2 col0" >MICH-FABNET_IPv4_MICH_nic-p1</td>
#       <td id="T_e360a_row2_col1" class="data row2 col1" >p1</td>
#       <td id="T_e360a_row2_col2" class="data row2 col2" >MICH</td>
#       <td id="T_e360a_row2_col3" class="data row2 col3" >FABNET_IPv4_MICH</td>
#       <td id="T_e360a_row2_col4" class="data row2 col4" >100</td>
#       <td id="T_e360a_row2_col5" class="data row2 col5" >auto</td>
#       <td id="T_e360a_row2_col6" class="data row2 col6" ></td>
#       <td id="T_e360a_row2_col7" class="data row2 col7" >22:45:42:BC:5D:36</td>
#       <td id="T_e360a_row2_col8" class="data row2 col8" >enp7s0</td>
#       <td id="T_e360a_row2_col9" class="data row2 col9" >enp7s0</td>
#       <td id="T_e360a_row2_col10" class="data row2 col10" >10.131.3.2</td>
#       <td id="T_e360a_row2_col11" class="data row2 col11" >6</td>
#     </tr>
#     <tr>
#       <td id="T_e360a_row3_col0" class="data row3 col0" >MASS-FABNET_IPv4_MASS_nic-p1</td>
#       <td id="T_e360a_row3_col1" class="data row3 col1" >p1</td>
#       <td id="T_e360a_row3_col2" class="data row3 col2" >MASS</td>
#       <td id="T_e360a_row3_col3" class="data row3 col3" >FABNET_IPv4_MASS</td>
#       <td id="T_e360a_row3_col4" class="data row3 col4" >100</td>
#       <td id="T_e360a_row3_col5" class="data row3 col5" >auto</td>
#       <td id="T_e360a_row3_col6" class="data row3 col6" ></td>
#       <td id="T_e360a_row3_col7" class="data row3 col7" >06:51:15:6C:19:23</td>
#       <td id="T_e360a_row3_col8" class="data row3 col8" >enp7s0</td>
#       <td id="T_e360a_row3_col9" class="data row3 col9" >enp7s0</td>
#       <td id="T_e360a_row3_col10" class="data row3 col10" >10.131.132.2</td>
#       <td id="T_e360a_row3_col11" class="data row3 col11" >4</td>
#     </tr>
#     <tr>
#       <td id="T_e360a_row4_col0" class="data row4 col0" >UTAH-FABNET_IPv4_UTAH_nic-p1</td>
#       <td id="T_e360a_row4_col1" class="data row4 col1" >p1</td>
#       <td id="T_e360a_row4_col2" class="data row4 col2" >UTAH</td>
#       <td id="T_e360a_row4_col3" class="data row4 col3" >FABNET_IPv4_UTAH</td>
#       <td id="T_e360a_row4_col4" class="data row4 col4" >100</td>
#       <td id="T_e360a_row4_col5" class="data row4 col5" >auto</td>
#       <td id="T_e360a_row4_col6" class="data row4 col6" ></td>
#       <td

# %% [markdown]
# <!-- ## Configure IP Addresses
#
# ### Get the Assigned Subnet
#
# FABnetv4 networks are assigned a subnet and gateway by FABRIC.  You can get the subnet and available IPs from the FABlib objects.  -->

# %% [markdown]
# ## Check connectivity via Experimenter's network

# %%
try:
    nodes[0] = slice.get_node(name=node_names[0])   
    nodes[2] = slice.get_node(name=node_names[2])
    node3_addr = nodes[2].get_interface(network_name=f'FABNET_IPv4_{nodes[2].get_site()}').get_ip_addr()
    
    nodes[0].execute('hostname')
    stdout, stderr = nodes[0].execute(f'ping -c 5 {node3_addr}')  
    
except Exception as e:
    print(f"Exception: {e}")
# Out:
# STAR
# PING 10.131.3.2 (10.131.3.2) 56(84) bytes of data.
# 64 bytes from 10.131.3.2: icmp_seq=1 ttl=62 time=7.21 ms
# 64 bytes from 10.131.3.2: icmp_seq=2 ttl=62 time=5.28 ms
# 64 bytes from 10.131.3.2: icmp_seq=3 ttl=62 time=5.29 ms
# 64 bytes from 10.131.3.2: icmp_seq=4 ttl=62 time=5.29 ms
# 64 bytes from 10.131.3.2: icmp_seq=5 ttl=62 time=5.28 ms
#
# --- 10.131.3.2 ping statistics ---
# 5 packets transmitted, 5 received, 0% packet loss, time 4005ms
# rtt min/avg/max/mdev = 5.277/5.667/7.206/0.769 ms

# %% [markdown]
# # Prepare each node for time precision experiments

# %%
nodes = slice.get_nodes()

# %% [markdown]
# ## Enable NAT64

# %% [markdown]
# ### Upload and Execute the NAT64 Script
#
# We will use a NAT64 script, which configures an *IPv6* node so that it can access non-*IPv6* services. To view the script, click [here](./nat64.sh). This script sets up the [Public NAT64 Service](https://nat64.net) on your node.
#
# For more details on how uploading and executing scripts works on FABRIC, click [here](../upload_and_execute/upload_and_execute.ipynb).
#
# Based on https://nat64.net/
# Note that NAT64 could go away at any minute, as it is a public service ran independently by Kasper Dupont, and is not affiliated with FABRIC.

# %%
# Change this to all nodes

from ipaddress import ip_address, IPv6Address

for node in nodes:
    try:     
        # If the node is an IPv6 Node then configure NAT64
        if node.validIPAddress(node.get_management_ip()) == "IPv6":
            # needed to fix sudo unable to resolve error
            commands = """
            sudo echo -n "127.0.0.1 " | sudo cat - /etc/hostname  | sudo tee -a /etc/hosts;
            sudo echo -n "2a01:4f9:c010:3f02:64:0:8c52:7103       github.com\n"|sudo tee -a /etc/hosts;
            sudo echo -n "2a01:4f9:c010:3f02:64:0:8c52:7009       codeload.github.com\n"|sudo tee -a /etc/hosts;
            sudo echo -n "2a01:4f9:c010:3f02:64:0:b9c7:6e85       objects.githubusercontent.com\n"|sudo tee -a /etc/hosts;
            sudo echo -n "2600:1fa0:80b4:db49:34d9:6d1e::         ansible-galaxy.s3.amazonaws.com\n"|sudo tee -a /etc/hosts;
            sudo echo -n "2a01:4f9:c010:3f02:64:0:3455:9777       packages.confluent.io\n"|sudo tee -a /etc/hosts;
            """
            stdout, stderr = node.execute(commands, quiet=True)

        # Access non-IPv6 Services
        stdout, stderr = node.execute(f'sudo yum install -y -q git && git clone https://github.com/fabric-testbed/jupyter-examples.git')

        stdout, stderr = node.execute(f'ls jupyter-examples')

    except Exception as e:
        print(f"Exception: {e}")
# Out:
#  Cloning into 'jupyter-examples'...
#  Changelog.md
# configure.ipynb
# docker_containers
# fabric_examples
# fabric_ssh_tunnel_tools
# LICENSE
# Readme.md
# requirements.txt
# start_here.ipynb
#  Cloning into 'jupyter-examples'...
#  Changelog.md
# configure.ipynb
# docker_containers
# fabric_examples
# fabric_ssh_tunnel_tools
# LICENSE
# Readme.md
# requirements.txt
# start_here.ipynb
#  Cloning into 'jupyter-examples'...
#  Changelog.md
# configure.ipynb
# docker_containers
# fabric_examples
# fabric_ssh_tunnel_tools
# LICENSE
# Readme.md
# requirements.txt
# start_here.ipynb
#  Cloning into 'jupyter-examples'...
#  Changelog.md
# configure.ipynb
# docker_containers
# fabric_examples
# fabric_ssh_tunnel_tools
# LICENSE
# Readme.md
# requirements.txt
# start_here.ipynb
#  Cloning into 'jupyter-examples'...
#  Changelog.md
# configure.ipynb
# docker_containers
# fabric_examples
# fabric_ssh_tunnel_tools
# LICENSE
# Readme.md
# requirements.txt
# start_here.ipynb
#  Cloning into 'jupyter-examples'...
#  Changelog.md
# configure.ipynb
# docker_containers
# fabric_examples
# fabric_ssh_tunnel_tools
# LICENSE
# Readme.md
# requirements.txt
# start_here.ipynb
#
# Upgraded:
#   git-2.39.3-1.el8_8.x86_64                git-core-2.39.3-1.el8_8.x86_64
#   git-core-doc-2.39.3-1.el8_8.noarch       perl-Git-2.39.3-1.el8_8.noarch
#
#  Failed to set locale, defaulting to C.UTF-8
#   Cloning into 'jupyter-examples'...
#  Changelog.md
# LICENSE
# Readme.md
# configure.ipynb
# docker_containers
# fabric_examples
# fabric_ssh_tunnel_tools
# requirements.txt
# start_here.ipynb
#
# Upgraded:
#   git-2.39.3-1.el8_8.x86_64                git-core-2.39.3-1.el8_8.x86_64
#   git-core-doc-2.39.3-1.el8_8.noarch       perl-Git-2.39.3-1.el8_8.noarch
#
#  Failed to set locale, defaulting to C.UTF-8
#   Cloning into 'jupyter-examples'...
#  Changelog.md
# LICENSE
# Readme.md
# configure.ipynb
# docker_containers
# fabric_examples
# fabric_ssh_tunnel_tools
# requirements.txt
# start_here.ipynb
#
# Upgraded:
#   git-2.39.3-1.el8_8.x86_64                git-core-2.39.3-1.el8_8.x86_64
#   git-core-doc-2.39.3-1.el8_8.noarch       perl-Git-2.39.3-1.el8_8.noarch
#
#  Failed to set locale, defaulting to C.UTF-8
#   Cloning into 'jupyter-examples'...
#  Changelog.md
# LICENSE
# Readme.md
# configure.ipynb
# docker_containers
# fabric_examples
# fabric_ssh_tunnel_tools
# requirements.txt
# start_here.ipynb
#
# Upgraded:
#   git-2.39.3-1.el8_8.x86_64                git-core-2.39.3-1.el8_8.x86_64
#   git-core-doc-2.39.3-1.el8_8.noarch       perl-Git-2.39.3-1.el8_8.noarch
#
#  Failed to set locale, defaulting to C.UTF-8
#   Cloning into 'jupyter-examples'...
#  Changelog.md
# LICENSE
# Readme.md
# configure.ipynb
# docker_containers
# fabric_examples
# fabric_ssh_tunnel_tools
# requirements.txt
# start_here.ipynb

# %% [markdown]
# ## Set up PTP (Precision Time Protocol)

# %% [markdown]
# #### Clone MeasurementFramework Git repo Locally

# %%
# %%bash
# rm -rf /tmp/MF;
# git clone https://github.com/fabric-testbed/MeasurementFramework.git /tmp/MF;
# Out:
# Cloning into '/tmp/MF'...

# %% [markdown]
# #### Install and setup linux ptp package on all nodes

# %%
pre_requisites = f"""
`sudo apt-get update;sudo apt-get -y install ansible git` || `sudo dnf -y install epel-release ;sudo dnf -y install ansible git`
"""
ansible_instructions = f"""
cd /tmp/ansible;ansible-playbook --connection=local --inventory 127.0.0.1, --limit 127.0.0.1 playbook_fabric_experiment_ptp.yml;
"""

for node in nodes:
    print (f"Installing PTP on {node.get_name()}")
    node.upload_directory('/tmp/MF/instrumentize/ptp/ansible','/tmp/')
    node.execute(f"{pre_requisites}"\
                 f"{ansible_instructions}"\
                )
    print (f"Installation of PTP Completed on {node.get_name()}\n\n")
# Out:
# Installing PTP on STAR
#
# PLAY [all] *********************************************************************
#  sudo: apt-get: command not found
# sudo: apt-get: command not found
# Importing GPG key 0xE451E5B5:
#  Userid     : "CentOS Storage SIG (http://wiki.centos.org/SpecialInterestGroup/Storage) <security@centos.org>"
#  Fingerprint: 7412 9C0B 173B 071A 3775 951A D4A2 E50B E451 E5B5
#  From       : /etc/pki/rpm-gpg/RPM-GPG-KEY-CentOS-SIG-Storage
# bash: line 1: Last: command not found
#
# TASK [Gathering Facts] *********************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : include] ******************************************************
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
#
# TASK [linuxptp : Check if Interface lo is PTP capable] *************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Check if Interface enp7s0 is PTP capable] *********************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Check if Interface enp3s0 is PTP capable] *********************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Check if ptp4l is installed] **********************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Update package cache in case of Debian based system (workaround)] ***
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Install dependencies] *****************************************
# skipping: [127.0.0.1]
#
# TASK [Download linuxptp] *******************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Run 'make clean' target as root] ******************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Run 'make install' target as root] ****************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Stop and Disable Chronyd] *************************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Modprobe ptp_kvm] *********************************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Ansible modprobe file for ptp_kvm] ****************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Remove old service files] *************************************
# changed: [127.0.0.1]
#  [WARNING]: Consider using the file module with state=absent rather than running
# 'rm'.  If you need to use command because file is insufficient you can add
# 'warn: false' to this command task or set 'command_warnings=False' in
# ansible.cfg to get rid of this message.
#
# TASK [linuxptp : Template phc2sys for PTP Capable Interfaces in KVM] ***********
# changed: [127.0.0.1]
#
# TASK [linuxptp : blockinfile] **************************************************
# changed: [127.0.0.1] => (item={'path': 'ptp4l', 'conf': '/var/log/ptp4l.log {
#        daily
#        rotate 7
#        size 10M
#        compress
#        delaycompress
#        copytruncate
#        missingok
# }
# '})
# changed: [127.0.0.1] => (item={'path': 'phc2sys', 'conf': '/var/log/phc2sys.log {
#        daily
#        rotate 7
#        size 10M
#        compress
#        delaycompress
#        copytruncate
#        missingok
# }
# '})
#
# TASK [linuxptp : blockinfile] **************************************************
# changed: [127.0.0.1] => (item={'path': 'ptp4l', 'conf': "if $programname == 'ptp4l' then /var/log/ptp4l.log
#   & stop
# "})
# changed: [127.0.0.1] => (item={'path': 'phc2sys', 'conf': "if $programname == 'phc2sys' then /var/log/phc2sys.log
#   & stop
# "})
#
# TASK [linuxptp : Re-read systemd services] *************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Start Syslog Services] ****************************************
# changed: [127.0.0.1] => (item=rsyslog)
#
# TASK [linuxptp : Stop phc2sys service for PTP Capable Interfaces] **************
# ok: [127.0.0.1] => (item=enp7s0)
# ok: [127.0.0.1] => (item=CLOCK_REALTIME)
#
# TASK [linuxptp : Start phc2sys service for PTP Capable Interfaces] *************
# changed: [127.0.0.1] => (item=enp7s0)
# changed: [127.0.0.1] => (item=CLOCK_REALTIME)
#
# PLAY RECAP *********************************************************************
# 127.0.0.1                  : ok=21   changed=13   unreachable=0    failed=0    skipped=7    rescued=0    ignored=0
#
# Installation of PTP Completed on STAR
#
#
# Installing PTP on MAX
#
# PLAY [all] *********************************************************************
#  sudo: apt-get: command not found
# sudo: apt-get: command not found
# Importing GPG key 0xE451E5B5:
#  Userid     : "CentOS Storage SIG (http://wiki.centos.org/SpecialInterestGroup/Storage) <security@centos.org>"
#  Fingerprint: 7412 9C0B 173B 071A 3775 951A D4A2 E50B E451 E5B5
#  From       : /etc/pki/rpm-gpg/RPM-GPG-KEY-CentOS-SIG-Storage
# bash: line 1: Last: command not found
#
# TASK [Gathering Facts] *********************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : include] ******************************************************
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
#
# TASK [linuxptp : Check if Interface lo is PTP capable] *************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Check if Interface enp7s0 is PTP capable] *********************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Check if Interface enp3s0 is PTP capable] *********************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Check if ptp4l is installed] **********************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Update package cache in case of Debian based system (workaround)] ***
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Install dependencies] *****************************************
# skipping: [127.0.0.1]
#
# TASK [Download linuxptp] *******************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Run 'make clean' target as root] ******************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Run 'make install' target as root] ****************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Stop and Disable Chronyd] *************************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Modprobe ptp_kvm] *********************************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Ansible modprobe file for ptp_kvm] ****************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Remove old service files] *************************************
# changed: [127.0.0.1]
#  [WARNING]: Consider using the file module with state=absent rather than running
# 'rm'.  If you need to use command because file is insufficient you can add
# 'warn: false' to this command task or set 'command_warnings=False' in
# ansible.cfg to get rid of this message.
#
# TASK [linuxptp : Template phc2sys for PTP Capable Interfaces in KVM] ***********
# changed: [127.0.0.1]
#
# TASK [linuxptp : blockinfile] **************************************************
# changed: [127.0.0.1] => (item={'path': 'ptp4l', 'conf': '/var/log/ptp4l.log {
#        daily
#        rotate 7
#        size 10M
#        compress
#        delaycompress
#        copytruncate
#        missingok
# }
# '})
# changed: [127.0.0.1] => (item={'path': 'phc2sys', 'conf': '/var/log/phc2sys.log {
#        daily
#        rotate 7
#        size 10M
#        compress
#        delaycompress
#        copytruncate
#        missingok
# }
# '})
#
# TASK [linuxptp : blockinfile] **************************************************
# changed: [127.0.0.1] => (item={'path': 'ptp4l', 'conf': "if $programname == 'ptp4l' then /var/log/ptp4l.log
#   & stop
# "})
# changed: [127.0.0.1] => (item={'path': 'phc2sys', 'conf': "if $programname == 'phc2sys' then /var/log/phc2sys.log
#   & stop
# "})
#
# TASK [linuxptp : Re-read systemd services] *************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Start Syslog Services] ****************************************
# changed: [127.0.0.1] => (item=rsyslog)
#
# TASK [linuxptp : Stop phc2sys service for PTP Capable Interfaces] **************
# ok: [127.0.0.1] => (item=enp7s0)
# ok: [127.0.0.1] => (item=CLOCK_REALTIME)
#
# TASK [linuxptp : Start phc2sys service for PTP Capable Interfaces] *************
# changed: [127.0.0.1] => (item=enp7s0)
# changed: [127.0.0.1] => (item=CLOCK_REALTIME)
#
# PLAY RECAP *********************************************************************
# 127.0.0.1                  : ok=21   changed=13   unreachable=0    failed=0    skipped=7    rescued=0    ignored=0
#
# Installation of PTP Completed on MAX
#
#
# Installing PTP on MICH
#
# PLAY [all] *********************************************************************
#  sudo: apt-get: command not found
# sudo: apt-get: command not found
# Importing GPG key 0xE451E5B5:
#  Userid     : "CentOS Storage SIG (http://wiki.centos.org/SpecialInterestGroup/Storage) <security@centos.org>"
#  Fingerprint: 7412 9C0B 173B 071A 3775 951A D4A2 E50B E451 E5B5
#  From       : /etc/pki/rpm-gpg/RPM-GPG-KEY-CentOS-SIG-Storage
# bash: line 1: Last: command not found
#
# TASK [Gathering Facts] *********************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : include] ******************************************************
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
#
# TASK [linuxptp : Check if Interface lo is PTP capable] *************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Check if Interface enp3s0 is PTP capable] *********************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Check if Interface enp7s0 is PTP capable] *********************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Check if ptp4l is installed] **********************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Update package cache in case of Debian based system (workaround)] ***
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Install dependencies] *****************************************
# skipping: [127.0.0.1]
#
# TASK [Download linuxptp] *******************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Run 'make clean' target as root] ******************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Run 'make install' target as root] ****************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Stop and Disable Chronyd] *************************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Modprobe ptp_kvm] *********************************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Ansible modprobe file for ptp_kvm] ****************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Remove old service files] *************************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Template phc2sys for PTP Capable Interfaces in KVM] ***********
#  [WARNING]: Consider using the file module with state=absent rather than running
# 'rm'.  If you need to use command because file is insufficient you can add
# 'warn: false' to this command task or set 'command_warnings=False' in
# ansible.cfg to get rid of this message.
#  changed: [127.0.0.1]
#
# TASK [linuxptp : blockinfile] **************************************************
# changed: [127.0.0.1] => (item={'path': 'ptp4l', 'conf': '/var/log/ptp4l.log {
#        daily
#        rotate 7
#        size 10M
#        compress
#        delaycompress
#        copytruncate
#        missingok
# }
# '})
# changed: [127.0.0.1] => (item={'path': 'phc2sys', 'conf': '/var/log/phc2sys.log {
#        daily
#        rotate 7
#        size 10M
#        compress
#        delaycompress
#        copytruncate
#        missingok
# }
# '})
#
# TASK [linuxptp : blockinfile] **************************************************
# changed: [127.0.0.1] => (item={'path': 'ptp4l', 'conf': "if $programname == 'ptp4l' then /var/log/ptp4l.log
#   & stop
# "})
# changed: [127.0.0.1] => (item={'path': 'phc2sys', 'conf': "if $programname == 'phc2sys' then /var/log/phc2sys.log
#   & stop
# "})
#
# TASK [linuxptp : Re-read systemd services] *************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Start Syslog Services] ****************************************
# changed: [127.0.0.1] => (item=rsyslog)
#
# TASK [linuxptp : Stop phc2sys service for PTP Capable Interfaces] **************
# ok: [127.0.0.1] => (item=enp7s0)
# ok: [127.0.0.1] => (item=CLOCK_REALTIME)
#
# TASK [linuxptp : Start phc2sys service for PTP Capable Interfaces] *************
# changed: [127.0.0.1] => (item=enp7s0)
# changed: [127.0.0.1] => (item=CLOCK_REALTIME)
#
# PLAY RECAP *********************************************************************
# 127.0.0.1                  : ok=21   changed=13   unreachable=0    failed=0    skipped=7    rescued=0    ignored=0
#
# Installation of PTP Completed on MICH
#
#
# Installing PTP on MASS
#
# PLAY [all] *********************************************************************
#  sudo: apt-get: command not found
# sudo: apt-get: command not found
# Importing GPG key 0xE451E5B5:
#  Userid     : "CentOS Storage SIG (http://wiki.centos.org/SpecialInterestGroup/Storage) <security@centos.org>"
#  Fingerprint: 7412 9C0B 173B 071A 3775 951A D4A2 E50B E451 E5B5
#  From       : /etc/pki/rpm-gpg/RPM-GPG-KEY-CentOS-SIG-Storage
# bash: line 1: Last: command not found
#
# TASK [Gathering Facts] *********************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : include] ******************************************************
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
#
# TASK [linuxptp : Check if Interface enp3s0 is PTP capable] *********************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Check if Interface lo is PTP capable] *************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Check if Interface enp7s0 is PTP capable] *********************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Check if ptp4l is installed] **********************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Update package cache in case of Debian based system (workaround)] ***
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Install dependencies] *****************************************
# skipping: [127.0.0.1]
#
# TASK [Download linuxptp] *******************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Run 'make clean' target as root] ******************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Run 'make install' target as root] ****************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Stop and Disable Chronyd] *************************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Modprobe ptp_kvm] *********************************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Ansible modprobe file for ptp_kvm] ****************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Remove old service files] *************************************
# changed: [127.0.0.1]
#  [WARNING]: Consider using the file module with state=absent rather than running
# 'rm'.  If you need to use command because file is insufficient you can add
# 'warn: false' to this command task or set 'command_warnings=False' in
# ansible.cfg to get rid of this message.
#
# TASK [linuxptp : Template phc2sys for PTP Capable Interfaces in KVM] ***********
# changed: [127.0.0.1]
#
# TASK [linuxptp : blockinfile] **************************************************
# changed: [127.0.0.1] => (item={'path': 'ptp4l', 'conf': '/var/log/ptp4l.log {
#        daily
#        rotate 7
#        size 10M
#        compress
#        delaycompress
#        copytruncate
#        missingok
# }
# '})
# changed: [127.0.0.1] => (item={'path': 'phc2sys', 'conf': '/var/log/phc2sys.log {
#        daily
#        rotate 7
#        size 10M
#        compress
#        delaycompress
#        copytruncate
#        missingok
# }
# '})
#
# TASK [linuxptp : blockinfile] **************************************************
# changed: [127.0.0.1] => (item={'path': 'ptp4l', 'conf': "if $programname == 'ptp4l' then /var/log/ptp4l.log
#   & stop
# "})
# changed: [127.0.0.1] => (item={'path': 'phc2sys', 'conf': "if $programname == 'phc2sys' then /var/log/phc2sys.log
#   & stop
# "})
#
# TASK [linuxptp : Re-read systemd services] *************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Start Syslog Services] ****************************************
# changed: [127.0.0.1] => (item=rsyslog)
#
# TASK [linuxptp : Stop phc2sys service for PTP Capable Interfaces] **************
# ok: [127.0.0.1] => (item=enp7s0)
# ok: [127.0.0.1] => (item=CLOCK_REALTIME)
#
# TASK [linuxptp : Start phc2sys service for PTP Capable Interfaces] *************
# changed: [127.0.0.1] => (item=enp7s0)
# changed: [127.0.0.1] => (item=CLOCK_REALTIME)
#
# PLAY RECAP *********************************************************************
# 127.0.0.1                  : ok=21   changed=13   unreachable=0    failed=0    skipped=7    rescued=0    ignored=0
#
# Installation of PTP Completed on MASS
#
#
# Installing PTP on UTAH
#
# PLAY [all] *********************************************************************
#  sudo: apt-get: command not found
# sudo: apt-get: command not found
# Importing GPG key 0xE451E5B5:
#  Userid     : "CentOS Storage SIG (http://wiki.centos.org/SpecialInterestGroup/Storage) <security@centos.org>"
#  Fingerprint: 7412 9C0B 173B 071A 3775 951A D4A2 E50B E451 E5B5
#  From       : /etc/pki/rpm-gpg/RPM-GPG-KEY-CentOS-SIG-Storage
# bash: line 1: Last: command not found
#
# TASK [Gathering Facts] *********************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : include] ******************************************************
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
#
# TASK [linuxptp : Check if Interface lo is PTP capable] *************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Check if Interface enp3s0 is PTP capable] *********************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Check if Interface enp7s0 is PTP capable] *********************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Check if ptp4l is installed] **********************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Update package cache in case of Debian based system (workaround)] ***
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Install dependencies] *****************************************
# skipping: [127.0.0.1]
#
# TASK [Download linuxptp] *******************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Run 'make clean' target as root] ******************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Run 'make install' target as root] ****************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Stop and Disable Chronyd] *************************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Modprobe ptp_kvm] *********************************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Ansible modprobe file for ptp_kvm] ****************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Remove old service files] *************************************
# changed: [127.0.0.1]
#  [WARNING]: Consider using the file module with state=absent rather than running
# 'rm'.  If you need to use command because file is insufficient you can add
# 'warn: false' to this command task or set 'command_warnings=False' in
# ansible.cfg to get rid of this message.
#
# TASK [linuxptp : Template phc2sys for PTP Capable Interfaces in KVM] ***********
# changed: [127.0.0.1]
#
# TASK [linuxptp : blockinfile] **************************************************
# changed: [127.0.0.1] => (item={'path': 'ptp4l', 'conf': '/var/log/ptp4l.log {
#        daily
#        rotate 7
#        size 10M
#        compress
#        delaycompress
#        copytruncate
#        missingok
# }
# '})
# changed: [127.0.0.1] => (item={'path': 'phc2sys', 'conf': '/var/log/phc2sys.log {
#        daily
#        rotate 7
#        size 10M
#        compress
#        delaycompress
#        copytruncate
#        missingok
# }
# '})
#
# TASK [linuxptp : blockinfile] **************************************************
# changed: [127.0.0.1] => (item={'path': 'ptp4l', 'conf': "if $programname == 'ptp4l' then /var/log/ptp4l.log
#   & stop
# "})
# changed: [127.0.0.1] => (item={'path': 'phc2sys', 'conf': "if $programname == 'phc2sys' then /var/log/phc2sys.log
#   & stop
# "})
#
# TASK [linuxptp : Re-read systemd services] *************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Start Syslog Services] ****************************************
# changed: [127.0.0.1] => (item=rsyslog)
#
# TASK [linuxptp : Stop phc2sys service for PTP Capable Interfaces] **************
# ok: [127.0.0.1] => (item=enp7s0)
# ok: [127.0.0.1] => (item=CLOCK_REALTIME)
#
# TASK [linuxptp : Start phc2sys service for PTP Capable Interfaces] *************
# changed: [127.0.0.1] => (item=enp7s0)
# changed: [127.0.0.1] => (item=CLOCK_REALTIME)
#
# PLAY RECAP *********************************************************************
# 127.0.0.1                  : ok=21   changed=13   unreachable=0    failed=0    skipped=7    rescued=0    ignored=0
#
# Installation of PTP Completed on UTAH
#
#
# Installing PTP on NCSA
#
# PLAY [all] *********************************************************************
#  sudo: apt-get: command not found
# sudo: apt-get: command not found
# Importing GPG key 0xE451E5B5:
#  Userid     : "CentOS Storage SIG (http://wiki.centos.org/SpecialInterestGroup/Storage) <security@centos.org>"
#  Fingerprint: 7412 9C0B 173B 071A 3775 951A D4A2 E50B E451 E5B5
#  From       : /etc/pki/rpm-gpg/RPM-GPG-KEY-CentOS-SIG-Storage
# bash: line 1: Last: command not found
#
# TASK [Gathering Facts] *********************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : include] ******************************************************
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
#
# TASK [linuxptp : Check if Interface enp3s0 is PTP capable] *********************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Check if Interface enp7s0 is PTP capable] *********************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Check if Interface lo is PTP capable] *************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Check if ptp4l is installed] **********************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Update package cache in case of Debian based system (workaround)] ***
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Install dependencies] *****************************************
# skipping: [127.0.0.1]
#
# TASK [Download linuxptp] *******************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Run 'make clean' target as root] ******************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Run 'make install' target as root] ****************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Stop and Disable Chronyd] *************************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Modprobe ptp_kvm] *********************************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Ansible modprobe file for ptp_kvm] ****************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Remove old service files] *************************************
# changed: [127.0.0.1]
#  [WARNING]: Consider using the file module with state=absent rather than running
# 'rm'.  If you need to use command because file is insufficient you can add
# 'warn: false' to this command task or set 'command_warnings=False' in
# ansible.cfg to get rid of this message.
#
# TASK [linuxptp : Template phc2sys for PTP Capable Interfaces in KVM] ***********
# changed: [127.0.0.1]
#
# TASK [linuxptp : blockinfile] **************************************************
# changed: [127.0.0.1] => (item={'path': 'ptp4l', 'conf': '/var/log/ptp4l.log {
#        daily
#        rotate 7
#        size 10M
#        compress
#        delaycompress
#        copytruncate
#        missingok
# }
# '})
# changed: [127.0.0.1] => (item={'path': 'phc2sys', 'conf': '/var/log/phc2sys.log {
#        daily
#        rotate 7
#        size 10M
#        compress
#        delaycompress
#        copytruncate
#        missingok
# }
# '})
#
# TASK [linuxptp : blockinfile] **************************************************
# changed: [127.0.0.1] => (item={'path': 'ptp4l', 'conf': "if $programname == 'ptp4l' then /var/log/ptp4l.log
#   & stop
# "})
# changed: [127.0.0.1] => (item={'path': 'phc2sys', 'conf': "if $programname == 'phc2sys' then /var/log/phc2sys.log
#   & stop
# "})
#
# TASK [linuxptp : Re-read systemd services] *************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Start Syslog Services] ****************************************
# changed: [127.0.0.1] => (item=rsyslog)
#
# TASK [linuxptp : Stop phc2sys service for PTP Capable Interfaces] **************
# ok: [127.0.0.1] => (item=enp7s0)
# ok: [127.0.0.1] => (item=CLOCK_REALTIME)
#
# TASK [linuxptp : Start phc2sys service for PTP Capable Interfaces] *************
# changed: [127.0.0.1] => (item=enp7s0)
# changed: [127.0.0.1] => (item=CLOCK_REALTIME)
#
# PLAY RECAP *********************************************************************
# 127.0.0.1                  : ok=21   changed=13   unreachable=0    failed=0    skipped=7    rescued=0    ignored=0
#
# Installation of PTP Completed on NCSA
#
#
# Installing PTP on UCSD
#
# PLAY [all] *********************************************************************
#  sudo: apt-get: command not found
# sudo: apt-get: command not found
# Failed to set locale, defaulting to C.UTF-8
# Failed to set locale, defaulting to C.UTF-8
# Importing GPG key 0xE451E5B5:
#  Userid     : "CentOS Storage SIG (http://wiki.centos.org/SpecialInterestGroup/Storage) <security@centos.org>"
#  Fingerprint: 7412 9C0B 173B 071A 3775 951A D4A2 E50B E451 E5B5
#  From       : /etc/pki/rpm-gpg/RPM-GPG-KEY-CentOS-SIG-Storage
# bash: line 1: Waiting: command not found
#
# TASK [Gathering Facts] *********************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : include] ******************************************************
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
#
# TASK [linuxptp : Check if Interface enp1s0 is PTP capable] *********************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Check if Interface lo is PTP capable] *************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Check if Interface enp6s0 is PTP capable] *********************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Check if ptp4l is installed] **********************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Update package cache in case of Debian based system (workaround)] ***
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Install dependencies] *****************************************
# skipping: [127.0.0.1]
#
# TASK [Download linuxptp] *******************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Run 'make clean' target as root] ******************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Run 'make install' target as root] ****************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Stop and Disable Chronyd] *************************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Modprobe ptp_kvm] *********************************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Ansible modprobe file for ptp_kvm] ****************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Remove old service files] *************************************
# changed: [127.0.0.1]
#  [WARNING]: Consider using the file module with state=absent rather than running
# 'rm'.  If you need to use command because file is insufficient you can add
# 'warn: false' to this command task or set 'command_warnings=False' in
# ansible.cfg to get rid of this message.
#
# TASK [linuxptp : Template phc2sys for PTP Capable Interfaces in KVM] ***********
# changed: [127.0.0.1]
#
# TASK [linuxptp : blockinfile] **************************************************
# changed: [127.0.0.1] => (item={'path': 'ptp4l', 'conf': '/var/log/ptp4l.log {
#        daily
#        rotate 7
#        size 10M
#        compress
#        delaycompress
#        copytruncate
#        missingok
# }
# '})
# changed: [127.0.0.1] => (item={'path': 'phc2sys', 'conf': '/var/log/phc2sys.log {
#        daily
#        rotate 7
#        size 10M
#        compress
#        delaycompress
#        copytruncate
#        missingok
# }
# '})
#
# TASK [linuxptp : blockinfile] **************************************************
# changed: [127.0.0.1] => (item={'path': 'ptp4l', 'conf': "if $programname == 'ptp4l' then /var/log/ptp4l.log
#   & stop
# "})
# changed: [127.0.0.1] => (item={'path': 'phc2sys', 'conf': "if $programname == 'phc2sys' then /var/log/phc2sys.log
#   & stop
# "})
#
# TASK [linuxptp : Re-read systemd services] *************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Start Syslog Services] ****************************************
# changed: [127.0.0.1] => (item=rsyslog)
#
# TASK [linuxptp : Stop phc2sys service for PTP Capable Interfaces] **************
# ok: [127.0.0.1] => (item=enp6s0)
# ok: [127.0.0.1] => (item=CLOCK_REALTIME)
#
# TASK [linuxptp : Start phc2sys service for PTP Capable Interfaces] *************
# changed: [127.0.0.1] => (item=enp6s0)
# changed: [127.0.0.1] => (item=CLOCK_REALTIME)
#
# PLAY RECAP *********************************************************************
# 127.0.0.1                  : ok=21   changed=13   unreachable=0    failed=0    skipped=7    rescued=0    ignored=0
#
# Installation of PTP Completed on UCSD
#
#
# Installing PTP on FIU
#
# PLAY [all] *********************************************************************
#  sudo: apt-get: command not found
# sudo: apt-get: command not found
# Failed to set locale, defaulting to C.UTF-8
# Failed to set locale, defaulting to C.UTF-8
# Importing GPG key 0xE451E5B5:
#  Userid     : "CentOS Storage SIG (http://wiki.centos.org/SpecialInterestGroup/Storage) <security@centos.org>"
#  Fingerprint: 7412 9C0B 173B 071A 3775 951A D4A2 E50B E451 E5B5
#  From       : /etc/pki/rpm-gpg/RPM-GPG-KEY-CentOS-SIG-Storage
# bash: line 1: Last: command not found
#
# TASK [Gathering Facts] *********************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : include] ******************************************************
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
#
# TASK [linuxptp : Check if Interface enp1s0 is PTP capable] *********************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Check if Interface enp6s0 is PTP capable] *********************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Check if Interface lo is PTP capable] *************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Check if ptp4l is installed] **********************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Update package cache in case of Debian based system (workaround)] ***
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Install dependencies] *****************************************
# skipping: [127.0.0.1]
#
# TASK [Download linuxptp] *******************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Run 'make clean' target as root] ******************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Run 'make install' target as root] ****************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Stop and Disable Chronyd] *************************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Modprobe ptp_kvm] *********************************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Ansible modprobe file for ptp_kvm] ****************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Remove old service files] *************************************
# changed: [127.0.0.1]
#  [WARNING]: Consider using the file module with state=absent rather than running
# 'rm'.  If you need to use command because file is insufficient you can add
# 'warn: false' to this command task or set 'command_warnings=False' in
# ansible.cfg to get rid of this message.
#
# TASK [linuxptp : Template phc2sys for PTP Capable Interfaces in KVM] ***********
# changed: [127.0.0.1]
#
# TASK [linuxptp : blockinfile] **************************************************
# changed: [127.0.0.1] => (item={'path': 'ptp4l', 'conf': '/var/log/ptp4l.log {
#        daily
#        rotate 7
#        size 10M
#        compress
#        delaycompress
#        copytruncate
#        missingok
# }
# '})
# changed: [127.0.0.1] => (item={'path': 'phc2sys', 'conf': '/var/log/phc2sys.log {
#        daily
#        rotate 7
#        size 10M
#        compress
#        delaycompress
#        copytruncate
#        missingok
# }
# '})
#
# TASK [linuxptp : blockinfile] **************************************************
# changed: [127.0.0.1] => (item={'path': 'ptp4l', 'conf': "if $programname == 'ptp4l' then /var/log/ptp4l.log
#   & stop
# "})
# changed: [127.0.0.1] => (item={'path': 'phc2sys', 'conf': "if $programname == 'phc2sys' then /var/log/phc2sys.log
#   & stop
# "})
#
# TASK [linuxptp : Re-read systemd services] *************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Start Syslog Services] ****************************************
# changed: [127.0.0.1] => (item=rsyslog)
#
# TASK [linuxptp : Stop phc2sys service for PTP Capable Interfaces] **************
# ok: [127.0.0.1] => (item=enp6s0)
# ok: [127.0.0.1] => (item=CLOCK_REALTIME)
#
# TASK [linuxptp : Start phc2sys service for PTP Capable Interfaces] *************
# changed: [127.0.0.1] => (item=enp6s0)
# changed: [127.0.0.1] => (item=CLOCK_REALTIME)
#
# PLAY RECAP *********************************************************************
# 127.0.0.1                  : ok=21   changed=13   unreachable=0    failed=0    skipped=7    rescued=0    ignored=0
#
# Installation of PTP Completed on FIU
#
#
# Installing PTP on CLEM
#
# PLAY [all] *********************************************************************
#  sudo: apt-get: command not found
# sudo: apt-get: command not found
# Failed to set locale, defaulting to C.UTF-8
# Failed to set locale, defaulting to C.UTF-8
# Importing GPG key 0xE451E5B5:
#  Userid     : "CentOS Storage SIG (http://wiki.centos.org/SpecialInterestGroup/Storage) <security@centos.org>"
#  Fingerprint: 7412 9C0B 173B 071A 3775 951A D4A2 E50B E451 E5B5
#  From       : /etc/pki/rpm-gpg/RPM-GPG-KEY-CentOS-SIG-Storage
# bash: line 1: Last: command not found
#
# TASK [Gathering Facts] *********************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : include] ******************************************************
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
#
# TASK [linuxptp : Check if Interface enp6s0 is PTP capable] *********************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Check if Interface enp1s0 is PTP capable] *********************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Check if Interface lo is PTP capable] *************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Check if ptp4l is installed] **********************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Update package cache in case of Debian based system (workaround)] ***
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Install dependencies] *****************************************
# skipping: [127.0.0.1]
#
# TASK [Download linuxptp] *******************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Run 'make clean' target as root] ******************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Run 'make install' target as root] ****************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Stop and Disable Chronyd] *************************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Modprobe ptp_kvm] *********************************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Ansible modprobe file for ptp_kvm] ****************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Remove old service files] *************************************
# changed: [127.0.0.1]
#  [WARNING]: Consider using the file module with state=absent rather than running
# 'rm'.  If you need to use command because file is insufficient you can add
# 'warn: false' to this command task or set 'command_warnings=False' in
# ansible.cfg to get rid of this message.
#
# TASK [linuxptp : Template phc2sys for PTP Capable Interfaces in KVM] ***********
# changed: [127.0.0.1]
#
# TASK [linuxptp : blockinfile] **************************************************
# changed: [127.0.0.1] => (item={'path': 'ptp4l', 'conf': '/var/log/ptp4l.log {
#        daily
#        rotate 7
#        size 10M
#        compress
#        delaycompress
#        copytruncate
#        missingok
# }
# '})
# changed: [127.0.0.1] => (item={'path': 'phc2sys', 'conf': '/var/log/phc2sys.log {
#        daily
#        rotate 7
#        size 10M
#        compress
#        delaycompress
#        copytruncate
#        missingok
# }
# '})
#
# TASK [linuxptp : blockinfile] **************************************************
# changed: [127.0.0.1] => (item={'path': 'ptp4l', 'conf': "if $programname == 'ptp4l' then /var/log/ptp4l.log
#   & stop
# "})
# changed: [127.0.0.1] => (item={'path': 'phc2sys', 'conf': "if $programname == 'phc2sys' then /var/log/phc2sys.log
#   & stop
# "})
#
# TASK [linuxptp : Re-read systemd services] *************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Start Syslog Services] ****************************************
# changed: [127.0.0.1] => (item=rsyslog)
#
# TASK [linuxptp : Stop phc2sys service for PTP Capable Interfaces] **************
# ok: [127.0.0.1] => (item=enp6s0)
# ok: [127.0.0.1] => (item=CLOCK_REALTIME)
#
# TASK [linuxptp : Start phc2sys service for PTP Capable Interfaces] *************
# changed: [127.0.0.1] => (item=enp6s0)
# changed: [127.0.0.1] => (item=CLOCK_REALTIME)
#
# PLAY RECAP *********************************************************************
# 127.0.0.1                  : ok=21   changed=13   unreachable=0    failed=0    skipped=7    rescued=0    ignored=0
#
# Installation of PTP Completed on CLEM
#
#
# Installing PTP on CERN
#
# PLAY [all] *********************************************************************
#  sudo: apt-get: command not found
# sudo: apt-get: command not found
# Failed to set locale, defaulting to C.UTF-8
# Failed to set locale, defaulting to C.UTF-8
# Importing GPG key 0xE451E5B5:
#  Userid     : "CentOS Storage SIG (http://wiki.centos.org/SpecialInterestGroup/Storage) <security@centos.org>"
#  Fingerprint: 7412 9C0B 173B 071A 3775 951A D4A2 E50B E451 E5B5
#  From       : /etc/pki/rpm-gpg/RPM-GPG-KEY-CentOS-SIG-Storage
# bash: line 1: Last: command not found
#
# TASK [Gathering Facts] *********************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : include] ******************************************************
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
# included: /tmp/ansible/roles/linuxptp/tasks/find_ptp_interfaces.yml for 127.0.0.1
#
# TASK [linuxptp : Check if Interface enp3s0 is PTP capable] *********************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Check if Interface lo is PTP capable] *************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Check if Interface enp7s0 is PTP capable] *********************
# changed: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Check if ptp4l is installed] **********************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Update package cache in case of Debian based system (workaround)] ***
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Install dependencies] *****************************************
# skipping: [127.0.0.1]
#
# TASK [Download linuxptp] *******************************************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Run 'make clean' target as root] ******************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : Run 'make install' target as root] ****************************
# skipping: [127.0.0.1]
#
# TASK [linuxptp : set_fact] *****************************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Stop and Disable Chronyd] *************************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Modprobe ptp_kvm] *********************************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Ansible modprobe file for ptp_kvm] ****************************
# changed: [127.0.0.1]
#
# TASK [linuxptp : Remove old service files] *************************************
# changed: [127.0.0.1]
#  [WARNING]: Consider using the file module with state=absent rather than running
# 'rm'.  If you need to use command because file is insufficient you can add
# 'warn: false' to this command task or set 'command_warnings=False' in
# ansible.cfg to get rid of this message.
#
# TASK [linuxptp : Template phc2sys for PTP Capable Interfaces in KVM] ***********
# changed: [127.0.0.1]
#
# TASK [linuxptp : blockinfile] **************************************************
# changed: [127.0.0.1] => (item={'path': 'ptp4l', 'conf': '/var/log/ptp4l.log {
#        daily
#        rotate 7
#        size 10M
#        compress
#        delaycompress
#        copytruncate
#        missingok
# }
# '})
# changed: [127.0.0.1] => (item={'path': 'phc2sys', 'conf': '/var/log/phc2sys.log {
#        daily
#        rotate 7
#        size 10M
#        compress
#        delaycompress
#        copytruncate
#        missingok
# }
# '})
#
# TASK [linuxptp : blockinfile] **************************************************
# changed: [127.0.0.1] => (item={'path': 'ptp4l', 'conf': "if $programname == 'ptp4l' then /var/log/ptp4l.log
#   & stop
# "})
# changed: [127.0.0.1] => (item={'path': 'phc2sys', 'conf': "if $programname == 'phc2sys' then /var/log/phc2sys.log
#   & stop
# "})
#
# TASK [linuxptp : Re-read systemd services] *************************************
# ok: [127.0.0.1]
#
# TASK [linuxptp : Start Syslog Services] ****************************************
# changed: [127.0.0.1] => (item=rsyslog)
#
# TASK [linuxptp : Stop phc2sys service for PTP Capable Interfaces] **************
# ok: [127.0.0.1] => (item=enp7s0)
# ok: [127.0.0.1] => (item=CLOCK_REALTIME)
#
# TASK [linuxptp : Start phc2sys service for PTP Capable Interfaces] *************
# changed: [127.0.0.1] => (item=enp7s0)
# changed: [127.0.0.1] => (item=CLOCK_REALTIME)
#
# PLAY RECAP *********************************************************************
# 127.0.0.1                  : ok=21   changed=13   unreachable=0    failed=0    skipped=7    rescued=0    ignored=0
#
# Installation of PTP Completed on CERN

# %% [markdown]
# ## Start Docker

# %%
for node in nodes:
    node.execute("sudo systemctl start docker")
    node.execute("sudo systemctl enable docker")
    node.execute("sudo usermod -aG docker rocky")
    
    print(f"\n Verify installtion... on {node.get_name()}")
    node.execute("docker --help")
# Out:
#  Created symlink /etc/systemd/system/multi-user.target.wants/docker.service → /usr/lib/systemd/system/docker.service.
#
#  Verify installtion... on STAR
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#   pull        Download an image from a registry
#   push        Upload an image to a registry
#   images      List images
#   login       Log in to a registry
#   logout      Log out from a registry
#   search      Search Docker Hub for images
#   version     Show the Docker version information
#   info        Display system-wide information
#
# Management Commands:
#   builder     Manage builds
#   buildx*     Docker Buildx (Docker Inc., v0.10.5)
#   checkpoint  Manage checkpoints
#   compose*    Docker Compose (Docker Inc., v2.18.1)
#   container   Manage containers
#   context     Manage contexts
#   image       Manage images
#   manifest    Manage Docker image manifests and manifest lists
#   network     Manage networks
#   plugin      Manage plugins
#   system      Manage Docker
#   trust       Manage trust on Docker images
#   volume      Manage volumes
#
# Swarm Commands:
#   swarm       Manage Swarm
#
# Commands:
#   attach      Attach local standard input, output, and error streams to a running container
#   commit      Create a new image from a container's changes
#   cp          Copy files/folders between a container and the local filesystem
#   create      Create a new container
#   diff        Inspect changes to files or directories on a container's filesystem
#   events      Get real time events from the server
#   export      Export a container's filesystem as a tar archive
#   history     Show the history of an image
#   import      Import the contents from a tarball to create a filesystem image
#   inspect     Return low-level information on Docker objects
#   kill        Kill one or more running containers
#   load        Load an image from a tar archive or STDIN
#   logs        Fetch the logs of a container
#   pause       Pause all processes within one or more containers
#   port        List port mappings or a specific mapping for the container
#   rename      Rename a container
#   restart     Restart one or more containers
#   rm          Remove one or more containers
#   rmi         Remove one or more images
#   save        Save one or more images to a tar archive (streamed to STDOUT by default)
#   start       Start one or more stopped containers
#   stats       Display a live stream of container(s) resource usage statistics
#   stop        Stop one or more running containers
#   tag         Create a tag TARGET_IMAGE that refers to SOURCE_IMAGE
#   top         Display the running processes of a container
#   unpause     Unpause all processes within one or more containers
#   update      Update configuration of one or more containers
#   wait        Block until one or more containers stop, then print their exit codes
#
# Global Options:
#       --config string      Location of client config files (default
#                            "/home/rocky/.docker")
#   -c, --context string     Name of the context to use to connect to the
#                            daemon (overrides DOCKER_HOST env var and
#                            default context set with "docker context use")
#   -D, --debug              Enable debug mode
#   -H, --host list          Daemon socket to connect to
#   -l, --log-level string   Set the logging level ("debug", "info",
#                            "warn", "error", "fatal") (default "info")
#       --tls                Use TLS; implied by --tlsverify
#       --tlscacert string   Trust certs signed only by this CA (default
#                            "/home/rocky/.docker/ca.pem")
#       --tlscert string     Path to TLS certificate file (default
#                            "/home/rocky/.docker/cert.pem")
#       --tlskey string      Path to TLS key file (default
#                            "/home/rocky/.docker/key.pem")
#       --tlsverify          Use TLS and verify the remote
#   -v, --version            Print version information and quit
#
# Run 'docker COMMAND --help' for more information on a command.
#
# For more help on how to use Docker, head to https://docs.docker.com/go/guides/
#  Created symlink /etc/systemd/system/multi-user.target.wants/docker.service → /usr/lib/systemd/system/docker.service.
#
#  Verify installtion... on MAX
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#   pull        Download an image from a registry
#   push        Upload an image to a registry
#   images      List images
#   login       Log in to a registry
#   logout      Log out from a registry
#   search      Search Docker Hub for images
#   version     Show the Docker version information
#   info        Display system-wide information
#
# Management Commands:
#   builder     Manage builds
#   buildx*     Docker Buildx (Docker Inc., v0.10.5)
#   checkpoint  Manage checkpoints
#   compose*    Docker Compose (Docker Inc., v2.18.1)
#   container   Manage containers
#   context     Manage contexts
#   image       Manage images
#   manifest    Manage Docker image manifests and manifest lists
#   network     Manage networks
#   plugin      Manage plugins
#   system      Manage Docker
#   trust       Manage trust on Docker images
#   volume      Manage volumes
#
# Swarm Commands:
#   swarm       Manage Swarm
#
# Commands:
#   attach      Attach local standard input, output, and error streams to a running container
#   commit      Create a new image from a container's changes
#   cp          Copy files/folders between a container and the local filesystem
#   create      Create a new container
#   diff        Inspect changes to files or directories on a container's filesystem
#   events      Get real time events from the server
#   export      Export a container's filesystem as a tar archive
#   history     Show the history of an image
#   import      Import the contents from a tarball to create a filesystem image
#   inspect     Return low-level information on Docker objects
#   kill        Kill one or more running containers
#   load        Load an image from a tar archive or STDIN
#   logs        Fetch the logs of a container
#   pause       Pause all processes within one or more containers
#   port        List port mappings or a specific mapping for the container
#   rename      Rename a container
#   restart     Restart one or more containers
#   rm          Remove one or more containers
#   rmi         Remove one or more images
#   save        Save one or more images to a tar archive (streamed to STDOUT by default)
#   start       Start one or more stopped containers
#   stats       Display a live stream of container(s) resource usage statistics
#   stop        Stop one or more running containers
#   tag         Create a tag TARGET_IMAGE that refers to SOURCE_IMAGE
#   top         Display the running processes of a container
#   unpause     Unpause all processes within one or more containers
#   update      Update configuration of one or more containers
#   wait        Block until one or more containers stop, then print their exit codes
#
# Global Options:
#       --config string      Location of client config files (default
#                            "/home/rocky/.docker")
#   -c, --context string     Name of the context to use to connect to the
#                            daemon (overrides DOCKER_HOST env var and
#                            default context set with "docker context use")
#   -D, --debug              Enable debug mode
#   -H, --host list          Daemon socket to connect to
#   -l, --log-level string   Set the logging level ("debug", "info",
#                            "warn", "error", "fatal") (default "info")
#       --tls                Use TLS; implied by --tlsverify
#       --tlscacert string   Trust certs signed only by this CA (default
#                            "/home/rocky/.docker/ca.pem")
#       --tlscert string     Path to TLS certificate file (default
#                            "/home/rocky/.docker/cert.pem")
#       --tlskey string      Path to TLS key file (default
#                            "/home/rocky/.docker/key.pem")
#       --tlsverify          Use TLS and verify the remote
#   -v, --version            Print version information and quit
#
# Run 'docker COMMAND --help' for more information on a command.
#
# For more help on how to use Docker, head to https://docs.docker.com/go/guides/
#  Created symlink /etc/systemd/system/multi-user.target.wants/docker.service → /usr/lib/systemd/system/docker.service.
#
#  Verify installtion... on MICH
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#   pull        Download an image from a registry
#   push        Upload an image to a registry
#   images      List images
#   login       Log in to a registry
#   logout      Log out from a registry
#   search      Search Docker Hub for images
#   version     Show the Docker version information
#   info        Display system-wide information
#
# Management Commands:
#   builder     Manage builds
#   buildx*     Docker Buildx (Docker Inc., v0.10.5)
#   checkpoint  Manage checkpoints
#   compose*    Docker Compose (Docker Inc., v2.18.1)
#   container   Manage containers
#   context     Manage contexts
#   image       Manage images
#   manifest    Manage Docker image manifests and manifest lists
#   network     Manage networks
#   plugin      Manage plugins
#   system      Manage Docker
#   trust       Manage trust on Docker images
#   volume      Manage volumes
#
# Swarm Commands:
#   swarm       Manage Swarm
#
# Commands:
#   attach      Attach local standard input, output, and error streams to a running container
#   commit      Create a new image from a container's changes
#   cp          Copy files/folders between a container and the local filesystem
#   create      Create a new container
#   diff        Inspect changes to files or directories on a container's filesystem
#   events      Get real time events from the server
#   export      Export a container's filesystem as a tar archive
#   history     Show the history of an image
#   import      Import the contents from a tarball to create a filesystem image
#   inspect     Return low-level information on Docker objects
#   kill        Kill one or more running containers
#   load        Load an image from a tar archive or STDIN
#   logs        Fetch the logs of a container
#   pause       Pause all processes within one or more containers
#   port        List port mappings or a specific mapping for the container
#   rename      Rename a container
#   restart     Restart one or more containers
#   rm          Remove one or more containers
#   rmi         Remove one or more images
#   save        Save one or more images to a tar archive (streamed to STDOUT by default)
#   start       Start one or more stopped containers
#   stats       Display a live stream of container(s) resource usage statistics
#   stop        Stop one or more running containers
#   tag         Create a tag TARGET_IMAGE that refers to SOURCE_IMAGE
#   top         Display the running processes of a container
#   unpause     Unpause all processes within one or more containers
#   update      Update configuration of one or more containers
#   wait        Block until one or more containers stop, then print their exit codes
#
# Global Options:
#       --config string      Location of client config files (default
#                            "/home/rocky/.docker")
#   -c, --context string     Name of the context to use to connect to the
#                            daemon (overrides DOCKER_HOST env var and
#                            default context set with "docker context use")
#   -D, --debug              Enable debug mode
#   -H, --host list          Daemon socket to connect to
#   -l, --log-level string   Set the logging level ("debug", "info",
#                            "warn", "error", "fatal") (default "info")
#       --tls                Use TLS; implied by --tlsverify
#       --tlscacert string   Trust certs signed only by this CA (default
#                            "/home/rocky/.docker/ca.pem")
#       --tlscert string     Path to TLS certificate file (default
#                            "/home/rocky/.docker/cert.pem")
#       --tlskey string      Path to TLS key file (default
#                            "/home/rocky/.docker/key.pem")
#       --tlsverify          Use TLS and verify the remote
#   -v, --version            Print version information and quit
#
# Run 'docker COMMAND --help' for more information on a command.
#
# For more help on how to use Docker, head to https://docs.docker.com/go/guides/
#  Created symlink /etc/systemd/system/multi-user.target.wants/docker.service → /usr/lib/systemd/system/docker.service.
#
#  Verify installtion... on MASS
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#   pull        Download an image from a registry
#   push        Upload an image to a registry
#   images      List images
#   login       Log in to a registry
#   logout      Log out from a registry
#   search      Search Docker Hub for images
#   version     Show the Docker version information
#   info        Display system-wide information
#
# Management Commands:
#   builder     Manage builds
#   buildx*     Docker Buildx (Docker Inc., v0.10.5)
#   checkpoint  Manage checkpoints
#   compose*    Docker Compose (Docker Inc., v2.18.1)
#   container   Manage containers
#   context     Manage contexts
#   image       Manage images
#   manifest    Manage Docker image manifests and manifest lists
#   network     Manage networks
#   plugin      Manage plugins
#   system      Manage Docker
#   trust       Manage trust on Docker images
#   volume      Manage volumes
#
# Swarm Commands:
#   swarm       Manage Swarm
#
# Commands:
#   attach      Attach local standard input, output, and error streams to a running container
#   commit      Create a new image from a container's changes
#   cp          Copy files/folders between a container and the local filesystem
#   create      Create a new container
#   diff        Inspect changes to files or directories on a container's filesystem
#   events      Get real time events from the server
#   export      Export a container's filesystem as a tar archive
#   history     Show the history of an image
#   import      Import the contents from a tarball to create a filesystem image
#   inspect     Return low-level information on Docker objects
#   kill        Kill one or more running containers
#   load        Load an image from a tar archive or STDIN
#   logs        Fetch the logs of a container
#   pause       Pause all processes within one or more containers
#   port        List port mappings or a specific mapping for the container
#   rename      Rename a container
#   restart     Restart one or more containers
#   rm          Remove one or more containers
#   rmi         Remove one or more images
#   save        Save one or more images to a tar archive (streamed to STDOUT by default)
#   start       Start one or more stopped containers
#   stats       Display a live stream of container(s) resource usage statistics
#   stop        Stop one or more running containers
#   tag         Create a tag TARGET_IMAGE that refers to SOURCE_IMAGE
#   top         Display the running processes of a container
#   unpause     Unpause all processes within one or more containers
#   update      Update configuration of one or more containers
#   wait        Block until one or more containers stop, then print their exit codes
#
# Global Options:
#       --config string      Location of client config files (default
#                            "/home/rocky/.docker")
#   -c, --context string     Name of the context to use to connect to the
#                            daemon (overrides DOCKER_HOST env var and
#                            default context set with "docker context use")
#   -D, --debug              Enable debug mode
#   -H, --host list          Daemon socket to connect to
#   -l, --log-level string   Set the logging level ("debug", "info",
#                            "warn", "error", "fatal") (default "info")
#       --tls                Use TLS; implied by --tlsverify
#       --tlscacert string   Trust certs signed only by this CA (default
#                            "/home/rocky/.docker/ca.pem")
#       --tlscert string     Path to TLS certificate file (default
#                            "/home/rocky/.docker/cert.pem")
#       --tlskey string      Path to TLS key file (default
#                            "/home/rocky/.docker/key.pem")
#       --tlsverify          Use TLS and verify the remote
#   -v, --version            Print version information and quit
#
# Run 'docker COMMAND --help' for more information on a command.
#
# For more help on how to use Docker, head to https://docs.docker.com/go/guides/
#  Created symlink /etc/systemd/system/multi-user.target.wants/docker.service → /usr/lib/systemd/system/docker.service.
#
#  Verify installtion... on UTAH
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#   pull        Download an image from a registry
#   push        Upload an image to a registry
#   images      List images
#   login       Log in to a registry
#   logout      Log out from a registry
#   search      Search Docker Hub for images
#   version     Show the Docker version information
#   info        Display system-wide information
#
# Management Commands:
#   builder     Manage builds
#   buildx*     Docker Buildx (Docker Inc., v0.10.5)
#   checkpoint  Manage checkpoints
#   compose*    Docker Compose (Docker Inc., v2.18.1)
#   container   Manage containers
#   context     Manage contexts
#   image       Manage images
#   manifest    Manage Docker image manifests and manifest lists
#   network     Manage networks
#   plugin      Manage plugins
#   system      Manage Docker
#   trust       Manage trust on Docker images
#   volume      Manage volumes
#
# Swarm Commands:
#   swarm       Manage Swarm
#
# Commands:
#   attach      Attach local standard input, output, and error streams to a running container
#   commit      Create a new image from a container's changes
#   cp          Copy files/folders between a container and the local filesystem
#   create      Create a new container
#   diff        Inspect changes to files or directories on a container's filesystem
#   events      Get real time events from the server
#   export      Export a container's filesystem as a tar archive
#   history     Show the history of an image
#   import      Import the contents from a tarball to create a filesystem image
#   inspect     Return low-level information on Docker objects
#   kill        Kill one or more running containers
#   load        Load an image from a tar archive or STDIN
#   logs        Fetch the logs of a container
#   pause       Pause all processes within one or more containers
#   port        List port mappings or a specific mapping for the container
#   rename      Rename a container
#   restart     Restart one or more containers
#   rm          Remove one or more containers
#   rmi         Remove one or more images
#   save        Save one or more images to a tar archive (streamed to STDOUT by default)
#   start       Start one or more stopped containers
#   stats       Display a live stream of container(s) resource usage statistics
#   stop        Stop one or more running containers
#   tag         Create a tag TARGET_IMAGE that refers to SOURCE_IMAGE
#   top         Display the running processes of a container
#   unpause     Unpause all processes within one or more containers
#   update      Update configuration of one or more containers
#   wait        Block until one or more containers stop, then print their exit codes
#
# Global Options:
#       --config string      Location of client config files (default
#                            "/home/rocky/.docker")
#   -c, --context string     Name of the context to use to connect to the
#                            daemon (overrides DOCKER_HOST env var and
#                            default context set with "docker context use")
#   -D, --debug              Enable debug mode
#   -H, --host list          Daemon socket to connect to
#   -l, --log-level string   Set the logging level ("debug", "info",
#                            "warn", "error", "fatal") (default "info")
#       --tls                Use TLS; implied by --tlsverify
#       --tlscacert string   Trust certs signed only by this CA (default
#                            "/home/rocky/.docker/ca.pem")
#       --tlscert string     Path to TLS certificate file (default
#                            "/home/rocky/.docker/cert.pem")
#       --tlskey string      Path to TLS key file (default
#                            "/home/rocky/.docker/key.pem")
#       --tlsverify          Use TLS and verify the remote
#   -v, --version            Print version information and quit
#
# Run 'docker COMMAND --help' for more information on a command.
#
# For more help on how to use Docker, head to https://docs.docker.com/go/guides/
#  Created symlink /etc/systemd/system/multi-user.target.wants/docker.service → /usr/lib/systemd/system/docker.service.
#
#  Verify installtion... on NCSA
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#   pull        Download an image from a registry
#   push        Upload an image to a registry
#   images      List images
#   login       Log in to a registry
#   logout      Log out from a registry
#   search      Search Docker Hub for images
#   version     Show the Docker version information
#   info        Display system-wide information
#
# Management Commands:
#   builder     Manage builds
#   buildx*     Docker Buildx (Docker Inc., v0.10.5)
#   checkpoint  Manage checkpoints
#   compose*    Docker Compose (Docker Inc., v2.18.1)
#   container   Manage containers
#   context     Manage contexts
#   image       Manage images
#   manifest    Manage Docker image manifests and manifest lists
#   network     Manage networks
#   plugin      Manage plugins
#   system      Manage Docker
#   trust       Manage trust on Docker images
#   volume      Manage volumes
#
# Swarm Commands:
#   swarm       Manage Swarm
#
# Commands:
#   attach      Attach local standard input, output, and error streams to a running container
#   commit      Create a new image from a container's changes
#   cp          Copy files/folders between a container and the local filesystem
#   create      Create a new container
#   diff        Inspect changes to files or directories on a container's filesystem
#   events      Get real time events from the server
#   export      Export a container's filesystem as a tar archive
#   history     Show the history of an image
#   import      Import the contents from a tarball to create a filesystem image
#   inspect     Return low-level information on Docker objects
#   kill        Kill one or more running containers
#   load        Load an image from a tar archive or STDIN
#   logs        Fetch the logs of a container
#   pause       Pause all processes within one or more containers
#   port        List port mappings or a specific mapping for the container
#   rename      Rename a container
#   restart     Restart one or more containers
#   rm          Remove one or more containers
#   rmi         Remove one or more images
#   save        Save one or more images to a tar archive (streamed to STDOUT by default)
#   start       Start one or more stopped containers
#   stats       Display a live stream of container(s) resource usage statistics
#   stop        Stop one or more running containers
#   tag         Create a tag TARGET_IMAGE that refers to SOURCE_IMAGE
#   top         Display the running processes of a container
#   unpause     Unpause all processes within one or more containers
#   update      Update configuration of one or more containers
#   wait        Block until one or more containers stop, then print their exit codes
#
# Global Options:
#       --config string      Location of client config files (default
#                            "/home/rocky/.docker")
#   -c, --context string     Name of the context to use to connect to the
#                            daemon (overrides DOCKER_HOST env var and
#                            default context set with "docker context use")
#   -D, --debug              Enable debug mode
#   -H, --host list          Daemon socket to connect to
#   -l, --log-level string   Set the logging level ("debug", "info",
#                            "warn", "error", "fatal") (default "info")
#       --tls                Use TLS; implied by --tlsverify
#       --tlscacert string   Trust certs signed only by this CA (default
#                            "/home/rocky/.docker/ca.pem")
#       --tlscert string     Path to TLS certificate file (default
#                            "/home/rocky/.docker/cert.pem")
#       --tlskey string      Path to TLS key file (default
#                            "/home/rocky/.docker/key.pem")
#       --tlsverify          Use TLS and verify the remote
#   -v, --version            Print version information and quit
#
# Run 'docker COMMAND --help' for more information on a command.
#
# For more help on how to use Docker, head to https://docs.docker.com/go/guides/
#  Created symlink /etc/systemd/system/multi-user.target.wants/docker.service → /usr/lib/systemd/system/docker.service.
#
#  Verify installtion... on UCSD
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#   pull        Download an image from a registry
#   push        Upload an image to a registry
#   images      List images
#   login       Log in to a registry
#   logout      Log out from a registry
#   search      Search Docker Hub for images
#   version     Show the Docker version information
#   info        Display system-wide information
#
# Management Commands:
#   builder     Manage builds
#   buildx*     Docker Buildx (Docker Inc., v0.10.4)
#   checkpoint  Manage checkpoints
#   compose*    Docker Compose (Docker Inc., v2.17.2)
#   container   Manage containers
#   context     Manage contexts
#   image       Manage images
#   manifest    Manage Docker image manifests and manifest lists
#   network     Manage networks
#   plugin      Manage plugins
#   system      Manage Docker
#   trust       Manage trust on Docker images
#   volume      Manage volumes
#
# Swarm Commands:
#   swarm       Manage Swarm
#
# Commands:
#   attach      Attach local standard input, output, and error streams to a running container
#   commit      Create a new image from a container's changes
#   cp          Copy files/folders between a container and the local filesystem
#   create      Create a new container
#   diff        Inspect changes to files or directories on a container's filesystem
#   events      Get real time events from the server
#   export      Export a container's filesystem as a tar archive
#   history     Show the history of an image
#   import      Import the contents from a tarball to create a filesystem image
#   inspect     Return low-level information on Docker objects
#   kill        Kill one or more running containers
#   load        Load an image from a tar archive or STDIN
#   logs        Fetch the logs of a container
#   pause       Pause all processes within one or more containers
#   port        List port mappings or a specific mapping for the container
#   rename      Rename a container
#   restart     Restart one or more containers
#   rm          Remove one or more containers
#   rmi         Remove one or more images
#   save        Save one or more images to a tar archive (streamed to STDOUT by default)
#   start       Start one or more stopped containers
#   stats       Display a live stream of container(s) resource usage statistics
#   stop        Stop one or more running containers
#   tag         Create a tag TARGET_IMAGE that refers to SOURCE_IMAGE
#   top         Display the running processes of a container
#   unpause     Unpause all processes within one or more containers
#   update      Update configuration of one or more containers
#   wait        Block until one or more containers stop, then print their exit codes
#
# Global Options:
#       --config string      Location of client config files (default
#                            "/home/rocky/.docker")
#   -c, --context string     Name of the context to use to connect to the
#                            daemon (overrides DOCKER_HOST env var and
#                            default context set with "docker context use")
#   -D, --debug              Enable debug mode
#   -H, --host list          Daemon socket(s) to connect to
#   -l, --log-level string   Set the logging level ("debug", "info",
#                            "warn", "error", "fatal") (default "info")
#       --tls                Use TLS; implied by --tlsverify
#       --tlscacert string   Trust certs signed only by this CA (default
#                            "/home/rocky/.docker/ca.pem")
#       --tlscert string     Path to TLS certificate file (default
#                            "/home/rocky/.docker/cert.pem")
#       --tlskey string      Path to TLS key file (default
#                            "/home/rocky/.docker/key.pem")
#       --tlsverify          Use TLS and verify the remote
#   -v, --version            Print version information and quit
#
# Run 'docker COMMAND --help' for more information on a command.
#
# For more help on how to use Docker, head to https://docs.docker.com/go/guides/
#  Created symlink /etc/systemd/system/multi-user.target.wants/docker.service → /usr/lib/systemd/system/docker.service.
#
#  Verify installtion... on FIU
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#   pull        Download an image from a registry
#   push        Upload an image to a registry
#   images      List images
#   login       Log in to a registry
#   logout      Log out from a registry
#   search      Search Docker Hub for images
#   version     Show the Docker version information
#   info        Display system-wide information
#
# Management Commands:
#   builder     Manage builds
#   buildx*     Docker Buildx (Docker Inc., v0.10.4)
#   checkpoint  Manage checkpoints
#   compose*    Docker Compose (Docker Inc., v2.17.2)
#   container   Manage containers
#   context     Manage contexts
#   image       Manage images
#   manifest    Manage Docker image manifests and manifest lists
#   network     Manage networks
#   plugin      Manage plugins
#   system      Manage Docker
#   trust       Manage trust on Docker images
#   volume      Manage volumes
#
# Swarm Commands:
#   swarm       Manage Swarm
#
# Commands:
#   attach      Attach local standard input, output, and error streams to a running container
#   commit      Create a new image from a container's changes
#   cp          Copy files/folders between a container and the local filesystem
#   create      Create a new container
#   diff        Inspect changes to files or directories on a container's filesystem
#   events      Get real time events from the server
#   export      Export a container's filesystem as a tar archive
#   history     Show the history of an image
#   import      Import the contents from a tarball to create a filesystem image
#   inspect     Return low-level information on Docker objects
#   kill        Kill one or more running containers
#   load        Load an image from a tar archive or STDIN
#   logs        Fetch the logs of a container
#   pause       Pause all processes within one or more containers
#   port        List port mappings or a specific mapping for the container
#   rename      Rename a container
#   restart     Restart one or more containers
#   rm          Remove one or more containers
#   rmi         Remove one or more images
#   save        Save one or more images to a tar archive (streamed to STDOUT by default)
#   start       Start one or more stopped containers
#   stats       Display a live stream of container(s) resource usage statistics
#   stop        Stop one or more running containers
#   tag         Create a tag TARGET_IMAGE that refers to SOURCE_IMAGE
#   top         Display the running processes of a container
#   unpause     Unpause all processes within one or more containers
#   update      Update configuration of one or more containers
#   wait        Block until one or more containers stop, then print their exit codes
#
# Global Options:
#       --config string      Location of client config files (default
#                            "/home/rocky/.docker")
#   -c, --context string     Name of the context to use to connect to the
#                            daemon (overrides DOCKER_HOST env var and
#                            default context set with "docker context use")
#   -D, --debug              Enable debug mode
#   -H, --host list          Daemon socket(s) to connect to
#   -l, --log-level string   Set the logging level ("debug", "info",
#                            "warn", "error", "fatal") (default "info")
#       --tls                Use TLS; implied by --tlsverify
#       --tlscacert string   Trust certs signed only by this CA (default
#                            "/home/rocky/.docker/ca.pem")
#       --tlscert string     Path to TLS certificate file (default
#                            "/home/rocky/.docker/cert.pem")
#       --tlskey string      Path to TLS key file (default
#                            "/home/rocky/.docker/key.pem")
#       --tlsverify          Use TLS and verify the remote
#   -v, --version            Print version information and quit
#
# Run 'docker COMMAND --help' for more information on a command.
#
# For more help on how to use Docker, head to https://docs.docker.com/go/guides/
#  Created symlink /etc/systemd/system/multi-user.target.wants/docker.service → /usr/lib/systemd/system/docker.service.
#
#  Verify installtion... on CLEM
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#   pull        Download an image from a registry
#   push        Upload an image to a registry
#   images      List images
#   login       Log in to a registry
#   logout      Log out from a registry
#   search      Search Docker Hub for images
#   version     Show the Docker version information
#   info        Display system-wide information
#
# Management Commands:
#   builder     Manage builds
#   buildx*     Docker Buildx (Docker Inc., v0.10.4)
#   checkpoint  Manage checkpoints
#   compose*    Docker Compose (Docker Inc., v2.17.2)
#   container   Manage containers
#   context     Manage contexts
#   image       Manage images
#   manifest    Manage Docker image manifests and manifest lists
#   network     Manage networks
#   plugin      Manage plugins
#   system      Manage Docker
#   trust       Manage trust on Docker images
#   volume      Manage volumes
#
# Swarm Commands:
#   swarm       Manage Swarm
#
# Commands:
#   attach      Attach local standard input, output, and error streams to a running container
#   commit      Create a new image from a container's changes
#   cp          Copy files/folders between a container and the local filesystem
#   create      Create a new container
#   diff        Inspect changes to files or directories on a container's filesystem
#   events      Get real time events from the server
#   export      Export a container's filesystem as a tar archive
#   history     Show the history of an image
#   import      Import the contents from a tarball to create a filesystem image
#   inspect     Return low-level information on Docker objects
#   kill        Kill one or more running containers
#   load        Load an image from a tar archive or STDIN
#   logs        Fetch the logs of a container
#   pause       Pause all processes within one or more containers
#   port        List port mappings or a specific mapping for the container
#   rename      Rename a container
#   restart     Restart one or more containers
#   rm          Remove one or more containers
#   rmi         Remove one or more images
#   save        Save one or more images to a tar archive (streamed to STDOUT by default)
#   start       Start one or more stopped containers
#   stats       Display a live stream of container(s) resource usage statistics
#   stop        Stop one or more running containers
#   tag         Create a tag TARGET_IMAGE that refers to SOURCE_IMAGE
#   top         Display the running processes of a container
#   unpause     Unpause all processes within one or more containers
#   update      Update configuration of one or more containers
#   wait        Block until one or more containers stop, then print their exit codes
#
# Global Options:
#       --config string      Location of client config files (default
#                            "/home/rocky/.docker")
#   -c, --context string     Name of the context to use to connect to the
#                            daemon (overrides DOCKER_HOST env var and
#                            default context set with "docker context use")
#   -D, --debug              Enable debug mode
#   -H, --host list          Daemon socket(s) to connect to
#   -l, --log-level string   Set the logging level ("debug", "info",
#                            "warn", "error", "fatal") (default "info")
#       --tls                Use TLS; implied by --tlsverify
#       --tlscacert string   Trust certs signed only by this CA (default
#                            "/home/rocky/.docker/ca.pem")
#       --tlscert string     Path to TLS certificate file (default
#                            "/home/rocky/.docker/cert.pem")
#       --tlskey string      Path to TLS key file (default
#                            "/home/rocky/.docker/key.pem")
#       --tlsverify          Use TLS and verify the remote
#   -v, --version            Print version information and quit
#
# Run 'docker COMMAND --help' for more information on a command.
#
# For more help on how to use Docker, head to https://docs.docker.com/go/guides/
#  Created symlink /etc/systemd/system/multi-user.target.wants/docker.service → /usr/lib/systemd/system/docker.service.
#
#  Verify installtion... on CERN
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#   pull        Download an image from a registry
#   push        Upload an image to a registry
#   images      List images
#   login       Log in to a registry
#   logout      Log out from a registry
#   search      Search Docker Hub for images
#   version     Show the Docker version information
#   info        Display system-wide information
#
# Management Commands:
#   builder     Manage builds
#   buildx*     Docker Buildx (Docker Inc., v0.10.4)
#   checkpoint  Manage checkpoints
#   compose*    Docker Compose (Docker Inc., v2.17.2)
#   container   Manage containers
#   context     Manage contexts
#   image       Manage images
#   manifest    Manage Docker image manifests and manifest lists
#   network     Manage networks
#   plugin      Manage plugins
#   system      Manage Docker
#   trust       Manage trust on Docker images
#   volume      Manage volumes
#
# Swarm Commands:
#   swarm       Manage Swarm
#
# Commands:
#   attach      Attach local standard input, output, and error streams to a running container
#   commit      Create a new image from a container's changes
#   cp          Copy files/folders between a container and the local filesystem
#   create      Create a new container
#   diff        Inspect changes to files or directories on a container's filesystem
#   events      Get real time events from the server
#   export      Export a container's filesystem as a tar archive
#   history     Show the history of an image
#   import      Import the contents from a tarball to create a filesystem image
#   inspect     Return low-level information on Docker objects
#   kill        Kill one or more running containers
#   load        Load an image from a tar archive or STDIN
#   logs        Fetch the logs of a container
#   pause       Pause all processes within one or more containers
#   port        List port mappings or a specific mapping for the container
#   rename      Rename a container
#   restart     Restart one or more containers
#   rm          Remove one or more containers
#   rmi         Remove one or more images
#   save        Save one or more images to a tar archive (streamed to STDOUT by default)
#   start       Start one or more stopped containers
#   stats       Display a live stream of container(s) resource usage statistics
#   stop        Stop one or more running containers
#   tag         Create a tag TARGET_IMAGE that refers to SOURCE_IMAGE
#   top         Display the running processes of a container
#   unpause     Unpause all processes within one or more containers
#   update      Update configuration of one or more containers
#   wait        Block until one or more containers stop, then print their exit codes
#
# Global Options:
#       --config string      Location of client config files (default
#                            "/home/rocky/.docker")
#   -c, --context string     Name of the context to use to connect to the
#                            daemon (overrides DOCKER_HOST env var and
#                            default context set with "docker context use")
#   -D, --debug              Enable debug mode
#   -H, --host list          Daemon socket(s) to connect to
#   -l, --log-level string   Set the logging level ("debug", "info",
#                            "warn", "error", "fatal") (default "info")
#       --tls                Use TLS; implied by --tlsverify
#       --tlscacert string   Trust certs signed only by this CA (default
#                            "/home/rocky/.docker/ca.pem")
#       --tlscert string     Path to TLS certificate file (default
#                            "/home/rocky/.docker/cert.pem")
#       --tlskey string      Path to TLS key file (default
#                            "/home/rocky/.docker/key.pem")
#       --tlsverify          Use TLS and verify the remote
#   -v, --version            Print version information and quit
#
# Run 'docker COMMAND --help' for more information on a command.
#
# For more help on how to use Docker, head to https://docs.docker.com/go/guides/

# %% [markdown]
# # (Optional) Extend the slice (Add 14 days)

# %%
try:
    slice = fablib.get_slice(name=slice_name)
    print(f"Lease End         : {slice.get_lease_end()}")
       
except Exception as e:
    print(f"Exception: {e}")
# Out:
# Lease End         : 2023-11-19 06:01:27 +0000

# %%
import datetime

#Extend slice
end_date = (datetime.datetime.now().astimezone() + datetime.timedelta(days=14)).strftime("%Y-%m-%d %H:%M:%S %z")

try:
    slice = fablib.get_slice(name=slice_name)
    slice.renew(end_date)
    print(f"New lease end date : {slice.get_lease_end()}")
    
except Exception as e:
    print(f"Exception: {e}")
# Out:
# New lease end date : 2023-11-19 06:01:27 +0000

# %% [markdown]
# # Delete the Slice

# %%
"""
try:
    slice = fablib.get_slice(name=slice_name)
    slice.delete()
except Exception as e:
    print(f"Exception: {e}")
"""

# %% [markdown]
# # Run OWL (One-Way Latency Measurements)
#
# Script for running OWL on one or more nodes in a slice. Output for each measurement is saved as a pcap file on the destination node.
# Current implementation on IPv4 experimenter interfaces only. Assumes each node has only 1 experimental interface.
#
# (Tested on 2023/08/18)

# %% [markdown]
# # First things first

# %%
from fabrictestbed_extensions.fablib.fablib import fablib
import json

# %%
slice_name = "PTP_slice_All"

try:
    slice = fablib.get_slice(name=slice_name)
except Exception as e:
    print(f"Fail: {e}")
print (slice)
# Out:
# -----------  ------------------------------------
# Slice Name   PTP_slice_All
# Slice ID     c2c2c7fa-5edd-40e6-979e-282e204fb892
# Slice State  ModifyError
# Lease End    2023-12-02 07:16:54 +0000
# -----------  ------------------------------------

# %%
from mflib import owl

# for debugging only
#import owl_local as owl

# %%
try:    
    node1 = slice.get_node(name=node_names[0])
    node2 = slice.get_node(name=node_names[1])
    node3 = slice.get_node(name=node_names[2])
    nodes = slice.get_nodes()
except Exception as e:
    print(f"Fail: {e}")

# %% [markdown]
# ## Look up IPs of nodes and decide which IP address to use
#
# Checking experiment IP addresses by filtering out meas_network addresses. Asssumes one experimenter interface per node.

# %%
node_ip_list = owl.nodes_ip_addrs(slice)
print(node_ip_list)
# Out:
# {'STAR': '10.129.129.2', 'MAX': '10.130.7.2', 'MICH': '10.131.3.2', 'MASS': '10.131.132.2', 'UTAH': '10.132.5.2', 'NCSA': '10.132.131.2', 'UCSD': '10.134.130.2', 'FIU': '10.135.133.2', 'CLEM': '10.136.2.2', 'CERN': '10.143.2.2'}

# %% [markdown]
# ## Check OWL prerequisites on all nodes in the slice
#
# Runs the following test and prints output on each node:
#
# + `git clone`
# + `ps -ef | grep phc2sys`
# + `docker --help`

# %%
owl.check_owl_prerequisites(slice)
# Out:
# ***** On STAR...
#
# ***** Is github reachable?
#  Cloning into 'teaching-materials'...
#  total 8
# drwxrwxr-x. 6 rocky rocky 4096 Nov 18 06:13 jupyter-examples
# drwxrwxr-x. 5 rocky rocky 4096 Nov 18 07:22 teaching-materials
#
# ***** Is PTP is enabled?
# root       16914       1  0 06:47 ?        00:00:00 /usr/sbin/phc2sys -u 8 -E linreg -O +0 -s /dev/ptp1 -c enp7s0
# root       17412       1  0 06:47 ?        00:00:00 /usr/sbin/phc2sys -u 8 -E linreg -O +0 -s /dev/ptp1 -c CLOCK_REALTIME
# rocky      26918   26917  0 07:22 ?        00:00:00 bash -c ps -ef | grep phc2sys
# rocky      26938   26918  0 07:22 ?        00:00:00 grep phc2sys
#
# *****Is Docker installed?
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#
# ***** On MAX...
#
# ***** Is github reachable?
#  Cloning into 'teaching-materials'...
#  total 8
# drwxrwxr-x. 6 rocky rocky 4096 Nov 18 06:17 jupyter-examples
# drwxrwxr-x. 5 rocky rocky 4096 Nov 18 07:22 teaching-materials
#
# ***** Is PTP is enabled?
# root       26163       1  0 06:49 ?        00:00:00 /usr/sbin/phc2sys -u 8 -E linreg -O +0 -s /dev/ptp1 -c enp7s0
# root       26215       1  0 06:49 ?        00:00:00 /usr/sbin/phc2sys -u 8 -E linreg -O +0 -s /dev/ptp1 -c CLOCK_REALTIME
# rocky      26802   26801  0 07:22 ?        00:00:00 bash -c ps -ef | grep phc2sys
# rocky      26822   26802  0 07:22 ?        00:00:00 grep phc2sys
#
# *****Is Docker installed?
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#
# ***** On MICH...
#
# ***** Is github reachable?
#  Cloning into 'teaching-materials'...
#  total 8
# drwxrwxr-x. 6 rocky rocky 4096 Nov 18 06:18 jupyter-examples
# drwxrwxr-x. 5 rocky rocky 4096 Nov 18 07:22 teaching-materials
#
# ***** Is PTP is enabled?
# root       18173       1  0 06:50 ?        00:00:00 /usr/sbin/phc2sys -u 8 -E linreg -O +0 -s /dev/ptp1 -c enp7s0
# root       18780       1  0 06:50 ?        00:00:00 /usr/sbin/phc2sys -u 8 -E linreg -O +0 -s /dev/ptp1 -c CLOCK_REALTIME
# rocky      26879   26878  0 07:22 ?        00:00:00 bash -c ps -ef | grep phc2sys
# rocky      26899   26879  0 07:22 ?        00:00:00 grep phc2sys
#
# *****Is Docker installed?
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#
# ***** On MASS...
#
# ***** Is github reachable?
#  Cloning into 'teaching-materials'...
#  total 8
# drwxrwxr-x. 6 rocky rocky 4096 Nov 18 06:22 jupyter-examples
# drwxrwxr-x. 5 rocky rocky 4096 Nov 18 07:23 teaching-materials
#
# ***** Is PTP is enabled?
# root       26138       1  0 06:51 ?        00:00:00 /usr/sbin/phc2sys -u 8 -E linreg -O +0 -s /dev/ptp1 -c enp7s0
# root       26190       1  0 06:51 ?        00:00:00 /usr/sbin/phc2sys -u 8 -E linreg -O +0 -s /dev/ptp1 -c CLOCK_REALTIME
# rocky      26786   26785  0 07:23 ?        00:00:00 bash -c ps -ef | grep phc2sys
# rocky      26806   26786  0 07:23 ?        00:00:00 grep phc2sys
#
# *****Is Docker installed?
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#
# ***** On UTAH...
#
# ***** Is github reachable?
#  Cloning into 'teaching-materials'...
#  total 8
# drwxrwxr-x. 6 rocky rocky 4096 Nov 18 06:22 jupyter-examples
# drwxrwxr-x. 5 rocky rocky 4096 Nov 18 07:23 teaching-materials
#
# ***** Is PTP is enabled?
# root       18229       1  0 06:54 ?        00:00:00 /usr/sbin/phc2sys -u 8 -E linreg -O +0 -s /dev/ptp1 -c enp7s0
# root       18776       1  0 06:54 ?        00:00:00 /usr/sbin/phc2sys -u 8 -E linreg -O +0 -s /dev/ptp1 -c CLOCK_REALTIME
# rocky      26845   26844  0 07:23 ?        00:00:00 bash -c ps -ef | grep phc2sys
# rocky      26865   26845  0 07:23 ?        00:00:00 grep phc2sys
#
# *****Is Docker installed?
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#
# ***** On NCSA...
#
# ***** Is github reachable?
#  Cloning into 'teaching-materials'...
#  total 8
# drwxrwxr-x. 6 rocky rocky 4096 Nov 18 06:23 jupyter-examples
# drwxrwxr-x. 5 rocky rocky 4096 Nov 18 07:23 teaching-materials
#
# ***** Is PTP is enabled?
# root       16932       1  0 06:54 ?        00:00:00 /usr/sbin/phc2sys -u 8 -E linreg -O +0 -s /dev/ptp1 -c enp7s0
# root       17183       1  0 06:54 ?        00:00:00 /usr/sbin/phc2sys -u 8 -E linreg -O +0 -s /dev/ptp1 -c CLOCK_REALTIME
# rocky      26832   26831  0 07:23 ?        00:00:00 bash -c ps -ef | grep phc2sys
# rocky      26852   26832  0 07:23 ?        00:00:00 grep phc2sys
#
# *****Is Docker installed?
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#
# ***** On UCSD...
#
# ***** Is github reachable?
#  Cloning into 'teaching-materials'...
#  total 8
# drwxrwxr-x. 6 rocky rocky 4096 Nov 18 06:28 jupyter-examples
# drwxrwxr-x. 5 rocky rocky 4096 Nov 18 07:23 teaching-materials
#
# ***** Is PTP is enabled?
# root       27589       1  0 06:56 ?        00:00:00 /usr/sbin/phc2sys -u 8 -E linreg -O +0 -s /dev/ptp1 -c enp6s0
# root       27640       1  0 06:56 ?        00:00:00 /usr/sbin/phc2sys -u 8 -E linreg -O +0 -s /dev/ptp1 -c CLOCK_REALTIME
# rocky      28192   28191  0 07:23 ?        00:00:00 bash -c ps -ef | grep phc2sys
# rocky      28212   28192  0 07:23 ?        00:00:00 grep phc2sys
#
# *****Is Docker installed?
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#
# ***** On FIU...
#
# ***** Is github reachable?
#  Cloning into 'teaching-materials'...
#  total 8
# drwxrwxr-x. 6 rocky rocky 4096 Nov 18 06:32 jupyter-examples
# drwxrwxr-x. 5 rocky rocky 4096 Nov 18 07:24 teaching-materials
#
# ***** Is PTP is enabled?
# root       27576       1  0 06:58 ?        00:00:00 /usr/sbin/phc2sys -u 8 -E linreg -O +0 -s /dev/ptp1 -c enp6s0
# root       27627       1  0 06:58 ?        00:00:00 /usr/sbin/phc2sys -u 8 -E linreg -O +0 -s /dev/ptp1 -c CLOCK_REALTIME
# rocky      28187   28186  0 07:24 ?        00:00:00 bash -c ps -ef | grep phc2sys
# rocky      28207   28187  0 07:24 ?        00:00:00 grep phc2sys
#
# *****Is Docker installed?
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#
# ***** On CLEM...
#
# ***** Is github reachable?
#  Cloning into 'teaching-materials'...
#  total 8
# drwxrwxr-x. 6 rocky rocky 4096 Nov 18 06:35 jupyter-examples
# drwxrwxr-x. 5 rocky rocky 4096 Nov 18 07:24 teaching-materials
#
# ***** Is PTP is enabled?
# root       27623       1  0 06:58 ?        00:00:00 /usr/sbin/phc2sys -u 8 -E linreg -O +0 -s /dev/ptp1 -c enp6s0
# root       27674       1  0 06:58 ?        00:00:00 /usr/sbin/phc2sys -u 8 -E linreg -O +0 -s /dev/ptp1 -c CLOCK_REALTIME
# rocky      28224   28223  0 07:24 ?        00:00:00 bash -c ps -ef | grep phc2sys
# rocky      28244   28224  0 07:24 ?        00:00:00 grep phc2sys
#
# *****Is Docker installed?
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile
#
# ***** On CERN...
#
# ***** Is github reachable?
#  Cloning into 'teaching-materials'...
#  total 8
# drwxrwxr-x. 6 rocky rocky 4096 Nov 18 06:37 jupyter-examples
# drwxrwxr-x. 5 rocky rocky 4096 Nov 18 07:24 teaching-materials
#
# ***** Is PTP is enabled?
# root       27631       1  0 06:59 ?        00:00:00 /usr/sbin/phc2sys -u 8 -E linreg -O +0 -s /dev/ptp1 -c enp7s0
# root       27682       1  0 06:59 ?        00:00:00 /usr/sbin/phc2sys -u 8 -E linreg -O +0 -s /dev/ptp1 -c CLOCK_REALTIME
# rocky      28237   28236  0 07:24 ?        00:00:00 bash -c ps -ef | grep phc2sys
# rocky      28257   28237  0 07:24 ?        00:00:00 grep phc2sys
#
# *****Is Docker installed?
#
# Usage:  docker [OPTIONS] COMMAND
#
# A self-sufficient runtime for containers
#
# Common Commands:
#   run         Create and run a new container from an image
#   exec        Execute a command in a running container
#   ps          List containers
#   build       Build an image from a Dockerfile

# %% [markdown]
# ## Pull OWL image from DockerHub

# %%
image_name="fabrictestbed/owl:0.1.4"

for node in nodes:
    node.execute(f"sudo docker pull {image_name}")
# Out:
# 0.1.4: Pulling from fabrictestbed/owl
# 8b91b88d5577: Pulling fs layer
# 824416e23423: Pulling fs layer
# 8d53da260408: Pulling fs layer
# 84c8c79126f6: Pulling fs layer
# 2e1c130fa3ec: Pulling fs layer
# e9571e66d363: Pulling fs layer
# c2426a8d87d1: Pulling fs layer
# 5922e7f17bf6: Pulling fs layer
# 7935dece71a7: Pulling fs layer
# aa4bd601fd3f: Pulling fs layer
# 6d94b93994d0: Pulling fs layer
# e1e2036205d2: Pulling fs layer
# 895f77b56ce1: Pulling fs layer
# 84c8c79126f6: Waiting
# 2e1c130fa3ec: Waiting
# c2426a8d87d1: Waiting
# e9571e66d363: Waiting
# 5922e7f17bf6: Waiting
# 7935dece71a7: Waiting
# 6d94b93994d0: Waiting
# e1e2036205d2: Waiting
# aa4bd601fd3f: Waiting
# 895f77b56ce1: Waiting
# 824416e23423: Verifying Checksum
# 824416e23423: Download complete
# 8d53da260408: Verifying Checksum
# 8d53da260408: Download complete
# 84c8c79126f6: Verifying Checksum
# 84c8c79126f6: Download complete
# 2e1c130fa3ec: Verifying Checksum
# 2e1c130fa3ec: Download complete
# 8b91b88d5577: Verifying Checksum
# 8b91b88d5577: Download complete
# c2426a8d87d1: Verifying Checksum
# c2426a8d87d1: Download complete
# 7935dece71a7: Verifying Checksum
# 7935dece71a7: Download complete
# 5922e7f17bf6: Verifying Checksum
# 5922e7f17bf6: Download complete
# 8b91b88d5577: Pull complete
# 824416e23423: Pull complete
# 6d94b93994d0: Verifying Checksum
# 6d94b93994d0: Download complete
# e9571e66d363: Verifying Checksum
# e9571e66d363: Download complete
# 8d53da260408: Pull complete
# 84c8c79126f6: Pull complete
# e1e2036205d2: Verifying Checksum
# e1e2036205d2: Download complete
# 895f77b56ce1: Verifying Checksum
# 895f77b56ce1: Download complete
# 2e1c130fa3ec: Pull complete
# aa4bd601fd3f: Verifying Checksum
# aa4bd601fd3f: Download complete
# e9571e66d363: Pull complete
# c2426a8d87d1: Pull complete
# 5922e7f17bf6: Pull complete
# 7935dece71a7: Pull complete
# aa4bd601fd3f: Pull complete
# 6d94b93994d0: Pull complete
# e1e2036205d2: Pull complete
# 895f77b56ce1: Pull complete
# Digest: sha256:7b50ef5ed9eb6c2fa293d85b842251370d12cdb759a18e52bbcff72905bae4f7
# Status: Downloaded newer image for fabrictestbed/owl:0.1.4
# docker.io/fabrictestbed/owl:0.1.4
# 0.1.4: Pulling from fabrictestbed/owl
# 8b91b88d5577: Pulling fs layer
# 824416e23423: Pulling fs layer
# 8d53da260408: Pulling fs layer
# 84c8c79126f6: Pulling fs layer
# 2e1c130fa3ec: Pulling fs layer
# e9571e66d363: Pulling fs layer
# c2426a8d87d1: Pulling fs layer
# 5922e7f17bf6: Pulling fs layer
# 7935dece71a7: Pulling fs layer
# aa4bd601fd3f: Pulling fs layer
# 6d94b93994d0: Pulling fs layer
# e1e2036205d2: Pulling fs layer
# 895f77b56ce1: Pulling fs layer
# c2426a8d87d1: Waiting
# 5922e7f17bf6: Waiting
# 7935dece71a7: Waiting
# aa4bd601fd3f: Waiting
# 6d94b93994d0: Waiting
# e1e2036205d2: Waiting
# 895f77b56ce1: Waiting
# 84c8c79126f6: Waiting
# 2e1c130fa3ec: Waiting
# e9571e66d363: Waiting
# 824416e23423: Verifying Checksum
# 824416e23423: Download complete
# 8d53da260408: Verifying Checksum
# 8d53da260408: Download complete
# 8b91b88d5577: Verifying Checksum
# 8b91b88d5577: Download complete
# 8b91b88d5577: Pull complete
# 824416e23423: Pull complete
# 8d53da260408: Pull complete
# 84c8c79126f6: Verifying Checksum
# 84c8c79126f6: Download complete
# 84c8c79126f6: Pull complete
# 2e1c130fa3ec: Verifying Checksum
# 2e1c130fa3ec: Download complete
# 2e1c130fa3ec: Pull complete
# e9571e66d363: Verifying Checksum
# e9571e66d363: Download complete
# e9571e66d363: Pull complete
# 7935dece71a7: Verifying Checksum
# 7935dece71a7: Download complete
# 5922e7f17bf6: Verifying Checksum
# 5922e7f17bf6: Download complete
# c2426a8d87d1: Verifying Checksum
# c2426a8d87d1: Download complete
# c2426a8d87d1: Pull complete
# 5922e7f17bf6: Pull complete
# 7935dece71a7: Pull complete
# 6d94b93994d0: Verifying Checksum
# 6d94b93994d0: Download complete
# e1e2036205d2: Verifying Checksum
# e1e2036205d2: Download complete
# aa4bd601fd3f: Verifying Checksum
# aa4bd601fd3f: Download complete
# aa4bd601fd3f: Pull complete
# 6d94b93994d0: Pull complete
# e1e2036205d2: Pull complete
# 895f77b56ce1: Verifying Checksum
# 895f77b56ce1: Download complete
# 895f77b56ce1: Pull complete
# Digest: sha256:7b50ef5ed9eb6c2fa293d85b842251370d12cdb759a18e52bbcff72905bae4f7
# Status: Downloaded newer image for fabrictestbed/owl:0.1.4
# docker.io/fabrictestbed/owl:0.1.4
# 0.1.4: Pulling from fabrictestbed/owl
# 8b91b88d5577: Pulling fs layer
# 824416e23423: Pulling fs layer
# 8d53da260408: Pulling fs layer
# 84c8c79126f6: Pulling fs layer
# 2e1c130fa3ec: Pulling fs layer
# e9571e66d363: Pulling fs layer
# c2426a8d87d1: Pulling fs layer
# 5922e7f17bf6: Pulling fs layer
# 7935dece71a7: Pulling fs layer
# aa4bd601fd3f: Pulling fs layer
# 6d94b93994d0: Pulling fs layer
# e1e2036205d2: Pulling fs layer
# 895f77b56ce1: Pulling fs layer
# 84c8c79126f6: Waiting
# 2e1c130fa3ec: Waiting
# e9571e66d363: Waiting
# c2426a8d87d1: Waiting
# 5922e7f17bf6: Waiting
# 7935dece71a7: Waiting
# aa4bd601fd3f: Waiting
# 6d94b93994d0: Waiting
# e1e2036205d2: Waiting
# 895f77b56ce1: Waiting
# 8d53da260408: Verifying Checksum
# 8d53da260408: Download complete
# 824416e23423: Verifying Checksum
# 824416e23423: Download complete
# 8b91b88d5577: Verifying Checksum
# 8b91b88d5577: Download complete
# 84c8c79126f6: Verifying Checksum
# 84c8c79126f6: Download complete
# 2e1c130fa3ec: Verifying Checksum
# 2e1c130fa3ec: Download complete
# c2426a8d87d1: Verifying Checksum
# c2426a8d87d1: Download complete
# 5922e7f17bf6: Verifying Checksum
# 5922e7f17bf6: Download complete
# 7935dece71a7: Download complete
# 6d94b93994d0: Verifying Checksum
# 6d94b93994d0: Download complete
# 8b91b88d5577: Pull complete
# e1e2036205d2: Verifying Checksum
# e1e2036205d2: Download complete
# 824416e23423: Pull complete
# aa4bd601fd3f: Verifying Checksum
# aa4bd601fd3f: Download complete
# 895f77b56ce1: Verifying Checksum
# 895f77b56ce1: Download complete
# e9571e66d363: Verifying Checksum
# e9571e66d363: Download complete
# 8d53da260408: Pull complete
# 84c8c79126f6: Pull complete
# 2e1c130fa3ec: Pull complete
# e9571e66d363: Pull complete
# c2426a8d87d1: Pull complete
# 5922e7f17bf6: Pull complete
# 7935dece71a7: Pull complete
# aa4bd601fd3f: Pull complete
# 6d94b93994d0: Pull complete
# e1e2036205d2: Pull complete
# 895f77b56ce1: Pull complete
# Digest: sha256:7b50ef5ed9eb6c2fa293d85b842251370d12cdb759a18e52bbcff72905bae4f7
# Status: Downloaded newer image for fabrictestbed/owl:0.1.4
# docker.io/fabrictestbed/owl:0.1.4
# 0.1.4: Pulling from fabrictestbed/owl
# 8b91b88d5577: Pulling fs layer
# 824416e23423: Pulling fs layer
# 8d53da260408: Pulling fs layer
# 84c8c79126f6: Pulling fs layer
# 2e1c130fa3ec: Pulling fs layer
# e9571e66d363: Pulling fs layer
# c2426a8d87d1: Pulling fs layer
# 5922e7f17bf6: Pulling fs layer
# 7935dece71a7: Pulling fs layer
# aa4bd601fd3f: Pulling fs layer
# 6d94b93994d0: Pulling fs layer
# e1e2036205d2: Pulling fs layer
# 895f77b56ce1: Pulling fs layer
# 5922e7f17bf6: Waiting
# 7935dece71a7: Waiting
# aa4bd601fd3f: Waiting
# 6d94b93994d0: Waiting
# e1e2036205d2: Waiting
# 895f77b56ce1: Waiting
# 2e1c130fa3ec: Waiting
# 84c8c79126f6: Waiting
# e9571e66d363: Waiting
# c2426a8d87d1: Waiting
# 824416e23423: Verifying Checksum
# 824416e23423: Download complete
# 8d53da260408: Verifying Checksum
# 8d53da260408: Download complete
# 8b91b88d5577: Verifying Checksum
# 8b91b88d5577: Download complete
# 8b91b88d5577: Pull complete
# 824416e23423: Pull complete
# 8d53da260408: Pull complete
# 84c8c79126f6: Verifying Checksum
# 84c8c79126f6: Download complete
# 84c8c79126f6: Pull complete
# 2e1c130fa3ec: Verifying Checksum
# 2e1c130fa3ec: Download complete
# 2e1c130fa3ec: Pull complete
# e9571e66d363: Verifying Checksum
# e9571e66d363: Download complete
# e9571e66d363: Pull complete
# 7935dece71a7: Verifying Checksum
# 7935dece71a7: Download complete
# c2426a8d87d1: Verifying Checksum
# c2426a8d87d1: Download complete
# 5922e7f17bf6: Verifying Checksum
# 5922e7f17bf6: Download complete
# c2426a8d87d1: Pull complete
# 5922e7f17bf6: Pull complete
# 7935dece71a7: Pull complete
# 6d94b93994d0: Verifying Checksum
# 6d94b93994d0: Download complete
# e1e2036205d2: Verifying Checksum
# e1e2036205d2: Download complete
# aa4bd601fd3f: Verifying Checksum
# aa4bd601fd3f: Download complete
# aa4bd601fd3f: Pull complete
# 6d94b93994d0: Pull complete
# e1e2036205d2: Pull complete
# 895f77b56ce1: Download complete
# 895f77b56ce1: Pull complete
# Digest: sha256:7b50ef5ed9eb6c2fa293d85b842251370d12cdb759a18e52bbcff72905bae4f7
# Status: Downloaded newer image for fabrictestbed/owl:0.1.4
# docker.io/fabrictestbed/owl:0.1.4
# 0.1.4: Pulling from fabrictestbed/owl
# 8b91b88d5577: Pulling fs layer
# 824416e23423: Pulling fs layer
# 8d53da260408: Pulling fs layer
# 84c8c79126f6: Pulling fs layer
# 2e1c130fa3ec: Pulling fs layer
# e9571e66d363: Pulling fs layer
# c2426a8d87d1: Pulling fs layer
# 5922e7f17bf6: Pulling fs layer
# 7935dece71a7: Pulling fs layer
# aa4bd601fd3f: Pulling fs layer
# 6d94b93994d0: Pulling fs layer
# e1e2036205d2: Pulling fs layer
# 895f77b56ce1: Pulling fs layer
# 84c8c79126f6: Waiting
# 2e1c130fa3ec: Waiting
# e9571e66d363: Waiting
# c2426a8d87d1: Waiting
# 5922e7f17bf6: Waiting
# 7935dece71a7: Waiting
# aa4bd601fd3f: Waiting
# 6d94b93994d0: Waiting
# e1e2036205d2: Waiting
# 895f77b56ce1: Waiting
# 824416e23423: Verifying Checksum
# 824416e23423: Download complete
# 8d53da260408: Download complete
# 8b91b88d5577: Verifying Checksum
# 8b91b88d5577: Download complete
# 84c8c79126f6: Verifying Checksum
# 84c8c79126f6: Download complete
# 2e1c130fa3ec: Verifying Checksum
# 2e1c130fa3ec: Download complete
# c2426a8d87d1: Verifying Checksum
# c2426a8d87d1: Download complete
# 8b91b88d5577: Pull complete
# 5922e7f17bf6: Verifying Checksum
# 5922e7f17bf6: Download complete
# 824416e23423: Pull complete
# 7935dece71a7: Verifying Checksum
# 7935dece71a7: Download complete
# 8d53da260408: Pull complete
# 84c8c79126f6: Pull complete
# 6d94b93994d0: Verifying Checksum
# 6d94b93994d0: Download complete
# e9571e66d363: Verifying Checksum
# e9571e66d363: Download complete
# 2e1c130fa3ec: Pull complete
# e1e2036205d2: Verifying Checksum
# e1e2036205d2: Download complete
# 895f77b56ce1: Verifying Checksum
# 895f77b56ce1: Download complete
# aa4bd601fd3f: Verifying Checksum
# aa4bd601fd3f: Download complete
# e9571e66d363: Pull complete
# c2426a8d87d1: Pull complete
# 5922e7f17bf6: Pull complete
# 7935dece71a7: Pull complete
# aa4bd601fd3f: Pull complete
# 6d94b93994d0: Pull complete
# e1e2036205d2: Pull complete
# 895f77b56ce1: Pull complete
# Digest: sha256:7b50ef5ed9eb6c2fa293d85b842251370d12cdb759a18e52bbcff72905bae4f7
# Status: Downloaded newer image for fabrictestbed/owl:0.1.4
# docker.io/fabrictestbed/owl:0.1.4
# 0.1.4: Pulling from fabrictestbed/owl
# 8b91b88d5577: Pulling fs layer
# 824416e23423: Pulling fs layer
# 8d53da260408: Pulling fs layer
# 84c8c79126f6: Pulling fs layer
# 2e1c130fa3ec: Pulling fs layer
# e9571e66d363: Pulling fs layer
# c2426a8d87d1: Pulling fs layer
# 5922e7f17bf6: Pulling fs layer
# 7935dece71a7: Pulling fs layer
# aa4bd601fd3f: Pulling fs layer
# 6d94b93994d0: Pulling fs layer
# e1e2036205d2: Pulling fs layer
# 895f77b56ce1: Pulling fs layer
# 5922e7f17bf6: Waiting
# 7935dece71a7: Waiting
# aa4bd601fd3f: Waiting
# 6d94b93994d0: Waiting
# 84c8c79126f6: Waiting
# 2e1c130fa3ec: Waiting
# e9571e66d363: Waiting
# c2426a8d87d1: Waiting
# e1e2036205d2: Waiting
# 895f77b56ce1: Waiting
# 824416e23423: Verifying Checksum
# 824416e23423: Download complete
# 8d53da260408: Verifying Checksum
# 8d53da260408: Download complete
# 8b91b88d5577: Verifying Checksum
# 8b91b88d5577: Download complete
# 84c8c79126f6: Verifying Checksum
# 84c8c79126f6: Download complete
# 2e1c130fa3ec: Verifying Checksum
# 2e1c130fa3ec: Download complete
# 5922e7f17bf6: Verifying Checksum
# 5922e7f17bf6: Download complete
# c2426a8d87d1: Verifying Checksum
# c2426a8d87d1: Download complete
# 7935dece71a7: Verifying Checksum
# 7935dece71a7: Download complete
# 6d94b93994d0: Verifying Checksum
# 6d94b93994d0: Download complete
# e9571e66d363: Verifying Checksum
# e9571e66d363: Download complete
# aa4bd601fd3f: Verifying Checksum
# aa4bd601fd3f: Download complete
# 8b91b88d5577: Pull complete
# 824416e23423: Pull complete
# 8d53da260408: Pull complete
# 84c8c79126f6: Pull complete
# 2e1c130fa3ec: Pull complete
# 895f77b56ce1: Verifying Checksum
# 895f77b56ce1: Download complete
# e1e2036205d2: Verifying Checksum
# e1e2036205d2: Download complete
# e9571e66d363: Pull complete
# c2426a8d87d1: Pull complete
# 5922e7f17bf6: Pull complete
# 7935dece71a7: Pull complete
# aa4bd601fd3f: Pull complete
# 6d94b93994d0: Pull complete
# e1e2036205d2: Pull complete
# 895f77b56ce1: Pull complete
# Digest: sha256:7b50ef5ed9eb6c2fa293d85b842251370d12cdb759a18e52bbcff72905bae4f7
# Status: Downloaded newer image for fabrictestbed/owl:0.1.4
# docker.io/fabrictestbed/owl:0.1.4
# 0.1.4: Pulling from fabrictestbed/owl
# 8b91b88d5577: Pulling fs layer
# 824416e23423: Pulling fs layer
# 8d53da260408: Pulling fs layer
# 84c8c79126f6: Pulling fs layer
# 2e1c130fa3ec: Pulling fs layer
# e9571e66d363: Pulling fs layer
# c2426a8d87d1: Pulling fs layer
# 5922e7f17bf6: Pulling fs layer
# 7935dece71a7: Pulling fs layer
# aa4bd601fd3f: Pulling fs layer
# 6d94b93994d0: Pulling fs layer
# e1e2036205d2: Pulling fs layer
# 895f77b56ce1: Pulling fs layer
# c2426a8d87d1: Waiting
# 5922e7f17bf6: Waiting
# 7935dece71a7: Waiting
# aa4bd601fd3f: Waiting
# 6d94b93994d0: Waiting
# e1e2036205d2: Waiting
# 895f77b56ce1: Waiting
# 2e1c130fa3ec: Waiting
# e9571e66d363: Waiting
# 84c8c79126f6: Waiting
# 824416e23423: Verifying Checksum
# 824416e23423: Download complete
# 8d53da260408: Verifying Checksum
# 8d53da260408: Download complete
# 8b91b88d5577: Verifying Checksum
# 8b91b88d5577: Download complete
# 8b91b88d5577: Pull complete
# 824416e23423: Pull complete
# 8d53da260408: Pull complete
# 84c8c79126f6: Verifying Checksum
# 84c8c79126f6: Download complete
# 84c8c79126f6: Pull complete
# 2e1c130fa3ec: Verifying Checksum
# 2e1c130fa3ec: Pull complete
# e9571e66d363: Verifying Checksum
# e9571e66d363: Download complete
# e9571e66d363: Pull complete
# c2426a8d87d1: Verifying Checksum
# c2426a8d87d1: Download complete
# 5922e7f17bf6: Verifying Checksum
# 5922e7f17bf6: Download complete
# 7935dece71a7: Verifying Checksum
# 7935dece71a7: Download complete
# c2426a8d87d1: Pull complete
# 5922e7f17bf6: Pull complete
# 7935dece71a7: Pull complete
# 6d94b93994d0: Verifying Checksum
# 6d94b93994d0: Download complete
# e1e2036205d2: Verifying Checksum
# e1e2036205d2: Download complete
# aa4bd601fd3f: Verifying Checksum
# aa4bd601fd3f: Download complete
# aa4bd601fd3f: Pull complete
# 6d94b93994d0: Pull complete
# e1e2036205d2: Pull complete
# 895f77b56ce1: Verifying Checksum
# 895f77b56ce1: Download complete
# 895f77b56ce1: Pull complete
# Digest: sha256:7b50ef5ed9eb6c2fa293d85b842251370d12cdb759a18e52bbcff72905bae4f7
# Status: Downloaded newer image for fabrictestbed/owl:0.1.4
# docker.io/fabrictestbed/owl:0.1.4
# 0.1.4: Pulling from fabrictestbed/owl
# 8b91b88d5577: Pulling fs layer
# 824416e23423: Pulling fs layer
# 8d53da260408: Pulling fs layer
# 84c8c79126f6: Pulling fs layer
# 2e1c130fa3ec: Pulling fs layer
# e9571e66d363: Pulling fs layer
# c2426a8d87d1: Pulling fs layer
# 5922e7f17bf6: Pulling fs layer
# 7935dece71a7: Pulling fs layer
# aa4bd601fd3f: Pulling fs layer
# 6d94b93994d0: Pulling fs layer
# e1e2036205d2: Pulling fs layer
# 895f77b56ce1: Pulling fs layer
# 84c8c79126f6: Waiting
# 2e1c130fa3ec: Waiting
# e9571e66d363: Waiting
# c2426a8d87d1: Waiting
# 5922e7f17bf6: Waiting
# 7935dece71a7: Waiting
# aa4bd601fd3f: Waiting
# 6d94b93994d0: Waiting
# e1e2036205d2: Waiting
# 895f77b56ce1: Waiting
# 824416e23423: Verifying Checksum
# 824416e23423: Download complete
# 8d53da260408: Verifying Checksum
# 8d53da260408: Download complete
# 8b91b88d5577: Verifying Checksum
# 8b91b88d5577: Download complete
# 8b91b88d5577: Pull complete
# 824416e23423: Pull complete
# 8d53da260408: Pull complete
# 84c8c79126f6: Verifying Checksum
# 84c8c79126f6: Download complete
# 2e1c130fa3ec: Verifying Checksum
# 2e1c130fa3ec: Download complete
# 84c8c79126f6: Pull complete
# 2e1c130fa3ec: Pull complete
# e9571e66d363: Verifying Checksum
# e9571e66d363: Download complete
# e9571e66d363: Pull complete
# 7935dece71a7: Verifying Checksum
# 7935dece71a7: Download complete
# c2426a8d87d1: Verifying Checksum
# c2426a8d87d1: Download complete
# 5922e7f17bf6: Verifying Checksum
# 5922e7f17bf6: Download complete
# c2426a8d87d1: Pull complete
# 5922e7f17bf6: Pull complete
# 7935dece71a7: Pull complete
# 6d94b93994d0: Verifying Checksum
# 6d94b93994d0: Download complete
# e1e2036205d2: Verifying Checksum
# e1e2036205d2: Download complete
# aa4bd601fd3f: Verifying Checksum
# aa4bd601fd3f: Download complete
# aa4bd601fd3f: Pull complete
# 6d94b93994d0: Pull complete
# e1e2036205d2: Pull complete
# 895f77b56ce1: Verifying Checksum
# 895f77b56ce1: Download complete
# 895f77b56ce1: Pull complete
# Digest: sha256:7b50ef5ed9eb6c2fa293d85b842251370d12cdb759a18e52bbcff72905bae4f7
# Status: Downloaded newer image for fabrictestbed/owl:0.1.4
# docker.io/fabrictestbed/owl:0.1.4
# 0.1.4: Pulling from fabrictestbed/owl
# 8b91b88d5577: Pulling fs layer
# 824416e23423: Pulling fs layer
# 8d53da260408: Pulling fs layer
# 84c8c79126f6: Pulling fs layer
# 2e1c130fa3ec: Pulling fs layer
# e9571e66d363: Pulling fs layer
# c2426a8d87d1: Pulling fs layer
# 5922e7f17bf6: Pulling fs layer
# 7935dece71a7: Pulling fs layer
# aa4bd601fd3f: Pulling fs layer
# 6d94b93994d0: Pulling fs layer
# e1e2036205d2: Pulling fs layer
# 895f77b56ce1: Pulling fs layer
# 5922e7f17bf6: Waiting
# 7935dece71a7: Waiting
# aa4bd601fd3f: Waiting
# 6d94b93994d0: Waiting
# e1e2036205d2: Waiting
# 895f77b56ce1: Waiting
# 2e1c130fa3ec: Waiting
# e9571e66d363: Waiting
# c2426a8d87d1: Waiting
# 84c8c79126f6: Waiting
# 824416e23423: Verifying Checksum
# 824416e23423: Download complete
# 8d53da260408: Verifying Checksum
# 8d53da260408: Download complete
# 8b91b88d5577: Verifying Checksum
# 8b91b88d5577: Download complete
# 84c8c79126f6: Verifying Checksum
# 84c8c79126f6: Download complete
# 2e1c130fa3ec: Verifying Checksum
# 2e1c130fa3ec: Download complete
# c2426a8d87d1: Verifying Checksum
# c2426a8d87d1: Download complete
# 7935dece71a7: Verifying Checksum
# 7935dece71a7: Download complete
# 5922e7f17bf6: Verifying Checksum
# 5922e7f17bf6: Download complete
# 6d94b93994d0: Verifying Checksum
# 6d94b93994d0: Download complete
# e1e2036205d2: Verifying Checksum
# e1e2036205d2: Download complete
# 895f77b56ce1: Verifying Checksum
# 895f77b56ce1: Download complete
# e9571e66d363: Verifying Checksum
# e9571e66d363: Download complete
# 8b91b88d5577: Pull complete
# aa4bd601fd3f: Verifying Checksum
# aa4bd601fd3f: Download complete
# 824416e23423: Pull complete
# 8d53da260408: Pull complete
# 84c8c79126f6: Pull complete
# 2e1c130fa3ec: Pull complete
# e9571e66d363: Pull complete
# c2426a8d87d1: Pull complete
# 5922e7f17bf6: Pull complete
# 7935dece71a7: Pull complete
# aa4bd601fd3f: Pull complete
# 6d94b93994d0: Pull complete
# e1e2036205d2: Pull complete
# 895f77b56ce1: Pull complete
# Digest: sha256:7b50ef5ed9eb6c2fa293d85b842251370d12cdb759a18e52bbcff72905bae4f7
# Status: Downloaded newer image for fabrictestbed/owl:0.1.4
# docker.io/fabrictestbed/owl:0.1.4
# 0.1.4: Pulling from fabrictestbed/owl
# 8b91b88d5577: Pulling fs layer
# 824416e23423: Pulling fs layer
# 8d53da260408: Pulling fs layer
# 84c8c79126f6: Pulling fs layer
# 2e1c130fa3ec: Pulling fs layer
# e9571e66d363: Pulling fs layer
# c2426a8d87d1: Pulling fs layer
# 5922e7f17bf6: Pulling fs layer
# 7935dece71a7: Pulling fs layer
# aa4bd601fd3f: Pulling fs layer
# 6d94b93994d0: Pulling fs layer
# e1e2036205d2: Pulling fs layer
# 895f77b56ce1: Pulling fs layer
# 84c8c79126f6: Waiting
# 2e1c130fa3ec: Waiting
# e9571e66d363: Waiting
# c2426a8d87d1: Waiting
# 5922e7f17bf6: Waiting
# 7935dece71a7: Waiting
# aa4bd601fd3f: Waiting
# 6d94b93994d0: Waiting
# e1e2036205d2: Waiting
# 895f77b56ce1: Waiting
# 824416e23423: Verifying Checksum
# 824416e23423: Download complete
# 8d53da260408: Verifying Checksum
# 8d53da260408: Download complete
# 8b91b88d5577: Verifying Checksum
# 8b91b88d5577: Download complete
# 84c8c79126f6: Verifying Checksum
# 84c8c79126f6: Download complete
# 2e1c130fa3ec: Verifying Checksum
# 2e1c130fa3ec: Download complete
# 8b91b88d5577: Pull complete
# 824416e23423: Pull complete
# c2426a8d87d1: Verifying Checksum
# c2426a8d87d1: Download complete
# 5922e7f17bf6: Verifying Checksum
# 5922e7f17bf6: Download complete
# 8d53da260408: Pull complete
# 84c8c79126f6: Pull complete
# 2e1c130fa3ec: Pull complete
# 7935dece71a7: Verifying Checksum
# 7935dece71a7: Download complete
# e9571e66d363: Verifying Checksum
# e9571e66d363: Download complete
# 6d94b93994d0: Verifying Checksum
# 6d94b93994d0: Download complete
# e1e2036205d2: Verifying Checksum
# e1e2036205d2: Download complete
# 895f77b56ce1: Verifying Checksum
# 895f77b56ce1: Download complete
# aa4bd601fd3f: Verifying Checksum
# aa4bd601fd3f: Download complete
# e9571e66d363: Pull complete
# c2426a8d87d1: Pull complete
# 5922e7f17bf6: Pull complete
# 7935dece71a7: Pull complete
# aa4bd601fd3f: Pull complete
# 6d94b93994d0: Pull complete
# e1e2036205d2: Pull complete
# 895f77b56ce1: Pull complete
# Digest: sha256:7b50ef5ed9eb6c2fa293d85b842251370d12cdb759a18e52bbcff72905bae4f7
# Status: Downloaded newer image for fabrictestbed/owl:0.1.4
# docker.io/fabrictestbed/owl:0.1.4

# %% [markdown]
# # Run the experiment
#
# There are 3 ways to use OWL
#
# 1. Specify each link with sender-capturer pair: this should be easiest method for most users.
# 2. Start each sender and capturer manually: this is useful when you want to have more precise control
# 3. Start on all links: this starts OWL on every pair of nodes in the slice (excluding meas-node if there is one)
#
#
# **Note: By default, all the previously saved pcap files will be deleted when a node starts a new OWL capturer session. If this behavior is not desired, set `delete_previous_output` to `False`.**

# %% [markdown]
# ## Method 1: Specify links by source and destination nodes
# This examples runs OWL on the following links:
#
# + Node1 --> Node2
# + Node2 --> Node3
# + Node3 --> Node2
#
# For each link, sender and capturer containers will start. If one node is a destination for more than 1 sender, only 1 capturer container instance will be created.

# %%
owl.start_owl(slice, src_node=slice.get_node(name='Node1'), dst_node=slice.get_node(name='Node2'), img_name=image_name, probe_freq=1, no_ptp=False, outfile=None, 
              duration = 120, delete_previous_output=True)

# %%
owl.start_owl(slice, src_node=slice.get_node(name='Node2'), dst_node=slice.get_node(name='Node3'), img_name=image_name, probe_freq=1, no_ptp=False, outfile=None, 
              duration = 600, delete_previous_output=True)

# %%
owl.start_owl(slice, src_node=slice.get_node(name='Node3'), dst_node=slice.get_node(name='Node2'), img_name=image_name, probe_freq=1, no_ptp=False, outfile=None, 
              duration = 600, delete_previous_output=True)

# %% [markdown]
# ### Check if they are running

# %%
owl.check_owl_all(slice)

# %% [markdown]
# ### Stop all OWL containers

# %%
owl.stop_owl_all(slice)

# %% [markdown]
# ### Verify

# %%
owl.check_owl_all(slice)

# %% [markdown]
# ## Method 2: start each sender, caputrer separately
#
# If user desires more granular control, sender and capturer can be started/stopped independently.

# %%
owl.start_owl_sender(slice, src_node=slice.get_node(name='Node1'), dst_node=slice.get_node(name='Node2'), img_name=image_name, duration=120)

# %%
owl.start_owl_sender(slice, src_node=slice.get_node(name='Node1'), dst_node=slice.get_node(name='Node3'), img_name=image_name, duration=120)

# %%
owl.start_owl_capturer(slice,  dst_node=slice.get_node(name='Node2'), img_name=image_name, duration=120)

# %%
owl.start_owl_sender(slice, src_node=slice.get_node(name='Node3'), dst_node=slice.get_node(name='Node2'), img_name=image_name, duration=120)

# %% [markdown]
# ### Check how the containers are running

# %%
owl.check_owl_all(slice)

# %% [markdown]
# ### Stop OWL containers on each node
#
# The method finds all containers with the prefix `owl-sender_` in their names, stops and removes them.

# %%
owl.stop_owl_sender(slice, src_node=slice.get_node(name='Node1'), dst_node=slice.get_node(name='Node2'))

# %%
owl.stop_owl_sender(slice, src_node=slice.get_node(name='Node1'), dst_node=slice.get_node(name='Node3'))

# %%
owl.stop_owl_capturer(slice,  dst_node=slice.get_node(name='Node2'))

# %%
owl.stop_owl_sender(slice, src_node=slice.get_node(name='Node3'), dst_node=slice.get_node(name='Node2'))

# %% [markdown]
# ### Verify

# %%
owl.check_owl_all(slice)

# %% [markdown]
# ## Method 3: start on all links
#
# If OWL measurements are desired on ALL possible links, call the following method. It will start sender and capturer containers on all nodes with each node sending probe packets to all the rest of the nodes in the slice.

# %%
owl.start_owl_all(slice, img_name=image_name, probe_freq=1, outfile=None, duration=600, delete_previous=True)
# Out:
# STAR --> MAX
# Staring sender
# 7c5c41c871a199bba4b6c024ca8dfd473ddb795da49bbd0fd974ab51217d3c92
# Staring capturer
# owl-capturer_10.130.7.2
# capturer already running on MAX
# STAR --> MICH
# Staring sender
# 3bf3b60aeda927658858bd7051934fbad4569c6d17c6a75cc3dabd6728341025
# Staring capturer
# owl-capturer_10.131.3.2
# capturer already running on MICH
# STAR --> MASS
# Staring sender
# 3461ff322837d7d879f20a4269a0c088df9611c2a675aac1b2d29f5fb82ea95b
# Staring capturer
# owl-capturer_10.131.132.2
# capturer already running on MASS
# STAR --> UTAH
# Staring sender
# 4a57fadf1e835ed22f15425fdf64b7f4e9c1438ad7f742734ddc6bd211e19599
# Staring capturer
# owl-capturer_10.132.5.2
# capturer already running on UTAH
# STAR --> NCSA
# Staring sender
# fac539dc8c903a81bda0fcdc6c2f4b44c4861157e616ae4f5473c7f1d66a1bfc
# Staring capturer
# owl-capturer_10.132.131.2
# capturer already running on NCSA
# STAR --> UCSD
# Staring sender
# 18ee088eee66f4bba69d7a912a75aa5c61d5b6f9e2d0524d56cb25ec882123ae
# Staring capturer
# owl-capturer_10.134.130.2
# capturer already running on UCSD
# STAR --> FIU
# Staring sender
# 23387ee19c2b149128456f4068fb9a6d971c45e369d385fcc3c2b8121edf395c
# Staring capturer
# owl-capturer_10.135.133.2
# capturer already running on FIU
# STAR --> CLEM
# Staring sender
# 1fb99c6f6595967fec5eeb992556d45aa059e68d9aa17ef6579e665b657caabb
# Staring capturer
# owl-capturer_10.136.2.2
# capturer already running on CLEM
# STAR --> CERN
# Staring sender
# 1ee948e54cfdf5bc9631df40b5ed4b7833b65f0cc7c22d40981f12003409e768
# Staring capturer
# owl-sender_10.143.2.2-10.136.2.2
# owl-capturer_10.143.2.2
# capturer already running on CERN
# MAX --> STAR
# Staring sender
# bb403d482a9cd70d940485d1a4616531643ec4d6e7f31515e5dbad6911a1bafa
# Staring capturer
# owl-sender_10.129.129.2-10.143.2.2
# owl-sender_10.129.129.2-10.136.2.2
# owl-sender_10.129.129.2-10.135.133.2
# owl-sender_10.129.129.2-10.134.130.2
# owl-sender_10.129.129.2-10.132.131.2
# owl-sender_10.129.129.2-10.132.5.2
# owl-sender_10.129.129.2-10.131.132.2
# owl-sender_10.129.129.2-10.131.3.2
# owl-sender_10.129.129.2-10.130.7.2
# owl-capturer_10.129.129.2
# capturer already running on STAR
# MAX --> MICH
# Staring sender
# 6d581cd80986cb4ea6e52c8354f5d7e743da4644bf865afb7838f6b3c1105fba
# Staring capturer
# owl-capturer_10.131.3.2
# capturer already running on MICH
# MAX --> MASS
# Staring sender
# 509ccd476dbf492c6ce901e9e8a94f692076f80dfdad6d91a92084c6cea52062
# Staring capturer
# owl-capturer_10.131.132.2
# capturer already running on MASS
# MAX --> UTAH
# Staring sender
# a5b2f1f9c5371ce01b9965f91461d4747b2262a6d53582f2ffa0d0ab1f6192b3
# Staring capturer
# owl-capturer_10.132.5.2
# capturer already running on UTAH
# MAX --> NCSA
# Staring sender
# 817c3af2ebe42baf38a674659ccdef171406ad1265796688450bef527cb29846
# Staring capturer
# owl-capturer_10.132.131.2
# capturer already running on NCSA
# MAX --> UCSD
# Staring sender
# ccc9245af01595a7eb4271bf406d7123255e294d83df22dc31e59fedec71f370
# Staring capturer
# owl-capturer_10.134.130.2
# capturer already running on UCSD
# MAX --> FIU
# Staring sender
# 019a08fb69a8b62ba894eb691251b3aba75657ed0a172d6ee0f2ec3c16271e27
# Staring capturer
# owl-capturer_10.135.133.2
# capturer already running on FIU
# MAX --> CLEM
# Staring sender
# a55efda97da488fa0c2ed30e5781bbc1154614723081603ed1ca2c5b7e8ae315
# Staring capturer
# owl-capturer_10.136.2.2
# capturer already running on CLEM
# MAX --> CERN
# Staring sender
# 0ff36c11c39836f16ff84bc0e9077dc0b6705fecacf0b40068c04b229c4c3e2c
# Staring capturer
# owl-capturer_10.143.2.2
# capturer already running on CERN
# MICH --> STAR
# Staring sender
# 31bdf46b7235fc22e2c7fb8fbcb2a89eade740e5942a1a7eb0ad2802924d7c54
# Staring capturer
# owl-sender_10.129.129.2-10.143.2.2
# owl-sender_10.129.129.2-10.136.2.2
# owl-sender_10.129.129.2-10.135.133.2
# owl-sender_10.129.129.2-10.134.130.2
# owl-sender_10.129.129.2-10.132.131.2
# owl-sender_10.129.129.2-10.132.5.2
# owl-sender_10.129.129.2-10.131.132.2
# owl-sender_10.129.129.2-10.131.3.2
# owl-capturer_10.129.129.2
# capturer already running on STAR
# MICH --> MAX
# Staring sender
# bb0ed89927ced7c063818bdf85a80136cc97dc1b2578cb87d1ec4d979ee82096
# Staring capturer
# owl-sender_10.130.7.2-10.143.2.2
# owl-sender_10.130.7.2-10.136.2.2
# owl-sender_10.130.7.2-10.135.133.2
# owl-sender_10.130.7.2-10.134.130.2
# owl-sender_10.130.7.2-10.132.131.2
# owl-sender_10.130.7.2-10.132.5.2
# owl-sender_10.130.7.2-10.131.132.2
# owl-sender_10.130.7.2-10.131.3.2
# owl-sender_10.130.7.2-10.129.129.2
# owl-capturer_10.130.7.2
# capturer already running on MAX
# MICH --> MASS
# Staring sender
# 398288babfcceed86bdd579cd58c691c269aa6d70a5116233e21f06177c1e672
# Staring capturer
# owl-capturer_10.131.132.2
# capturer already running on MASS
# MICH --> UTAH
# Staring sender
# b1897a646fa770c25969488f0a015982faba3a2567bead4d75c28f10ab553687
# Staring capturer
# owl-capturer_10.132.5.2
# capturer already running on UTAH
# MICH --> NCSA
# Staring sender
# a1633fd9a70c7a135658bf0fdf0ac4193fc00c568b76f30b3a1e469a241d1dc1
# Staring capturer
# owl-capturer_10.132.131.2
# capturer already running on NCSA
# MICH --> UCSD
# Staring sender
# 0ec52ed5b851b88e4c1c275756047fc8f99fce2cc9ee72e533256cb5aa31b988
# Staring capturer
# owl-capturer_10.134.130.2
# capturer already running on UCSD
# MICH --> FIU
# Staring sender
# aed88500543313a7868e18f920e8fdfad5be5fb2a71404f518a40b99707d403c
# Staring capturer
# owl-capturer_10.135.133.2
# capturer already running on FIU
# MICH --> CLEM
# Staring sender
# ab99281550523708362057645291aa7a93c60375ec666748523063a7e319ad35
# Staring capturer
# owl-capturer_10.136.2.2
# capturer already running on CLEM
# MICH --> CERN
# Staring sender
# 0f9263e7739ea6d2c0f3820355467e367c38addcb85756275a0c9d5fcbdf9217
# Staring capturer
# owl-capturer_10.143.2.2
# capturer already running on CERN
# MASS --> STAR
# Staring sender
# 2c05952445de499823e3d7a0abe2b1206f84f746861fa360c05edeb75adec73c
# Staring capturer
# owl-capturer_10.129.129.2
# capturer already running on STAR
# MASS --> MAX
# Staring sender
# c566d9dbf9951bdcd865d9947bb08757f6ba31e0200ee126ac36a545ef9c9ad7
# Staring capturer
# owl-sender_10.130.7.2-10.143.2.2
# owl-sender_10.130.7.2-10.136.2.2
# owl-sender_10.130.7.2-10.135.133.2
# owl-sender_10.130.7.2-10.134.130.2
# owl-sender_10.130.7.2-10.132.131.2
# owl-sender_10.130.7.2-10.132.5.2
# owl-sender_10.130.7.2-10.131.132.2
# owl-sender_10.130.7.2-10.131.3.2
# owl-capturer_10.130.7.2
# capturer already running on MAX
# MASS --> MICH
# Staring sender
# 67a91aa851864bb3ffc7239b90a6b4af1bf0bf44b4109e94f70605bf849d6bdf
# Staring capturer
# owl-sender_10.131.3.2-10.143.2.2
# owl-sender_10.131.3.2-10.136.2.2
# owl-sender_10.131.3.2-10.135.133.2
# owl-sender_10.131.3.2-10.134.130.2
# owl-sender_10.131.3.2-10.132.131.2
# owl-sender_10.131.3.2-10.132.5.2
# owl-sender_10.131.3.2-10.131.132.2
# owl-sender_10.131.3.2-10.130.7.2
# owl-sender_10.131.3.2-10.129.129.2
# owl-capturer_10.131.3.2
# capturer already running on MICH
# MASS --> UTAH
# Staring sender
# 112880c9a55f37a772c7e88c9c9dc5e34d028b13942ee7c3d625a8803c846008
# Staring capturer
# owl-capturer_10.132.5.2
# capturer already running on UTAH
# MASS --> NCSA
# Staring sender
# cd2ed22940275bca89f6d0391217b92ce5f6ffe2c582ebe8e8bf6a01e29c2b0a
# Staring capturer
# owl-capturer_10.132.131.2
# capturer already running on NCSA
# MASS --> UCSD
# Staring sender
# 0f310bc86dceab52f505dc26047691a9df92865ebc535c1e0de23666e41afb1b
# Staring capturer
# owl-capturer_10.134.130.2
# capturer already running on UCSD
# MASS --> FIU
# Staring sender
# 828b329a093795441b6f3e83d6c8ce155178801a04669a2f6d7891a6a479101b
# Staring capturer
# owl-capturer_10.135.133.2
# capturer already running on FIU
# MASS --> CLEM
# Staring sender
# c2b593dea4aee552fa85d0834e34d327a6c0df1ae966f73790f7099c32669520
# Staring capturer
# owl-capturer_10.136.2.2
# capturer already running on CLEM
# MASS --> CERN
# Staring sender
# ccfe7b663b929125ce64351f495f5415d06a9f19b6f261875ec4c809701dad1c
# Staring capturer
# owl-capturer_10.143.2.2
# capturer already running on CERN
# UTAH --> STAR
# Staring sender
# b938e9a408b396f5a3fab80dfc816ab463974b2027c5f6b592fdc438b0e297b1
# Staring capturer
# owl-capturer_10.129.129.2
# capturer already running on STAR
# UTAH --> MAX
# Staring sender
# e6dcc05b0a9c54629e22185aa5970a0131c9d1d678de789facae04885b36666a
# Staring capturer
# owl-capturer_10.130.7.2
# capturer already running on MAX
# UTAH --> MICH
# Staring sender
# cc7015f579eebb2860d65e746b041f2e122363bacf67f2187a88b6791bb80ea1
# Staring capturer
# owl-sender_10.131.3.2-10.143.2.2
# owl-sender_10.131.3.2-10.136.2.2
# owl-sender_10.131.3.2-10.135.133.2
# owl-sender_10.131.3.2-10.134.130.2
# owl-sender_10.131.3.2-10.132.131.2
# owl-sender_10.131.3.2-10.132.5.2
# owl-capturer_10.131.3.2
# capturer already running on MICH
# UTAH --> MASS
# Staring sender
# 8f2a2f35fa2030e1d2f2eb34d7bc17c0644839eb2abca214c09aa10e0f0280b2
# Staring capturer
# capturer already running on MASS
# UTAH --> NCSA
# Staring sender
# 4f122c335a26a7f07aa4059e376631c530daa456b81b8aa3cf7fe6632978ee35
# Staring capturer
# owl-capturer_10.132.131.2
# capturer already running on NCSA
# UTAH --> UCSD
# Staring sender
# 2ee021bc8bb8dc31def28cf9f4e6674c59d58401dab7e816fdeb1cb80944d410
# Staring capturer
# owl-capturer_10.134.130.2
# capturer already running on UCSD
# UTAH --> FIU
# Staring sender
# 9903d2b6b443a8c1927c2d9b69bd92e0f0ff381b1e214b890787045d8bc6edc1
# Staring capturer
# owl-capturer_10.135.133.2
# capturer already running on FIU
# UTAH --> CLEM
# Staring sender
# 6f41827501002700fae5ccebcbea0fcf0d2bf7c4160e7c63936615e614bfa81d
# Staring capturer
# owl-capturer_10.136.2.2
# capturer already running on CLEM
# UTAH --> CERN
# Staring sender
# 1b8f92c91132bb5e8af2063ff11f9b3e80b0feebbe04985a2d39c85473eac4bf
# Staring capturer
# owl-capturer_10.143.2.2
# capturer already running on CERN
# NCSA --> STAR
# Staring sender
# 84f653f6b009bb55ea385ba1e470db32a5ead951a06de7ea4b2ec855430927ba
# Staring capturer
# owl-capturer_10.129.129.2
# capturer already running on STAR
# NCSA --> MAX
# Staring sender
# 885571533e73281a23489cf2a03051cb2f4626619357dfce17025c85a3e66db6
# Staring capturer
# owl-capturer_10.130.7.2
# capturer already running on MAX
# NCSA --> MICH
# Staring sender
# 2022ecfad1209447b43e87caaf6e10b41d28c9616f925c58acde1e3bf35350af
# Staring capturer
# owl-capturer_10.131.3.2
# capturer already running on MICH
# NCSA --> MASS
# Staring sender
# 2c481aa409b373ed66c048a005a6bc21cbc9875eb68657c92d23451617bf6d31
# Staring capturer
# owl-sender_10.131.132.2-10.143.2.2
# owl-sender_10.131.132.2-10.136.2.2
# owl-sender_10.131.132.2-10.135.133.2
# owl-sender_10.131.132.2-10.134.130.2
# owl-sender_10.131.132.2-10.132.131.2
# owl-sender_10.131.132.2-10.132.5.2
# owl-capturer_10.131.132.2
# capturer already running on MASS
# NCSA --> UTAH
# Staring sender
# b20743c1808ab8e406e0951b37f3a5381e5780535739437916b9e37112892a4b
# Staring capturer
# owl-sender_10.132.5.2-10.143.2.2
# owl-sender_10.132.5.2-10.136.2.2
# owl-sender_10.132.5.2-10.135.133.2
# owl-sender_10.132.5.2-10.134.130.2
# owl-sender_10.132.5.2-10.132.131.2
# owl-sender_10.132.5.2-10.131.132.2
# owl-sender_10.132.5.2-10.131.3.2
# owl-sender_10.132.5.2-10.130.7.2
# owl-sender_10.132.5.2-10.129.129.2
# owl-capturer_10.132.5.2
# capturer already running on UTAH
# NCSA --> UCSD
# Staring sender
# 1bbd314fb7c4fd80b98727a3026ad606f83f7c6421817a0bb48d187c3f93f44e
# Staring capturer
# owl-capturer_10.134.130.2
# capturer already running on UCSD
# NCSA --> FIU
# Staring sender
# e3a0bd42e54a43a8c529c52785e566d910fbf8694bde9b250c347b40393ea58b
# Staring capturer
# owl-capturer_10.135.133.2
# capturer already running on FIU
# NCSA --> CLEM
# Staring sender
# 51bcd2c18c590175da6e33b4991cca4ec44fac40c855f835202c1d3f29119538
# Staring capturer
# owl-capturer_10.136.2.2
# capturer already running on CLEM
# NCSA --> CERN
# Staring sender
# 7b01ac61a72661b6798aa3add526736d9d05e4175c43814442576b95d8d65765
# Staring capturer
# owl-capturer_10.143.2.2
# capturer already running on CERN
# UCSD --> STAR
# Staring sender
# 53b76a4c38e4a1f219e5d59137d645c0ec89fe49e1914235ba7fef4e6f42b5dc
# Staring capturer
# owl-capturer_10.129.129.2
# capturer already running on STAR
# UCSD --> MAX
# Staring sender
# 5dfca5b23f11ce815da143d97ca218845128cb15a1dad911b248196098cee450
# Staring capturer
# owl-capturer_10.130.7.2
# capturer already running on MAX
# UCSD --> MICH
# Staring sender
# a309872149df88fcf2b4a6d1f8d966aa836f0c6e5b2f7521060f638aac6e8f49
# Staring capturer
# owl-capturer_10.131.3.2
# capturer already running on MICH
# UCSD --> MASS
# Staring sender
# 514ac2b1af0544c2f8ab712485a571db5312fafc96fd1af33e42a68b49a6a0ee
# Staring capturer
# owl-capturer_10.131.132.2
# capturer already running on MASS
# UCSD --> UTAH
# Staring sender
# daeffa4be0d22082cbe2a2587001ec7dbafb0562d3b6e2fe90c678934360242a
# Staring capturer
# owl-sender_10.132.5.2-10.143.2.2
# owl-sender_10.132.5.2-10.136.2.2
# owl-sender_10.132.5.2-10.135.133.2
# owl-sender_10.132.5.2-10.134.130.2
# owl-capturer_10.132.5.2
# capturer already running on UTAH
# UCSD --> NCSA
# Staring sender
# 8f52f938eedc9d7bd4a66ad40505fe18d10db59ae7ff026c0a82638d8e0a0bea
# Staring capturer
# owl-sender_10.132.131.2-10.143.2.2
# owl-sender_10.132.131.2-10.136.2.2
# owl-sender_10.132.131.2-10.135.133.2
# owl-sender_10.132.131.2-10.134.130.2
# owl-sender_10.132.131.2-10.132.5.2
# owl-sender_10.132.131.2-10.131.132.2
# owl-sender_10.132.131.2-10.131.3.2
# owl-sender_10.132.131.2-10.130.7.2
# owl-sender_10.132.131.2-10.129.129.2
# owl-capturer_10.132.131.2
# capturer already running on NCSA
# UCSD --> FIU
# Staring sender
# eaf571da5a8b12a2acca975f153e8946bef7be59ff2feeb9fda493eaad6289c9
# Staring capturer
# owl-capturer_10.135.133.2
# capturer already running on FIU
# UCSD --> CLEM
# Staring sender
# 9b43c8f78b07ef66ff12a29eacd615cd851fb499a703e25eaa5954210b4d0131
# Staring capturer
# owl-capturer_10.136.2.2
# capturer already running on CLEM
# UCSD --> CERN
# Staring sender
# 79cff07d878ee163dee76f856287e7d899a0a61ad7c7d54cef3234a522e42005
# Staring capturer
# owl-capturer_10.143.2.2
# capturer already running on CERN
# FIU --> STAR
# Staring sender
# cb099ee61d49d30f38ee251df151bbdc76bf5f6d4288f8e9d8c891be3c2c7f05
# Staring capturer
# owl-capturer_10.129.129.2
# capturer already running on STAR
# FIU --> MAX
# Staring sender
# a8648db8b6f750e249335acce0755bbdf95d00b0193c2ad4447429edcb6f8fb3
# Staring capturer
# owl-capturer_10.130.7.2
# capturer already running on MAX
# FIU --> MICH
# Staring sender
# 3f8243aa71f64aad1e019f70872f5cb1dddd9dbaea623dac9fb0481f7c1bdd2d
# Staring capturer
# owl-capturer_10.131.3.2
# capturer already running on MICH
# FIU --> MASS
# Staring sender
# f25516a46b92e0bdf1dbcd3c452b4662ec937634ff6269e284b2fef60a2a30f8
# Staring capturer
# owl-capturer_10.131.132.2
# capturer already running on MASS
# FIU --> UTAH
# Staring sender
# 89714475a93acb293346bf512286c7543bbce9398c49161b47fdd3f6b0af528f
# Staring capturer
# owl-capturer_10.132.5.2
# capturer already running on UTAH
# FIU --> NCSA
# Staring sender
# 044279e91007b3f9e17f07e7452d4f1ee360673f3d9f850103cac3ec0f27acba
# Staring capturer
# owl-sender_10.132.131.2-10.143.2.2
# owl-sender_10.132.131.2-10.136.2.2
# owl-sender_10.132.131.2-10.135.133.2
# owl-capturer_10.132.131.2
# capturer already running on NCSA
# FIU --> UCSD
# Staring sender
# 53c54e56953a8bfb5e20b7237fdd7e46cfd478c46859fdf0a1dddde8c37d1a79
# Staring capturer
# owl-sender_10.134.130.2-10.143.2.2
# owl-sender_10.134.130.2-10.136.2.2
# owl-sender_10.134.130.2-10.135.133.2
# owl-sender_10.134.130.2-10.132.131.2
# owl-sender_10.134.130.2-10.132.5.2
# owl-sender_10.134.130.2-10.131.132.2
# owl-sender_10.134.130.2-10.131.3.2
# owl-sender_10.134.130.2-10.130.7.2
# owl-sender_10.134.130.2-10.129.129.2
# owl-capturer_10.134.130.2
# capturer already running on UCSD
# FIU --> CLEM
# Staring sender
# 9823e278d6ff10aa973acdf80ca09611de761fb8caf3f9085d5afc4913f8d448
# Staring capturer
# owl-capturer_10.136.2.2
# capturer already running on CLEM
# FIU --> CERN
# Staring sender
# f24e23cc004b4d3553ac4a36c512421b73a2006a4899272612e9fc3f5556664b
# Staring capturer
# owl-capturer_10.143.2.2
# capturer already running on CERN
# CLEM --> STAR
# Staring sender
# 40bd414cc6017546a1450d562a8792f5470291a3e77d69edd901f4a6cdc789b3
# Staring capturer
# owl-capturer_10.129.129.2
# capturer already running on STAR
# CLEM --> MAX
# Staring sender
# 2ce8e72554b3353a6c86bec1d0ae77d55841474db6afb02b2316629574b1fa49
# Staring capturer
# owl-capturer_10.130.7.2
# capturer already running on MAX
# CLEM --> MICH
# Staring sender
# 33e2c5922e33976ab1aa0becbff25543f50b08f52d9aa6d580e1d771659d8d23
# Staring capturer
# owl-capturer_10.131.3.2
# capturer already running on MICH
# CLEM --> MASS
# Staring sender
# 0b7c55a5ff0c65e6bee087dfccd48f00efb5a58e45b4e37950e6d685091caef3
# Staring capturer
# owl-capturer_10.131.132.2
# capturer already running on MASS
# CLEM --> UTAH
# Staring sender
# 0d8f40e6b0f760b6885cb14e462b416cae3e50539be9c4f4b1e305d74041cf39
# Staring capturer
# owl-capturer_10.132.5.2
# capturer already running on UTAH
# CLEM --> NCSA
# Staring sender
# 1cec17e711535fb1a18da02c4b3033a5ec784edc41272c5914b16abfea3f4cfb
# Staring capturer
# owl-capturer_10.132.131.2
# capturer already running on NCSA
# CLEM --> UCSD
# Staring sender
# 7b9696c7baa1e405bf04b38c22359c1070a593905067af78e4a6d36f8cc89a64
# Staring capturer
# owl-sender_10.134.130.2-10.143.2.2
# owl-sender_10.134.130.2-10.136.2.2
# owl-sender_10.134.130.2-10.135.133.2
# owl-capturer_10.134.130.2
# capturer already running on UCSD
# CLEM --> FIU
# Staring sender
# 05bfceef7ac4c26fa7b798ce992a8fe9c2cb4f5744bbddb51a725fe1df8a483c
# Staring capturer
# owl-sender_10.135.133.2-10.143.2.2
# owl-sender_10.135.133.2-10.136.2.2
# owl-sender_10.135.133.2-10.134.130.2
# owl-sender_10.135.133.2-10.132.131.2
# owl-sender_10.135.133.2-10.132.5.2
# owl-sender_10.135.133.2-10.131.132.2
# owl-sender_10.135.133.2-10.131.3.2
# owl-sender_10.135.133.2-10.130.7.2
# owl-sender_10.135.133.2-10.129.129.2
# owl-capturer_10.135.133.2
# capturer already running on FIU
# CLEM --> CERN
# Staring sender
# 6c27e1ba68b428fba8832e662a2120195f66a72bdb1ca565a360c15a4432287f
# Staring capturer
# owl-capturer_10.143.2.2
# capturer already running on CERN
# CERN --> STAR
# Staring sender
# ffcd4bf078ba3fd97dd3fc36769749dd1327a6864e9c3f94a40d41772c71ebf6
# Staring capturer
# owl-capturer_10.129.129.2
# capturer already running on STAR
# CERN --> MAX
# Staring sender
# 5d251e7a8fe5a50837ed0058d81409184ab54117fe623a018767f16345ef0604
# Staring capturer
# owl-capturer_10.130.7.2
# capturer already running on MAX
# CERN --> MICH
# Staring sender
# 8d4da276e763b09dd93fa4a1ff68a7724608cfb86c85b2676bfbe0fcdea15c06
# Staring capturer
# owl-capturer_10.131.3.2
# capturer already running on MICH
# CERN --> MASS
# Staring sender
# ec72fb79b697be0e39f2ea77e8e81e0860d0525e75a0dd18993cda406b38c583
# Staring capturer
# owl-capturer_10.131.132.2
# capturer already running on MASS
# CERN --> UTAH
# Staring sender
# 997ec6e7fccfb2d2bd8ffb54e72d6f9ce23cf05acdaffd293ca51262f5e508e0
# Staring capturer
# owl-capturer_10.132.5.2
# capturer already running on UTAH
# CERN --> NCSA
# Staring sender
# eae9632df3bab1820d228acd917f4f565dc56812049997fc0436edb05a3749b7
# Staring capturer
# owl-capturer_10.132.131.2
# capturer already running on NCSA
# CERN --> UCSD
# Staring sender
# 0a3463fdaba15d15edfa0575a20dc2369bfa1d479cea38057df0927ec8bef15a
# Staring capturer
# owl-capturer_10.134.130.2
# capturer already running on UCSD
# CERN --> FIU
# Staring sender
# 76b4ef9abd8d7ca48f2360f5ab7ff075ac5c0509fc9857baf9ff425397efa8f9
# Staring capturer
# owl-sender_10.135.133.2-10.143.2.2
# owl-capturer_10.135.133.2
# capturer already running on FIU
# CERN --> CLEM
# Staring sender
# 8a234da4b1ff32aa8f9b7ff64eba76d7bc57c9dfc78e6c379690e7662a23d599
# Staring capturer
# owl-sender_10.136.2.2-10.143.2.2
# owl-sender_10.136.2.2-10.135.133.2
# owl-sender_10.136.2.2-10.134.130.2
# owl-sender_10.136.2.2-10.132.131.2
# owl-sender_10.136.2.2-10.132.5.2
# owl-sender_10.136.2.2-10.131.132.2
# owl-sender_10.136.2.2-10.131.3.2
# owl-sender_10.136.2.2-10.130.7.2
# owl-sender_10.136.2.2-10.129.129.2
# owl-capturer_10.136.2.2
# capturer already running on CLEM

# %% [markdown]
# ### Check if they are running

# %%
owl.check_owl_all(slice)
# Out:
# STAR
# CONTAINER ID   IMAGE                     COMMAND                  CREATED          STATUS          PORTS     NAMES
# 14059ab95863   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   43 minutes ago   Up 43 minutes             owl-capturer_10.129.129.2
# MAX
# CONTAINER ID   IMAGE                     COMMAND                  CREATED          STATUS          PORTS     NAMES
# 6db9673a0d8f   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   49 minutes ago   Up 49 minutes             owl-capturer_10.130.7.2
# MICH
# CONTAINER ID   IMAGE                     COMMAND                  CREATED          STATUS          PORTS     NAMES
# c9bbaec947b0   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   48 minutes ago   Up 48 minutes             owl-capturer_10.131.3.2
# MASS
# CONTAINER ID   IMAGE                     COMMAND                  CREATED          STATUS          PORTS     NAMES
# 76720c534357   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   48 minutes ago   Up 48 minutes             owl-capturer_10.131.132.2
# UTAH
# CONTAINER ID   IMAGE                     COMMAND                  CREATED          STATUS          PORTS     NAMES
# d4ce77007a36   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   47 minutes ago   Up 47 minutes             owl-capturer_10.132.5.2
# NCSA
# CONTAINER ID   IMAGE                     COMMAND                  CREATED          STATUS          PORTS     NAMES
# 69e741cf19f9   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   46 minutes ago   Up 46 minutes             owl-capturer_10.132.131.2
# UCSD
# CONTAINER ID   IMAGE                     COMMAND                  CREATED          STATUS          PORTS     NAMES
# f1e19483e43f   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   46 minutes ago   Up 46 minutes             owl-capturer_10.134.130.2
# FIU
# CONTAINER ID   IMAGE                     COMMAND                  CREATED          STATUS          PORTS     NAMES
# 4186f45f73cd   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   45 minutes ago   Up 45 minutes             owl-capturer_10.135.133.2
# CLEM
# CONTAINER ID   IMAGE                     COMMAND                  CREATED          STATUS          PORTS     NAMES
# 8820c3e06514   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   5 minutes ago    Up 5 minutes              owl-sender_10.136.2.2-10.143.2.2
# 18f21caa2fa0   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   6 minutes ago    Up 6 minutes              owl-sender_10.136.2.2-10.135.133.2
# 6ca1b960e574   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   6 minutes ago    Up 6 minutes              owl-sender_10.136.2.2-10.134.130.2
# 04fc1d9a8e9b   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   7 minutes ago    Up 7 minutes              owl-sender_10.136.2.2-10.132.131.2
# 0bd32396cfcd   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   7 minutes ago    Up 7 minutes              owl-sender_10.136.2.2-10.132.5.2
# 83fbf7164485   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   8 minutes ago    Up 8 minutes              owl-sender_10.136.2.2-10.131.132.2
# d70d7c808820   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   8 minutes ago    Up 8 minutes              owl-sender_10.136.2.2-10.131.3.2
# f37ef072fc48   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   9 minutes ago    Up 9 minutes              owl-sender_10.136.2.2-10.130.7.2
# ed64e44c1145   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   45 minutes ago   Up 45 minutes             owl-capturer_10.136.2.2
# CERN
# CONTAINER ID   IMAGE                     COMMAND                  CREATED              STATUS              PORTS     NAMES
# 737d3ee24fce   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   45 seconds ago       Up 44 seconds                 owl-sender_10.143.2.2-10.136.2.2
# 698368a173b3   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   About a minute ago   Up About a minute             owl-sender_10.143.2.2-10.135.133.2
# 7a8a200e9faf   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   About a minute ago   Up About a minute             owl-sender_10.143.2.2-10.134.130.2
# 92532e4732c9   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   2 minutes ago        Up 2 minutes                  owl-sender_10.143.2.2-10.132.131.2
# d190ea454e03   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   2 minutes ago        Up 2 minutes                  owl-sender_10.143.2.2-10.132.5.2
# 0d2dffa220aa   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   3 minutes ago        Up 3 minutes                  owl-sender_10.143.2.2-10.131.132.2
# 9e1aeec7dccb   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   4 minutes ago        Up 4 minutes                  owl-sender_10.143.2.2-10.131.3.2
# bcf135207aac   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   4 minutes ago        Up 4 minutes                  owl-sender_10.143.2.2-10.130.7.2
# 40dc0e2e9bad   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   5 minutes ago        Up 5 minutes                  owl-sender_10.143.2.2-10.129.129.2
# f44047255efa   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   44 minutes ago       Up 44 minutes                 owl-capturer_10.143.2.2

# %% [markdown]
# ### Stop all OWL containers

# %%
owl.stop_owl_all(slice)

# %% [markdown]
# ### Verify

# %%
owl.check_owl_all(slice)
# Out:
# STAR
# CONTAINER ID   IMAGE                     COMMAND                  CREATED       STATUS       PORTS     NAMES
# 14059ab95863   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   2 hours ago   Up 2 hours             owl-capturer_10.129.129.2
# MAX
# CONTAINER ID   IMAGE                     COMMAND                  CREATED       STATUS       PORTS     NAMES
# 6db9673a0d8f   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   2 hours ago   Up 2 hours             owl-capturer_10.130.7.2
# MICH
# CONTAINER ID   IMAGE                     COMMAND                  CREATED       STATUS       PORTS     NAMES
# c9bbaec947b0   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   2 hours ago   Up 2 hours             owl-capturer_10.131.3.2
# MASS
# CONTAINER ID   IMAGE                     COMMAND                  CREATED       STATUS       PORTS     NAMES
# 76720c534357   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   2 hours ago   Up 2 hours             owl-capturer_10.131.132.2
# UTAH
# CONTAINER ID   IMAGE                     COMMAND                  CREATED       STATUS       PORTS     NAMES
# d4ce77007a36   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   2 hours ago   Up 2 hours             owl-capturer_10.132.5.2
# NCSA
# CONTAINER ID   IMAGE                     COMMAND                  CREATED       STATUS       PORTS     NAMES
# 69e741cf19f9   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   2 hours ago   Up 2 hours             owl-capturer_10.132.131.2
# UCSD
# CONTAINER ID   IMAGE                     COMMAND                  CREATED       STATUS       PORTS     NAMES
# f1e19483e43f   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   2 hours ago   Up 2 hours             owl-capturer_10.134.130.2
# FIU
# CONTAINER ID   IMAGE                     COMMAND                  CREATED       STATUS       PORTS     NAMES
# 4186f45f73cd   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   2 hours ago   Up 2 hours             owl-capturer_10.135.133.2
# CLEM
# CONTAINER ID   IMAGE                     COMMAND                  CREATED         STATUS         PORTS     NAMES
# 6c27e1ba68b4   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   5 minutes ago   Up 5 minutes             owl-sender_10.136.2.2-10.143.2.2
# 05bfceef7ac4   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   6 minutes ago   Up 6 minutes             owl-sender_10.136.2.2-10.135.133.2
# 7b9696c7baa1   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   6 minutes ago   Up 6 minutes             owl-sender_10.136.2.2-10.134.130.2
# 1cec17e71153   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   7 minutes ago   Up 7 minutes             owl-sender_10.136.2.2-10.132.131.2
# 0d8f40e6b0f7   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   7 minutes ago   Up 7 minutes             owl-sender_10.136.2.2-10.132.5.2
# 0b7c55a5ff0c   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   8 minutes ago   Up 8 minutes             owl-sender_10.136.2.2-10.131.132.2
# 33e2c5922e33   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   8 minutes ago   Up 8 minutes             owl-sender_10.136.2.2-10.131.3.2
# 2ce8e72554b3   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   9 minutes ago   Up 9 minutes             owl-sender_10.136.2.2-10.130.7.2
# ed64e44c1145   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   2 hours ago     Up 2 hours               owl-capturer_10.136.2.2
# CERN
# CONTAINER ID   IMAGE                     COMMAND                  CREATED              STATUS              PORTS     NAMES
# 8a234da4b1ff   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   44 seconds ago       Up 44 seconds                 owl-sender_10.143.2.2-10.136.2.2
# 76b4ef9abd8d   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   About a minute ago   Up About a minute             owl-sender_10.143.2.2-10.135.133.2
# 0a3463fdaba1   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   About a minute ago   Up About a minute             owl-sender_10.143.2.2-10.134.130.2
# eae9632df3ba   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   2 minutes ago        Up 2 minutes                  owl-sender_10.143.2.2-10.132.131.2
# 997ec6e7fccf   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   2 minutes ago        Up 2 minutes                  owl-sender_10.143.2.2-10.132.5.2
# ec72fb79b697   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   3 minutes ago        Up 3 minutes                  owl-sender_10.143.2.2-10.131.132.2
# 8d4da276e763   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   4 minutes ago        Up 4 minutes                  owl-sender_10.143.2.2-10.131.3.2
# 5d251e7a8fe5   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   4 minutes ago        Up 4 minutes                  owl-sender_10.143.2.2-10.130.7.2
# ffcd4bf078ba   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   5 minutes ago        Up 5 minutes                  owl-sender_10.143.2.2-10.129.129.2
# f44047255efa   fabrictestbed/owl:0.1.4   "python3 sock_ops/ud…"   2 hours ago          Up 2 hours                    owl-capturer_10.143.2.2

# %% [markdown]
# # Get the Output files
#
# By default, all the pcap files are saved in `/home/rocky/owl-output` as `{dest_ip}.pcap` on the desination node.
#
# ## Check the availability of output files

# %%
owl_output_dir = '/home/rocky/owl-output'

for node in nodes:
    print(node.get_name())
    node.execute(f"ls -lh {owl_output_dir}")
# Out:
# STAR
# total 560K
# -rw-r--r--. 1 root root 554K Nov 18 09:16 10.129.129.2.pcap
# MAX
# total 556K
# -rw-r--r--. 1 root root 550K Nov 18 09:16 10.130.7.2.pcap
# MICH
# total 556K
# -rw-r--r--. 1 root root 549K Nov 18 09:16 10.131.3.2.pcap
# MASS
# total 552K
# -rw-r--r--. 1 root root 545K Nov 18 09:16 10.131.132.2.pcap
# UTAH
# total 548K
# -rw-r--r--. 1 root root 543K Nov 18 09:16 10.132.5.2.pcap
# NCSA
# total 544K
# -rw-r--r--. 1 root root 540K Nov 18 09:16 10.132.131.2.pcap
# UCSD
# total 4.0K
# -rw-r--r--. 1 root root 24 Nov 18 07:35 10.134.130.2.pcap
# FIU
# total 4.0K
# -rw-r--r--. 1 root root 24 Nov 18 07:36 10.135.133.2.pcap
# CLEM
# total 4.0K
# -rw-r--r--. 1 root root 24 Nov 18 07:36 10.136.2.2.pcap
# CERN
# total 584K
# -rw-r--r--. 1 root root 577K Nov 18 09:05 10.143.2.2.pcap

# %% [markdown]
# ## Download the pcap files for analysis

# %%
for node in nodes:
    
    print(f"Downloading pcap files from {node.get_name()}")
    
    local_output_dir = '/home/fabric/work/my_notebooks/OWL_new/'
    owl.download_output(node, local_output_dir)
# Out:
# Downloading pcap files from STAR
# 10.129.129.2.pcap
# Downloaded /home/rocky/owl-output/10.129.129.2.pcap from STAR to /home/fabric/work/my_notebooks/OWL_new/STAR/10.129.129.2.pcap
# Downloading pcap files from MAX
# 10.130.7.2.pcap
# Downloaded /home/rocky/owl-output/10.130.7.2.pcap from MAX to /home/fabric/work/my_notebooks/OWL_new/MAX/10.130.7.2.pcap
# Downloading pcap files from MICH
# 10.131.3.2.pcap
# Downloaded /home/rocky/owl-output/10.131.3.2.pcap from MICH to /home/fabric/work/my_notebooks/OWL_new/MICH/10.131.3.2.pcap
# Downloading pcap files from MASS
# 10.131.132.2.pcap
# Downloaded /home/rocky/owl-output/10.131.132.2.pcap from MASS to /home/fabric/work/my_notebooks/OWL_new/MASS/10.131.132.2.pcap
# Downloading pcap files from UTAH
# 10.132.5.2.pcap
# Downloaded /home/rocky/owl-output/10.132.5.2.pcap from UTAH to /home/fabric/work/my_notebooks/OWL_new/UTAH/10.132.5.2.pcap
# Downloading pcap files from NCSA
# 10.132.131.2.pcap
# Downloaded /home/rocky/owl-output/10.132.131.2.pcap from NCSA to /home/fabric/work/my_notebooks/OWL_new/NCSA/10.132.131.2.pcap
# Downloading pcap files from UCSD
# 10.134.130.2.pcap
# Downloaded /home/rocky/owl-output/10.134.130.2.pcap from UCSD to /home/fabric/work/my_notebooks/OWL_new/UCSD/10.134.130.2.pcap
# Downloading pcap files from FIU
# 10.135.133.2.pcap
# Downloaded /home/rocky/owl-output/10.135.133.2.pcap from FIU to /home/fabric/work/my_notebooks/OWL_new/FIU/10.135.133.2.pcap
# Downloading pcap files from CLEM
# 10.136.2.2.pcap
# Downloaded /home/rocky/owl-output/10.136.2.2.pcap from CLEM to /home/fabric/work/my_notebooks/OWL_new/CLEM/10.136.2.2.pcap
# Downloading pcap files from CERN
# 10.143.2.2.pcap
# Downloaded /home/rocky/owl-output/10.143.2.2.pcap from CERN to /home/fabric/work/my_notebooks/OWL_new/CERN/10.143.2.2.pcap
